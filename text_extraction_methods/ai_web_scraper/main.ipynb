# %%
def crawl_links(start_url, max_pages=10000):
    """
    Web crawler that recursively visits URLs and extracts links from each page.
    
    Args:
        start_url (str): The starting URL to begin crawling
        max_pages (int): Maximum number of pages to crawl (safety limit)
        
    Returns:
        set: Set of all discovered links matching the base URL
    """
    from urllib.parse import urlparse, urljoin
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.chrome.options import Options
    import time
    
    # Set up Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Run in headless mode
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    
    # Initialize the browser
    driver = webdriver.Chrome(options=chrome_options)
    
    # Extract the base URL for comparison
    parsed_url = urlparse(start_url)
    base_url = f"{parsed_url.scheme}://{parsed_url.netloc}/"
    print(f"\n=== CRAWLER STARTING ===")
    print(f"Starting URL: {start_url}")
    print(f"Base URL for filtering: {base_url}")
    
    # Initialize queue and visited set
    queue = [start_url]
    visited = set()
    all_discovered_links = set()
    
    pages_visited = 0
    
    try:
        while queue and pages_visited < max_pages:
            # Get the next URL from the queue
            current_url = queue.pop(0)
            
            # Skip if already visited
            if current_url in visited:
                continue
            
            print(f"\n[{pages_visited + 1}/{max_pages}] Processing: {current_url}")
            
            # Visit the URL
            try:
                driver.get(current_url)
                time.sleep(0.1)  # Wait for page to load
                
                # Mark as visited
                visited.add(current_url)
                pages_visited += 1
                
                # Check if we're on the right site
                current_page_url = driver.current_url
                current_parsed = urlparse(current_page_url)
                current_base = f"{current_parsed.scheme}://{current_parsed.netloc}/"
                
                if current_base != base_url:
                    print(f"ERROR: We've navigated away from {base_url} to {current_base}")
                    continue
                
                # Scroll to make sure all content is loaded
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(0.5)
                driver.execute_script("window.scrollTo(0, 0);")
                time.sleep(0.5)
                
                # Get ALL anchor elements with href attributes
                link_elements = driver.find_elements(By.CSS_SELECTOR, "a[href]")
                print(f"Found {len(link_elements)} total links on the page")
                
                # Extract and process links
                new_links = 0
                for element in link_elements:
                    try:
                        href = element.get_attribute('href')
                        
                        if not href or href in ['#', 'javascript:void(0)', 'javascript:;']:
                            continue
                        
                        # Make URL absolute
                        if not href.startswith('http'):
                            href = urljoin(current_page_url, href)
                        
                        # Parse the link to get its base URL
                        link_parsed = urlparse(href)
                        link_base = f"{link_parsed.scheme}://{link_parsed.netloc}/"
                        
                        # Only process links with matching base URL
                        if link_base == base_url:
                            # Add to all discovered links
                            all_discovered_links.add(href)
                            
                            # If not visited and not in queue, add to queue
                            if href not in visited and href not in queue:
                                queue.append(href)
                                new_links += 1
                    except Exception as e:
                        continue
                
                print(f"Added {new_links} new links to the queue")
                print(f"Queue size: {len(queue)}")
                print(f"Total discovered links: {len(all_discovered_links)}")
                
            except Exception as e:
                print(f"Error processing {current_url}: {str(e)}")
        
        if pages_visited >= max_pages:
            print(f"\n=== MAXIMUM PAGES LIMIT REACHED ({max_pages}) ===")
        else:
            print(f"\n=== CRAWL COMPLETE ===")
        
        print(f"Total pages visited: {pages_visited}")
        print(f"Total unique links discovered: {len(all_discovered_links)}")
        
        # Print the array of all discovered links
        print("\n=== ALL DISCOVERED LINKS ===")
        for link in all_discovered_links:
            print(link)
        
        return all_discovered_links
        
    except Exception as e:
        print(f"Crawler error: {str(e)}")
        return all_discovered_links
    finally:
        # Always close the browser
        driver.quit()

# %%
crawl_links("https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter")
# Out:
# === CRAWLER STARTING ===
# Starting URL: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter
# Base URL for filtering: https://catalog.manoa.hawaii.edu/
#
# [1/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter
# Found 178 total links on the page
# Added 155 new links to the queue
# Queue size: 155
# Total discovered links: 155
#
# [2/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#select_catalog
# Found 178 total links on the page
# Added 0 new links to the queue
# Queue size: 154
# Total discovered links: 155
#
# [3/100] Processing: https://catalog.manoa.hawaii.edu/search_advanced.php?catoid=2
# Found 63 total links on the page
# Added 2 new links to the queue
# Queue size: 155
# Total discovered links: 157
#
# [4/100] Processing: https://catalog.manoa.hawaii.edu/index.php?catoid=2
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 157
# Total discovered links: 160
#
# [5/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=420
# Found 178 total links on the page
# Added 3 new links to the queue
# Queue size: 159
# Total discovered links: 163
#
# [6/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=423
# Found 83 total links on the page
# Added 18 new links to the queue
# Queue size: 176
# Total discovered links: 181
#
# [7/100] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=506
# Found 178 total links on the page
# Added 7 new links to the queue
# Queue size: 182
# Total discovered links: 188
#
# [8/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=510
# Found 384 total links on the page
# Added 323 new links to the queue
# Queue size: 504
# Total discovered links: 511
#
# [9/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=424
# Found 73 total links on the page
# Added 9 new links to the queue
# Queue size: 512
# Total discovered links: 520
#
# [10/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=511
# Found 261 total links on the page
# Added 201 new links to the queue
# Queue size: 712
# Total discovered links: 721
#
# [11/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=513
# Found 222 total links on the page
# Added 142 new links to the queue
# Queue size: 853
# Total discovered links: 863
#
# [12/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=514
# Found 175 total links on the page
# Added 97 new links to the queue
# Queue size: 949
# Total discovered links: 960
#
# [13/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=515
# Found 120 total links on the page
# Added 43 new links to the queue
# Queue size: 991
# Total discovered links: 1003
#
# [14/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=516
# Found 189 total links on the page
# Added 101 new links to the queue
# Queue size: 1091
# Total discovered links: 1104
#
# [15/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=517
# Found 204 total links on the page
# Added 109 new links to the queue
# Queue size: 1199
# Total discovered links: 1213
#
# [16/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=518
# Found 126 total links on the page
# Added 60 new links to the queue
# Queue size: 1258
# Total discovered links: 1273
#
# [17/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=519
# Found 87 total links on the page
# Added 18 new links to the queue
# Queue size: 1275
# Total discovered links: 1291
#
# [18/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=684
# Found 70 total links on the page
# Added 5 new links to the queue
# Queue size: 1279
# Total discovered links: 1296
#
# [19/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=680
# Found 70 total links on the page
# Added 8 new links to the queue
# Queue size: 1286
# Total discovered links: 1304
#
# [20/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=520
# Found 83 total links on the page
# Added 10 new links to the queue
# Queue size: 1295
# Total discovered links: 1314
#
# [21/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=521
# Found 124 total links on the page
# Added 47 new links to the queue
# Queue size: 1341
# Total discovered links: 1361
#
# [22/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=523
# Found 78 total links on the page
# Added 3 new links to the queue
# Queue size: 1343
# Total discovered links: 1364
#
# [23/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=524
# Found 66 total links on the page
# Added 6 new links to the queue
# Queue size: 1348
# Total discovered links: 1370
#
# [24/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=525
# Found 79 total links on the page
# Added 8 new links to the queue
# Queue size: 1355
# Total discovered links: 1378
#
# [25/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=522
# Found 77 total links on the page
# Added 16 new links to the queue
# Queue size: 1370
# Total discovered links: 1394
#
# [26/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=526
# Found 119 total links on the page
# Added 53 new links to the queue
# Queue size: 1422
# Total discovered links: 1447
#
# [27/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=527
# Found 271 total links on the page
# Added 115 new links to the queue
# Queue size: 1536
# Total discovered links: 1562
#
# [28/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=528
# Found 80 total links on the page
# Added 18 new links to the queue
# Queue size: 1553
# Total discovered links: 1580
#
# [29/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=529
# Found 71 total links on the page
# Added 5 new links to the queue
# Queue size: 1557
# Total discovered links: 1585
#
# [30/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=942
# Found 104 total links on the page
# Added 3 new links to the queue
# Queue size: 1559
# Total discovered links: 1588
#
# [31/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=450
# Found 66 total links on the page
# Added 5 new links to the queue
# Queue size: 1563
# Total discovered links: 1593
#
# [32/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=451
# Found 71 total links on the page
# Added 7 new links to the queue
# Queue size: 1569
# Total discovered links: 1600
#
# [33/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=471
# Found 79 total links on the page
# Added 18 new links to the queue
# Queue size: 1586
# Total discovered links: 1618
#
# [34/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=467
# Found 66 total links on the page
# Added 6 new links to the queue
# Queue size: 1591
# Total discovered links: 1624
#
# [35/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=425
# Found 79 total links on the page
# Added 18 new links to the queue
# Queue size: 1608
# Total discovered links: 1642
#
# [36/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=426
# Found 68 total links on the page
# Added 8 new links to the queue
# Queue size: 1615
# Total discovered links: 1650
#
# [37/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=427
# Found 90 total links on the page
# Added 30 new links to the queue
# Queue size: 1644
# Total discovered links: 1680
#
# [38/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=428
# Found 88 total links on the page
# Added 28 new links to the queue
# Queue size: 1671
# Total discovered links: 1708
#
# [39/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=429
# Found 117 total links on the page
# Added 57 new links to the queue
# Queue size: 1727
# Total discovered links: 1765
#
# [40/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=533
# Found 95 total links on the page
# Added 3 new links to the queue
# Queue size: 1729
# Total discovered links: 1768
#
# [41/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1&print
# Found 184 total links on the page
# Added 21 new links to the queue
# Queue size: 1749
# Total discovered links: 1789
#
# [42/100] Processing: https://catalog.manoa.hawaii.edu/help.php?catoid=2
# Found 16 total links on the page
# Added 7 new links to the queue
# Queue size: 1755
# Total discovered links: 1796
#
# [43/100] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=535
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1757
# Total discovered links: 1799
#
# [44/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34323
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1759
# Total discovered links: 1802
#
# [45/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34324
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1761
# Total discovered links: 1805
#
# [46/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34325
# Found 66 total links on the page
# Added 4 new links to the queue
# Queue size: 1764
# Total discovered links: 1809
#
# [47/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34326
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1766
# Total discovered links: 1812
#
# [48/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34327
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1768
# Total discovered links: 1815
#
# [49/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34328
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1770
# Total discovered links: 1818
#
# [50/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34329
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1772
# Total discovered links: 1821
#
# [51/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34330
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1774
# Total discovered links: 1824
#
# [52/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34331
# Found 65 total links on the page
# Added 4 new links to the queue
# Queue size: 1777
# Total discovered links: 1828
#
# [53/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34332
# Found 64 total links on the page
# Added 4 new links to the queue
# Queue size: 1780
# Total discovered links: 1832
#
# [54/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34333
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1782
# Total discovered links: 1835
#
# [55/100] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34334
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 crawl_links("https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter")
#
# Cell In[3], line 54, in crawl_links(start_url, max_pages)
#      52 # Visit the URL
#      53 try:
# ---> 54     driver.get(current_url)
#      55     time.sleep(0.1)  # Wait for page to load
#      57     # Mark as visited
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:479, in WebDriver.get(self, url)
#     461 def get(self, url: str) -> None:
#     462     """Navigate the browser to the specified URL in the current window or
#     463     tab.
#     464
#    (...)    477     >>> driver.get("https://example.com")
#     478     """
# --> 479     self.execute(Command.GET, {"url": url})
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:451, in WebDriver.execute(self, driver_command, params)
#     448     elif "sessionId" not in params:
#     449         params["sessionId"] = self.session_id
# --> 451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
#     454     self.error_handler.check_response(response)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/urllib3/poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def ai_crawler(start_url, extraction_prompt, output_file="scraped_data.json", max_pages=50, google_api_key=None):
    """
    AI-powered web crawler that visits URLs, extracts structured data using Gemini-1.5-lite,
    and saves results to a JSON file.
    
    Args:
        start_url (str): The starting URL to begin crawling
        extraction_prompt (str): Prompt for the LLM describing what data to extract
        output_file (str): Path to save the extracted JSON data
        max_pages (int): Maximum number of pages to crawl (safety limit)
        google_api_key (str): Google API key for Gemini models
        
    Returns:
        list: List of all extracted data items
    """
    from urllib.parse import urlparse, urljoin
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.chrome.options import Options
    from bs4 import BeautifulSoup
    import time
    import json
    import os
    import google.generativeai as genai
    
    # Initialize Google Gemini client
    if not google_api_key:
        google_api_key = os.environ.get("GOOGLE_API_KEY")
    
    if not google_api_key:
        raise ValueError("Google API key must be provided either directly or via GOOGLE_API_KEY environment variable")
    
    genai.configure(api_key=google_api_key)
    
    # Set up Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Run in headless mode
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    
    # Initialize the browser
    driver = webdriver.Chrome(options=chrome_options)
    
    # Extract the base URL for comparison
    parsed_url = urlparse(start_url)
    base_url = f"{parsed_url.scheme}://{parsed_url.netloc}/"
    print(f"\n=== AI CRAWLER STARTING ===")
    print(f"Starting URL: {start_url}")
    print(f"Base URL for filtering: {base_url}")
    
    # Initialize queue and visited set
    queue = [start_url]
    visited = set()
    all_discovered_links = set()
    
    # Initialize data storage
    all_extracted_data = []
    
    pages_visited = 0
    
    # Function to extract data using Gemini
    def extract_with_gemini(page_content, page_url):
        try:
            # Create a combined prompt with page URL and content
            combined_prompt = f"""
URL: {page_url}

EXTRACTION INSTRUCTIONS:
{extraction_prompt}

PAGE CONTENT:
{page_content}

Please extract the requested information as a valid JSON array. Each item should be a JSON object.
If no relevant information is found, return an empty array [].
Return ONLY a valid JSON array without any explanations, markdown formatting, or additional text.
"""
            # Set up the model
            model = genai.GenerativeModel('gemini-1.5-flash')
            
            # Call the Gemini API
            response = model.generate_content(
                combined_prompt,
                generation_config=genai.types.GenerationConfig(
                    temperature=0.1,  # Lower temperature for more consistent outputs
                    max_output_tokens=8192,
                    response_mime_type="application/json"
                )
            )
            
            # Get the model response
            llm_response = response.text.strip()
            
            # Extract just the JSON part (in case the model added explanations)
            json_str = llm_response
            if "```json" in json_str:
                json_str = json_str.split("```json")[1].split("```")[0].strip()
            elif "```" in json_str:
                json_str = json_str.split("```")[1].split("```")[0].strip()
                
            # Parse the JSON response
            extracted_data = json.loads(json_str)
            
            # Ensure we have a list
            if not isinstance(extracted_data, list):
                extracted_data = [extracted_data]
                
            # Add source URL to each item
            for item in extracted_data:
                if isinstance(item, dict):
                    item['source_url'] = page_url
                    item['extraction_timestamp'] = time.strftime("%Y-%m-%d %H:%M:%S")
                    
            return extracted_data
            
        except Exception as e:
            print(f"Error extracting data with Gemini: {str(e)}")
            return []
    
    # Function to save data to JSON file
    def save_to_json(data, filepath):
        try:
            with open(filepath, 'w', encoding='utf-8') as f:
                json.dump(data, f, indent=2, ensure_ascii=False)
            print(f"Data saved to {filepath}")
        except Exception as e:
            print(f"Error saving data to {filepath}: {str(e)}")
            # Create backup file
            backup_file = f"{filepath}.backup_{int(time.time())}.json"
            try:
                with open(backup_file, 'w', encoding='utf-8') as f:
                    json.dump(data, f, indent=2, ensure_ascii=False)
                print(f"Backup data saved to {backup_file}")
            except:
                pass
    
    try:
        while queue and pages_visited < max_pages:
            # Get the next URL from the queue
            current_url = queue.pop(0)
            
            # Skip if already visited
            if current_url in visited:
                continue
            
            print(f"\n[{pages_visited + 1}/{max_pages}] Processing: {current_url}")
            
            # Visit the URL
            try:
                driver.get(current_url)
                time.sleep(0.1)  # Wait for page to load
                
                # Mark as visited
                visited.add(current_url)
                pages_visited += 1
                
                # Check if we're on the right site
                current_page_url = driver.current_url
                current_parsed = urlparse(current_page_url)
                current_base = f"{current_parsed.scheme}://{current_parsed.netloc}/"
                
                if current_base != base_url:
                    print(f"ERROR: We've navigated away from {base_url} to {current_base}")
                    continue
                
                # Scroll to make sure all content is loaded
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(0.1)
                driver.execute_script("window.scrollTo(0, 0);")
                time.sleep(0.1)
                
                # Get page content
                page_source = driver.page_source
                soup = BeautifulSoup(page_source, 'html.parser')
                
                # Clean up page content (remove scripts, styles, etc.)
                for tag in soup(["script", "style", "noscript", "iframe", "meta"]):
                    tag.decompose()
                
                # Get the cleaned text
                page_text = soup.get_text(separator="\n", strip=True)
                page_text = "\n".join(line.strip() for line in page_text.split("\n") if line.strip())
                
                print(f"Page content length: {len(page_text)} characters")
                
                # Process with Gemini and extract data
                print("Extracting data with Gemini-1.5-lite...")
                extracted_items = extract_with_gemini(page_text[:100000], current_page_url)  # Truncate if too long
                
                # Add to overall results
                if extracted_items:
                    print(f"Extracted {len(extracted_items)} items")
                    all_extracted_data.extend(extracted_items)
                else:
                    print("No data extracted from this page")
                
                # Save after each page (incremental saving to prevent data loss)
                print(f"Saving {len(all_extracted_data)} total items to {output_file}")
                save_to_json(all_extracted_data, output_file)
                
                # Get ALL anchor elements with href attributes
                link_elements = driver.find_elements(By.CSS_SELECTOR, "a[href]")
                print(f"Found {len(link_elements)} total links on the page")
                
                # Extract and process links
                new_links = 0
                for element in link_elements:
                    try:
                        href = element.get_attribute('href')
                        
                        if not href or href in ['#', 'javascript:void(0)', 'javascript:;']:
                            continue
                        
                        # Make URL absolute
                        if not href.startswith('http'):
                            href = urljoin(current_page_url, href)
                        
                        # Parse the link to get its base URL
                        link_parsed = urlparse(href)
                        link_base = f"{link_parsed.scheme}://{link_parsed.netloc}/"
                        
                        # Only process links with matching base URL
                        if link_base == base_url:
                            # Add to all discovered links
                            all_discovered_links.add(href)
                            
                            # If not visited and not in queue, add to queue
                            if href not in visited and href not in queue:
                                queue.append(href)
                                new_links += 1
                    except Exception as e:
                        continue
                
                print(f"Added {new_links} new links to the queue")
                print(f"Queue size: {len(queue)}")
                print(f"Total discovered links: {len(all_discovered_links)}")
                
            except Exception as e:
                print(f"Error processing {current_url}: {str(e)}")
        
        if pages_visited >= max_pages:
            print(f"\n=== MAXIMUM PAGES LIMIT REACHED ({max_pages}) ===")
        else:
            print(f"\n=== CRAWL COMPLETE ===")
        
        print(f"Total pages visited: {pages_visited}")
        print(f"Total unique links discovered: {len(all_discovered_links)}")
        print(f"Total data items extracted: {len(all_extracted_data)}")
        
        # Final save
        save_to_json(all_extracted_data, output_file)
        
        return all_extracted_data
        
    except Exception as e:
        print(f"Crawler error: {str(e)}")
        
        # Try to save any data collected so far
        if all_extracted_data:
            save_to_json(all_extracted_data, output_file)
            
        return all_extracted_data
    finally:
        # Always close the browser
        driver.quit()

# %%
description="Traverse the website and extract all course information. The JSON should contain the following information: course prefix (ACC, CINE, AS, BIOL), course number (101, 105, 475, 477), course title (General Biology, Contemporary Middle East: The Politics of Nationalismm Introduction to Women's Studies), course description (Introduction to biology: Cell structure and function, metabolism, molecular, and organismal genetics, and animal physiology., Economic, political and social forces behind current Middle East tensions: Historical origins of Middle East issues, key current conflicts in the Middle East; analysis of the role of oil, religious and national antagonisms and the geopolotical importance o fthe region in twentieth and twenty-first century superpower policy.), num units (4, V, 3), department name (Anthropology, Sociology, Anthropology), metadata (4 units; CSU GE 'B2/B3').. Return as a JSON array of course objects."
extraction_prompt = """
Extract the following information from course catalog pages:
- course_code: The course code (e.g. CS 101)
- title: The course title
- credits: Number of credit hours
- description: Full course description
- prerequisites: Any listed prerequisites

Return as a JSON array of course objects.
"""

results = ai_crawler(
    start_url="https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter", 
    extraction_prompt=description,
    output_file="course_catalog.json", 
    max_pages=10000,
    google_api_key="AIzaSyAdmHIhoIPCg9gdWCfjTBMVetVy4xgAGLw"  # Or set via GOOGLE_API_KEY env var
)
# Out:
# === AI CRAWLER STARTING ===
# Starting URL: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter
# Base URL for filtering: https://catalog.manoa.hawaii.edu/
#
# [1/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter
# Page content length: 9101 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 100 items
# Saving 100 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 178 total links on the page
# Added 155 new links to the queue
# Queue size: 155
# Total discovered links: 155
#
# [2/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#select_catalog
# Page content length: 9101 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 100 items
# Saving 200 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 178 total links on the page
# Added 0 new links to the queue
# Queue size: 154
# Total discovered links: 155
#
# [3/10000] Processing: https://catalog.manoa.hawaii.edu/search_advanced.php?catoid=2
# Page content length: 3725 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 200 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 2 new links to the queue
# Queue size: 155
# Total discovered links: 157
#
# [4/10000] Processing: https://catalog.manoa.hawaii.edu/index.php?catoid=2
# Page content length: 6689 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 200 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 157
# Total discovered links: 160
#
# [5/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=420
# Page content length: 9108 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 100 items
# Saving 300 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 178 total links on the page
# Added 3 new links to the queue
# Queue size: 159
# Total discovered links: 163
#
# [6/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=423
# Page content length: 5119 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 300 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 83 total links on the page
# Added 18 new links to the queue
# Queue size: 176
# Total discovered links: 181
#
# [7/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=506
# Page content length: 29595 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 79 items
# Saving 379 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 178 total links on the page
# Added 7 new links to the queue
# Queue size: 182
# Total discovered links: 188
#
# [8/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=510
# Page content length: 17771 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 379 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 384 total links on the page
# Added 323 new links to the queue
# Queue size: 504
# Total discovered links: 511
#
# [9/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=424
# Page content length: 4819 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 379 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 73 total links on the page
# Added 9 new links to the queue
# Queue size: 512
# Total discovered links: 520
#
# [10/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=511
# Page content length: 10406 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 379 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 261 total links on the page
# Added 201 new links to the queue
# Queue size: 712
# Total discovered links: 721
#
# [11/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=513
# Page content length: 34811 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 379 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 222 total links on the page
# Added 142 new links to the queue
# Queue size: 853
# Total discovered links: 863
#
# [12/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=514
# Page content length: 47856 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 380 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 175 total links on the page
# Added 97 new links to the queue
# Queue size: 949
# Total discovered links: 960
#
# [13/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=515
# Page content length: 20067 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 380 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 120 total links on the page
# Added 43 new links to the queue
# Queue size: 991
# Total discovered links: 1003
#
# [14/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=516
# Page content length: 22697 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 380 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 189 total links on the page
# Added 101 new links to the queue
# Queue size: 1091
# Total discovered links: 1104
#
# [15/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=517
# Page content length: 36573 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 12 items
# Saving 392 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 204 total links on the page
# Added 109 new links to the queue
# Queue size: 1199
# Total discovered links: 1213
#
# [16/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=518
# Page content length: 18331 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 392 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 126 total links on the page
# Added 60 new links to the queue
# Queue size: 1258
# Total discovered links: 1273
#
# [17/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=519
# Page content length: 9547 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 392 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 87 total links on the page
# Added 18 new links to the queue
# Queue size: 1275
# Total discovered links: 1291
#
# [18/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=684
# Page content length: 10076 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 392 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 70 total links on the page
# Added 5 new links to the queue
# Queue size: 1279
# Total discovered links: 1296
#
# [19/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=680
# Page content length: 4891 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 392 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 70 total links on the page
# Added 8 new links to the queue
# Queue size: 1286
# Total discovered links: 1304
#
# [20/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=520
# Page content length: 30182 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 392 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 83 total links on the page
# Added 10 new links to the queue
# Queue size: 1295
# Total discovered links: 1314
#
# [21/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=521
# Page content length: 21214 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 2 items
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 124 total links on the page
# Added 47 new links to the queue
# Queue size: 1341
# Total discovered links: 1361
#
# [22/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=523
# Page content length: 13163 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 78 total links on the page
# Added 3 new links to the queue
# Queue size: 1343
# Total discovered links: 1364
#
# [23/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=524
# Page content length: 3026 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 6 new links to the queue
# Queue size: 1348
# Total discovered links: 1370
#
# [24/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=525
# Page content length: 20895 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 79 total links on the page
# Added 8 new links to the queue
# Queue size: 1355
# Total discovered links: 1378
#
# [25/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=522
# Page content length: 5355 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 77 total links on the page
# Added 16 new links to the queue
# Queue size: 1370
# Total discovered links: 1394
#
# [26/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=526
# Page content length: 27257 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 119 total links on the page
# Added 53 new links to the queue
# Queue size: 1422
# Total discovered links: 1447
#
# [27/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=527
# Page content length: 50927 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 271 total links on the page
# Added 115 new links to the queue
# Queue size: 1536
# Total discovered links: 1562
#
# [28/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=528
# Page content length: 4725 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 80 total links on the page
# Added 18 new links to the queue
# Queue size: 1553
# Total discovered links: 1580
#
# [29/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=529
# Page content length: 16245 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 71 total links on the page
# Added 5 new links to the queue
# Queue size: 1557
# Total discovered links: 1585
#
# [30/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=942
# Page content length: 35134 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 104 total links on the page
# Added 3 new links to the queue
# Queue size: 1559
# Total discovered links: 1588
#
# [31/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=450
# Page content length: 7813 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 5 new links to the queue
# Queue size: 1563
# Total discovered links: 1593
#
# [32/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=451
# Page content length: 8030 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 71 total links on the page
# Added 7 new links to the queue
# Queue size: 1569
# Total discovered links: 1600
#
# [33/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=471
# Page content length: 3526 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 79 total links on the page
# Added 18 new links to the queue
# Queue size: 1586
# Total discovered links: 1618
#
# [34/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=467
# Page content length: 2861 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 6 new links to the queue
# Queue size: 1591
# Total discovered links: 1624
#
# [35/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=425
# Page content length: 4364 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 79 total links on the page
# Added 18 new links to the queue
# Queue size: 1608
# Total discovered links: 1642
#
# [36/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=426
# Page content length: 13319 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 68 total links on the page
# Added 8 new links to the queue
# Queue size: 1615
# Total discovered links: 1650
#
# [37/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=427
# Page content length: 250131 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 90 total links on the page
# Added 30 new links to the queue
# Queue size: 1644
# Total discovered links: 1680
#
# [38/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=428
# Page content length: 90955 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 88 total links on the page
# Added 28 new links to the queue
# Queue size: 1671
# Total discovered links: 1708
#
# [39/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=429
# Page content length: 82935 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 117 total links on the page
# Added 57 new links to the queue
# Queue size: 1727
# Total discovered links: 1765
#
# [40/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=533
# Page content length: 3326 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 394 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 95 total links on the page
# Added 3 new links to the queue
# Queue size: 1729
# Total discovered links: 1768
#
# [41/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1&print
# Page content length: 9083 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 100 items
# Saving 494 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 184 total links on the page
# Added 21 new links to the queue
# Queue size: 1749
# Total discovered links: 1789
#
# [42/10000] Processing: https://catalog.manoa.hawaii.edu/help.php?catoid=2
# Page content length: 4443 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 494 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 16 total links on the page
# Added 7 new links to the queue
# Queue size: 1755
# Total discovered links: 1796
#
# [43/10000] Processing: https://catalog.manoa.hawaii.edu/content.php?catoid=2&navoid=535
# Page content length: 7906 characters
# Extracting data with Gemini-1.5-lite...
# No data extracted from this page
# Saving 494 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1757
# Total discovered links: 1799
#
# [44/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34323
# Page content length: 3062 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 495 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1759
# Total discovered links: 1802
#
# [45/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34324
# Page content length: 3028 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 496 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1761
# Total discovered links: 1805
#
# [46/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34325
# Page content length: 3105 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 497 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 4 new links to the queue
# Queue size: 1764
# Total discovered links: 1809
#
# [47/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34326
# Page content length: 3109 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 498 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1766
# Total discovered links: 1812
#
# [48/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34327
# Page content length: 2932 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 499 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1768
# Total discovered links: 1815
#
# [49/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34328
# Page content length: 3093 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 500 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1770
# Total discovered links: 1818
#
# [50/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34329
# Page content length: 3153 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 501 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1772
# Total discovered links: 1821
#
# [51/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34330
# Page content length: 2998 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 502 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1774
# Total discovered links: 1824
#
# [52/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34331
# Page content length: 3147 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 503 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 65 total links on the page
# Added 4 new links to the queue
# Queue size: 1777
# Total discovered links: 1828
#
# [53/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34332
# Page content length: 3077 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 504 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 4 new links to the queue
# Queue size: 1780
# Total discovered links: 1832
#
# [54/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34333
# Page content length: 3145 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 505 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1782
# Total discovered links: 1835
#
# [55/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34334
# Page content length: 2941 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 506 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1784
# Total discovered links: 1838
#
# [56/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34335
# Page content length: 3082 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 507 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 65 total links on the page
# Added 3 new links to the queue
# Queue size: 1786
# Total discovered links: 1841
#
# [57/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34336
# Page content length: 3090 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 508 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1788
# Total discovered links: 1844
#
# [58/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=50853
# Page content length: 3211 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 509 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1790
# Total discovered links: 1847
#
# [59/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=50854
# Page content length: 3265 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 510 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1792
# Total discovered links: 1850
#
# [60/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=50855
# Page content length: 3321 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 511 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1794
# Total discovered links: 1853
#
# [61/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34338
# Page content length: 3094 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 512 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1796
# Total discovered links: 1856
#
# [62/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34339
# Page content length: 3065 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 513 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1798
# Total discovered links: 1859
#
# [63/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34340
# Page content length: 3124 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 514 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1800
# Total discovered links: 1862
#
# [64/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34341
# Page content length: 3074 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 515 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1802
# Total discovered links: 1865
#
# [65/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34342
# Page content length: 3159 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 516 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1804
# Total discovered links: 1868
#
# [66/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34343
# Page content length: 3141 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 517 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1806
# Total discovered links: 1871
#
# [67/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34344
# Page content length: 3042 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 518 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1808
# Total discovered links: 1874
#
# [68/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34345
# Page content length: 3044 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 519 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1810
# Total discovered links: 1877
#
# [69/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34346
# Page content length: 3088 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 520 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1812
# Total discovered links: 1880
#
# [70/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34347
# Page content length: 3032 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 521 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1814
# Total discovered links: 1883
#
# [71/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34348
# Page content length: 3042 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 522 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1816
# Total discovered links: 1886
#
# [72/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34349
# Page content length: 3057 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 523 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1818
# Total discovered links: 1889
#
# [73/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34350
# Page content length: 3008 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 524 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1820
# Total discovered links: 1892
#
# [74/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34351
# Page content length: 3064 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 525 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 65 total links on the page
# Added 3 new links to the queue
# Queue size: 1822
# Total discovered links: 1895
#
# [75/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34352
# Page content length: 3064 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 526 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1824
# Total discovered links: 1898
#
# [76/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34353
# Page content length: 3103 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 527 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 65 total links on the page
# Added 3 new links to the queue
# Queue size: 1826
# Total discovered links: 1901
#
# [77/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34354
# Page content length: 2924 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 528 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1828
# Total discovered links: 1904
#
# [78/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34355
# Page content length: 2961 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 529 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1830
# Total discovered links: 1907
#
# [79/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34356
# Page content length: 3084 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 530 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1832
# Total discovered links: 1910
#
# [80/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34357
# Page content length: 3077 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 531 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1834
# Total discovered links: 1913
#
# [81/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34358
# Page content length: 3041 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 532 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1836
# Total discovered links: 1916
#
# [82/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34359
# Page content length: 3068 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 533 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1838
# Total discovered links: 1919
#
# [83/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34360
# Page content length: 3095 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 534 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1840
# Total discovered links: 1922
#
# [84/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34361
# Page content length: 3148 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 535 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1842
# Total discovered links: 1925
#
# [85/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=34362
# Page content length: 3009 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 536 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1844
# Total discovered links: 1928
#
# [86/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35805
# Page content length: 3023 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 537 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1846
# Total discovered links: 1931
#
# [87/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35806
# Page content length: 3064 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 538 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1848
# Total discovered links: 1934
#
# [88/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35807
# Page content length: 3088 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 539 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 65 total links on the page
# Added 4 new links to the queue
# Queue size: 1851
# Total discovered links: 1938
#
# [89/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35808
# Page content length: 2956 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 540 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1853
# Total discovered links: 1941
#
# [90/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35809
# Page content length: 3124 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 541 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1855
# Total discovered links: 1944
#
# [91/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35810
# Page content length: 3125 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 542 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1857
# Total discovered links: 1947
#
# [92/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35811
# Page content length: 3255 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 543 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 73 total links on the page
# Added 9 new links to the queue
# Queue size: 1865
# Total discovered links: 1956
#
# [93/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35812
# Page content length: 3076 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 544 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1867
# Total discovered links: 1959
#
# [94/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35813
# Page content length: 2952 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 545 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1869
# Total discovered links: 1962
#
# [95/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35816
# Page content length: 3068 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 546 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1871
# Total discovered links: 1965
#
# [96/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35818
# Page content length: 3137 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 547 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1873
# Total discovered links: 1968
#
# [97/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=50758
# Page content length: 3128 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 548 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1875
# Total discovered links: 1971
#
# [98/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=50766
# Page content length: 3037 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 549 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1877
# Total discovered links: 1974
#
# [99/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35819
# Page content length: 2955 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 550 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1879
# Total discovered links: 1977
#
# [100/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35820
# Page content length: 3183 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 551 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 67 total links on the page
# Added 3 new links to the queue
# Queue size: 1881
# Total discovered links: 1980
#
# [101/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35821
# Page content length: 3119 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 552 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1883
# Total discovered links: 1983
#
# [102/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35822
# Page content length: 3179 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 553 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 4 new links to the queue
# Queue size: 1886
# Total discovered links: 1987
#
# [103/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=50727
# Page content length: 3140 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 554 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 65 total links on the page
# Added 3 new links to the queue
# Queue size: 1888
# Total discovered links: 1990
#
# [104/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35823
# Page content length: 2983 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 555 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1890
# Total discovered links: 1993
#
# [105/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=50728
# Page content length: 3124 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 556 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 4 new links to the queue
# Queue size: 1893
# Total discovered links: 1997
#
# [106/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35824
# Page content length: 3010 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 557 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1895
# Total discovered links: 2000
#
# [107/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35825
# Page content length: 3207 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 558 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 67 total links on the page
# Added 3 new links to the queue
# Queue size: 1897
# Total discovered links: 2003
#
# [108/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35826
# Page content length: 3109 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 559 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1899
# Total discovered links: 2006
#
# [109/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35827
# Page content length: 3104 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 560 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1901
# Total discovered links: 2009
#
# [110/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35828
# Page content length: 3236 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 561 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 68 total links on the page
# Added 3 new links to the queue
# Queue size: 1903
# Total discovered links: 2012
#
# [111/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35829
# Page content length: 3117 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 562 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1905
# Total discovered links: 2015
#
# [112/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35830
# Page content length: 3044 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 563 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1907
# Total discovered links: 2018
#
# [113/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35831
# Page content length: 3084 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 564 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1909
# Total discovered links: 2021
#
# [114/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35832
# Page content length: 2967 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 565 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 63 total links on the page
# Added 3 new links to the queue
# Queue size: 1911
# Total discovered links: 2024
#
# [115/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35833
# Page content length: 3082 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 566 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 64 total links on the page
# Added 3 new links to the queue
# Queue size: 1913
# Total discovered links: 2027
#
# [116/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35834
# Page content length: 3080 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 567 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1915
# Total discovered links: 2030
#
# [117/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35835
# Page content length: 2996 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 568 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1917
# Total discovered links: 2033
#
# [118/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35836
# Page content length: 3234 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 569 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 73 total links on the page
# Added 3 new links to the queue
# Queue size: 1919
# Total discovered links: 2036
#
# [119/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35837
# Page content length: 3174 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 570 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 70 total links on the page
# Added 3 new links to the queue
# Queue size: 1921
# Total discovered links: 2039
#
# [120/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35838
# Page content length: 3309 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 571 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 70 total links on the page
# Added 3 new links to the queue
# Queue size: 1923
# Total discovered links: 2042
#
# [121/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35839
# Page content length: 3144 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 572 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 66 total links on the page
# Added 3 new links to the queue
# Queue size: 1925
# Total discovered links: 2045
#
# [122/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35817
# Page content length: 3080 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 1 items
# Saving 573 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 68 total links on the page
# Added 3 new links to the queue
# Queue size: 1927
# Total discovered links: 2048
#
# [123/10000] Processing: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=35841
# Page content length: 3095 characters
# ...
# Page content length: 9870 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 43 items
# Saving 12790 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 165 total links on the page
# Added 31 new links to the queue
# Queue size: 6551
# Total discovered links: 7028
#
# [478/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=743&returnto=510
# Page content length: 7101 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 38 items
# Saving 12828 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 115 total links on the page
# Added 9 new links to the queue
# Queue size: 6559
# Total discovered links: 7037
#
# [479/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=745&returnto=510
# Page content length: 12420 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 84 items
# Saving 12912 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 198 total links on the page
# Added 26 new links to the queue
# Queue size: 6584
# Total discovered links: 7063
#
# [480/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=754&returnto=510
# Page content length: 8254 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 26 items
# Saving 12938 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 148 total links on the page
# Added 26 new links to the queue
# Queue size: 6609
# Total discovered links: 7089
#
# [481/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=757&returnto=510
# Page content length: 7395 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 59 items
# Saving 12997 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 105 total links on the page
# Added 20 new links to the queue
# Queue size: 6628
# Total discovered links: 7109
#
# [482/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1588&returnto=510
# Page content length: 7407 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 50 items
# Saving 13047 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 105 total links on the page
# Added 20 new links to the queue
# Queue size: 6647
# Total discovered links: 7129
#
# [483/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1049&returnto=510
# Page content length: 6433 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 12 items
# Saving 13059 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 88 total links on the page
# Added 8 new links to the queue
# Queue size: 6654
# Total discovered links: 7137
#
# [484/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1038&returnto=510
# Page content length: 6140 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 22 items
# Saving 13081 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 106 total links on the page
# Added 13 new links to the queue
# Queue size: 6666
# Total discovered links: 7150
#
# [485/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1039&returnto=510
# Page content length: 5946 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 21 items
# Saving 13102 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 101 total links on the page
# Added 11 new links to the queue
# Queue size: 6676
# Total discovered links: 7161
#
# [486/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1040&returnto=510
# Page content length: 5503 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 18 items
# Saving 13120 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 105 total links on the page
# Added 15 new links to the queue
# Queue size: 6690
# Total discovered links: 7176
#
# [487/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1041&returnto=510
# Page content length: 5568 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 21 items
# Saving 13141 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 113 total links on the page
# Added 17 new links to the queue
# Queue size: 6706
# Total discovered links: 7193
#
# [488/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1042&returnto=510
# Page content length: 5399 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 26 items
# Saving 13167 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 105 total links on the page
# Added 14 new links to the queue
# Queue size: 6719
# Total discovered links: 7207
#
# [489/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=774&returnto=510
# Page content length: 9075 characters
# Extracting data with Gemini-1.5-lite...
# Extracted 30 items
# Saving 13197 total items to course_catalog.json
# Data saved to course_catalog.json
# Found 144 total links on the page
# Added 23 new links to the queue
# Queue size: 6741
# Total discovered links: 7230
#
# [490/10000] Processing: https://catalog.manoa.hawaii.edu/preview_program.php?catoid=2&poid=1066&returnto=510
# Page content length: 9061 characters
# Extracting data with Gemini-1.5-lite...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 13
#       1 description="Traverse the website and extract all course information. The JSON should contain the following information: course prefix (ACC, CINE, AS, BIOL), course number (101, 105, 475, 477), course title (General Biology, Contemporary Middle East: The Politics of Nationalismm Introduction to Women's Studies), course description (Introduction to biology: Cell structure and function, metabolism, molecular, and organismal genetics, and animal physiology., Economic, political and social forces behind current Middle East tensions: Historical origins of Middle East issues, key current conflicts in the Middle East; analysis of the role of oil, religious and national antagonisms and the geopolotical importance o fthe region in twentieth and twenty-first century superpower policy.), num units (4, V, 3), department name (Anthropology, Sociology, Anthropology), metadata (4 units; CSU GE 'B2/B3').. Return as a JSON array of course objects."
#       2 extraction_prompt = """
#       3 Extract the following information from course catalog pages:
#       4 - course_code: The course code (e.g. CS 101)
#    (...)     10 Return as a JSON array of course objects.
#      11 """
# ---> 13 results = ai_crawler(
#      14     start_url="https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter",
#      15     extraction_prompt=description,
#      16     output_file="course_catalog.json",
#      17     max_pages=10000,
#      18     google_api_key="AIzaSyAdmHIhoIPCg9gdWCfjTBMVetVy4xgAGLw"  # Or set via GOOGLE_API_KEY env var
#      19 )
#
# Cell In[10], line 188, in ai_crawler(start_url, extraction_prompt, output_file, max_pages, google_api_key)
#     186 # Process with Gemini and extract data
#     187 print("Extracting data with Gemini-1.5-lite...")
# --> 188 extracted_items = extract_with_gemini(page_text[:100000], current_page_url)  # Truncate if too long
#     190 # Add to overall results
#     191 if extracted_items:
#
# Cell In[10], line 82, in ai_crawler.<locals>.extract_with_gemini(page_content, page_url)
#      79 model = genai.GenerativeModel('gemini-1.5-flash')
#      81 # Call the Gemini API
# ---> 82 response = model.generate_content(
#      83     combined_prompt,
#      84     generation_config=genai.types.GenerationConfig(
#      85         temperature=0.1,  # Lower temperature for more consistent outputs
#      86         max_output_tokens=8192,
#      87         response_mime_type="application/json"
#      88     )
#      89 )
#      91 # Get the model response
#      92 llm_response = response.text.strip()
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/generativeai/generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)    275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/grpc/_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:79, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)     76         },
#      77     )
# ---> 79 response = continuation(client_call_details, request)
#      80 if logging_enabled:  # pragma: NO COVER
#      81     response_metadata = response.trailing_metadata()
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)    312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/grpc/_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)   1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)   1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
import time
import json
import re
import os
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock
from urllib.parse import urljoin
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

def load_translations(translations_file_path):
    """Load course prefix to department name translations from JSON file."""
    try:
        with open(translations_file_path, 'r', encoding='utf-8') as f:
            return json.load(f)
    except Exception as e:
        print(f"Warning: Could not load translations file {translations_file_path}: {e}")
        return {}

def parse_course_preview_html(html, url, translations=None):
    soup = BeautifulSoup(html, 'html.parser')
    container = soup.find('td', class_='block_content', colspan="2")
    if not container:
        return None

    # Course prefix, number, title
    course_title_h1 = container.find('h1', id='course_preview_title')
    prefix = number = title = None
    if course_title_h1:
        text = course_title_h1.get_text(separator=' ', strip=True)
        match = re.match(r'([A-Z]+)\s+([\dA-Z]+)\s*-\s*(.*)', text)
        if match:
            prefix, number, title = match.groups()

    # Units (credits)
    credits_match = re.search(r'Credits:\s*(\d+(\.\d+)?)', container.get_text())
    credits_text = credits_match.group(1) if credits_match else None

    # Full text as lines
    full_text = container.get_text(separator='\n', strip=True)
    credits_pos = full_text.find('Credits:')

    # Extract description: from Credits: to before first <strong> label or end of content
    desc = None
    if credits_pos >= 0:
        # Find where the description ends: position of first <strong> tag's text after credits, or end of text if none found
        strong_tags = container.find_all('strong')
        end_pos = len(full_text)
        for tag in strong_tags:
            label = tag.get_text(strip=True)
            idx = full_text.find(label)
            if idx > credits_pos and idx < end_pos:
                end_pos = idx
        desc = full_text[credits_pos + len('Credits:'):end_pos].strip()

    # Now extract all metadata fields dynamically: all <strong> labels and their following text content
    metadata = {}
    strong_tags = container.find_all('strong')
    for tag in strong_tags:
        label = tag.get_text(strip=True).rstrip(':')
        content_parts = []
        sibling = tag.next_sibling
        while sibling:
            if getattr(sibling, 'name', None) == 'strong':
                break
            if isinstance(sibling, str):
                content_parts.append(sibling.strip())
            else:
                content_parts.append(sibling.get_text(strip=True))
            sibling = sibling.next_sibling
        value = ' '.join([part for part in content_parts if part])
        metadata[label] = value

    # Clean metadata of description-related keys
    metadata.pop('Credits', None)
    if '' in metadata:
        metadata.pop('')

    # Get department name from translations
    dept_name = None
    if translations and prefix:
        dept_name = translations.get(prefix, None)
    
    return {
        'course_prefix': prefix,
        'course_number': number,
        'course_title': title,
        'course_desc': desc,
        'num_units': credits_text,
        'dept_name': dept_name,
        'inst_ipeds': None,     # Placeholder if you want to add later
        'metadata': metadata,
        'source_url': url,
        'extraction_timestamp': time.strftime("%Y-%m-%d %H:%M:%S")
    }

def save_to_json(data, filepath, lock=None):
    try:
        if lock:
            with lock:
                with open(filepath, 'w', encoding='utf-8') as f:
                    json.dump(data, f, indent=2, ensure_ascii=False)
                print(f"Saved {len(data)} records to {filepath}")
        else:
            with open(filepath, 'w', encoding='utf-8') as f:
                json.dump(data, f, indent=2, ensure_ascii=False)
            print(f"Saved {len(data)} records to {filepath}")
    except Exception as e:
        print(f"Error saving JSON: {e}")

def extract_single_course(course_url, translations, delay=0.1):
    """Extract a single course using its own webdriver instance."""
    options = Options()
    options.add_argument("--headless")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    
    driver = webdriver.Chrome(options=options)
    
    try:
        driver.get(course_url)
        time.sleep(delay)
        
        page_source = driver.page_source
        parsed = parse_course_preview_html(page_source, course_url, translations)
        return parsed
    except Exception as e:
        print(f"Error extracting course {course_url}: {e}")
        return None
    finally:
        driver.quit()

def crawl_courses(base_catalog_url_template, base_course_url_prefix, output_file, start_page=0, end_page=92, 
                 max_workers=4, delay_between_requests=0.1, batch_size=50):
    """
    Parallelized course crawler with configurable parameters.
    
    Args:
        max_workers: Number of parallel browser instances (default: 4)
        delay_between_requests: Delay between requests in seconds (default: 0.1)
        batch_size: Number of courses to process before saving (default: 50)
    """
    print(f"Starting parallelized crawl with {max_workers} workers, {delay_between_requests}s delay, batch size {batch_size}")
    
    # Load translations for department names
    try:
        script_dir = os.path.dirname(os.path.abspath(__file__))
    except NameError:
        script_dir = os.getcwd()
    
    translations_path = os.path.join(script_dir, 'translations.json')
    translations = load_translations(translations_path)
    print(f"Loaded {len(translations)} department translations from {translations_path}")

    # Setup for catalog page collection
    options = Options()
    options.add_argument("--headless")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    driver = webdriver.Chrome(options=options)

    visited_courses = set()
    all_extracted = []
    file_lock = Lock()
    total_course_count = 0

    # Process each catalog page one by one
    for page_num in range(start_page, end_page + 1):
        catalog_url = base_catalog_url_template.format(page_number=page_num)
        print(f"\nVisiting catalog page {page_num}: {catalog_url}")
        
        # Collect course links from current catalog page
        current_page_course_links = set()
        try:
            driver.get(catalog_url)
            time.sleep(0.1)

            links = driver.find_elements(By.CSS_SELECTOR, "a[href]")
            for link in links:
                href = link.get_attribute('href')
                if href and href.startswith(base_course_url_prefix):
                    if href not in visited_courses:
                        current_page_course_links.add(href)
            
            print(f"  Found {len(current_page_course_links)} new course links on this page.")
        except Exception as e:
            print(f"  Error visiting catalog page {catalog_url}: {e}")
            continue

        if not current_page_course_links:
            continue

        # Process courses from current catalog page in parallel
        course_urls = list(current_page_course_links)
        print(f"\nProcessing {len(course_urls)} courses from page {page_num} with {max_workers} workers...")
        
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            # Submit all course extraction tasks
            future_to_url = {
                executor.submit(extract_single_course, url, translations, delay_between_requests): url 
                for url in course_urls
            }
            
            # Process completed tasks
            completed_count = 0
            batch_results = []
            
            for future in as_completed(future_to_url):
                course_url = future_to_url[future]
                completed_count += 1
                total_course_count += 1
                
                try:
                    parsed = future.result()
                    if parsed:
                        print(f"[{completed_count}/{len(course_urls)}] [Total: {total_course_count}] Extracted: {parsed['course_prefix']} {parsed['course_number']} - {parsed['course_title']}")
                        batch_results.append(parsed)
                        all_extracted.append(parsed)
                    else:
                        print(f"[{completed_count}/{len(course_urls)}] [Total: {total_course_count}] Failed to parse: {course_url}")
                    
                    visited_courses.add(course_url)
                    
                    # Save in batches to prevent data loss while maintaining performance
                    if len(batch_results) >= batch_size or completed_count == len(course_urls):
                        save_to_json(all_extracted, output_file, file_lock)
                        batch_results = []
                        
                except Exception as e:
                    print(f"[{completed_count}/{len(course_urls)}] [Total: {total_course_count}] Error processing {course_url}: {e}")
        
        print(f"\nCompleted catalog page {page_num}. Total courses extracted so far: {len(all_extracted)}")

    driver.quit()
    print(f"\nParallelized crawling finished. Extracted {len(all_extracted)} courses total.")
    save_to_json(all_extracted, output_file, file_lock)

if __name__ == "__main__":
    BASE_CATALOG_URL_TEMPLATE = (
        "https://catalog.manoa.hawaii.edu/content.php?"
        "catoid=2&catoid=2&navoid=420&"
        "filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&"
        "filter%5B3%5D=1&filter%5Bcpage%5D={page_number}#acalog_template_course_filter"
    )
    BASE_COURSE_URL_PREFIX = "https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid="
    OUTPUT_FILE = "extracted_coursesV2.json"

    # Parallelization parameters - adjust these for speed vs. server load balance
    MAX_WORKERS = 50        # Number of parallel browser instances (higher = faster, but more resource intensive)
    DELAY = 0.05          # Delay between requests in seconds (lower = faster, but higher server load)
    BATCH_SIZE = 100       # Save frequency (lower = more frequent saves, higher = better performance)

    crawl_courses(
        BASE_CATALOG_URL_TEMPLATE, 
        BASE_COURSE_URL_PREFIX, 
        OUTPUT_FILE, 
        start_page=0, 
        end_page=92,
        max_workers=MAX_WORKERS,
        delay_between_requests=DELAY,
        batch_size=BATCH_SIZE
    )
# Out:
# Starting parallelized crawl with 50 workers, 0.05s delay, batch size 100
# Loaded 179 department translations from /Users/rodericktabalba/Documents/GitHub/RAG-system/text_extraction_methods/ai_web_scraper/translations.json
#
# Visiting catalog page 0: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=0#acalog_template_course_filter
#   Found 0 new course links on this page.
#
# Visiting catalog page 1: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=1#acalog_template_course_filter
#   Found 100 new course links on this page.
#
# Processing 100 courses from page 1 with 50 workers...
# [1/100] [Total: 1] Extracted: CINE 495 - Cinematic Arts Internship
# [2/100] [Total: 2] Extracted: CINE 410 - Advanced Cinematic Production
# [3/100] [Total: 3] Extracted: CINE 419 - Virtual and Augmented Reality Programming
# [4/100] [Total: 4] Extracted: ACC 602 - CPA Review-Audit and Attestation
# [5/100] [Total: 5] Extracted: CINE 370 - Directing the Actor on Screen
# [6/100] [Total: 6] Extracted: CINE 475 - Screenwriting Capstone
# [45/55] [Total: 9045] Extracted: ZOOL 399 - Directed Study
# [46/55] [Total: 9046] Extracted: ZOOL 691 - (Alpha) Seminar in Zoology
# [47/55] [Total: 9047] Extracted: ZOOL 619 - Seminar on Science Teaching
# [48/55] [Total: 9048] Extracted: ZOOL 780 - Foundations of Evolution and Ecology I
# [49/55] [Total: 9049] Extracted: ZOOL 490 - (Alpha) Seminar in Zoology
# [50/55] [Total: 9050] Extracted: ZOOL 691H - Seminar in Zoology: marine biology
# [51/55] [Total: 9051] Extracted: ZOOL 607 - Genetics of Behavior and Evolution
# [52/55] [Total: 9052] Extracted: ZOOL 691B - Seminar in Zoology: general zoology
# [53/55] [Total: 9053] Extracted: ZOOL 715 - Topics in Invertebrate Zoology
# [54/55] [Total: 9054] Extracted: ZOOL 750 - Topics in Conservation Biology
# [55/55] [Total: 9055] Extracted: ZOOL 420 - Developmental Biology
# Saved 9055 records to extracted_coursesV2.json
#
# Completed catalog page 91. Total courses extracted so far: 9055
#
# Visiting catalog page 92: https://catalog.manoa.hawaii.edu/content.php?catoid=2&catoid=2&navoid=420&filter%5Bitem_type%5D=3&filter%5Bonly_active%5D=1&filter%5B3%5D=1&filter%5Bcpage%5D=92#acalog_template_course_filter
#   Found 1 new course links on this page.
#
# Processing 1 courses from page 92 with 50 workers...
# [1/1] [Total: 9056] Failed to parse: https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid=
# Saved 9055 records to extracted_coursesV2.json
#
# Completed catalog page 92. Total courses extracted so far: 9055
#
# Parallelized crawling finished. Extracted 9055 courses total.
# Saved 9055 records to extracted_coursesV2.json

# %%
import time
import json
import re
import os
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock
from urllib.parse import urljoin
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

def load_translations(translations_file_path):
    """Load course prefix to department name translations from JSON file."""
    try:
        with open(translations_file_path, 'r', encoding='utf-8') as f:
            return json.load(f)
    except Exception as e:
        print(f"Warning: Could not load translations file {translations_file_path}: {e}")
        return {}

def parse_course_preview_html(html, url, translations=None):
    soup = BeautifulSoup(html, 'html.parser')
    container = soup.find('td', class_='block_content', colspan="2")
    if not container:
        return None

    # Course prefix, number, title
    course_title_h1 = container.find('h1', id='course_preview_title')
    prefix = number = title = None
    if course_title_h1:
        text = course_title_h1.get_text(separator=' ', strip=True)
        match = re.match(r'([A-Z]+)\s+([\dA-Z]+)\s*-\s*(.*)', text)
        if match:
            prefix, number, title = match.groups()

    # Units (credits)
    credits_match = re.search(r'Credits:\s*(\d+(\.\d+)?)', container.get_text())
    credits_text = credits_match.group(1) if credits_match else None

    # Full text as lines
    full_text = container.get_text(separator='\n', strip=True)
    credits_pos = full_text.find('Credits:')

    # Extract description: from Credits: to before first <strong> label or end of content
    desc = None
    if credits_pos >= 0:
        # Find where the description ends: position of first <strong> tag's text after credits, or end of text if none found
        strong_tags = container.find_all('strong')
        end_pos = len(full_text)
        for tag in strong_tags:
            label = tag.get_text(strip=True)
            idx = full_text.find(label)
            if idx > credits_pos and idx < end_pos:
                end_pos = idx
        desc = full_text[credits_pos + len('Credits:'):end_pos].strip()

    # Now extract all metadata fields dynamically: all <strong> labels and their following text content
    metadata = {}
    strong_tags = container.find_all('strong')
    for tag in strong_tags:
        label = tag.get_text(strip=True).rstrip(':')
        content_parts = []
        sibling = tag.next_sibling
        while sibling:
            if getattr(sibling, 'name', None) == 'strong':
                break
            if isinstance(sibling, str):
                content_parts.append(sibling.strip())
            else:
                content_parts.append(sibling.get_text(strip=True))
            sibling = sibling.next_sibling
        value = ' '.join([part for part in content_parts if part])
        metadata[label] = value

    # Clean metadata of description-related keys
    metadata.pop('Credits', None)
    if '' in metadata:
        metadata.pop('')

    # Get department name from translations
    dept_name = None
    if translations and prefix:
        dept_name = translations.get(prefix, None)
    
    return {
        'course_prefix': prefix,
        'course_number': number,
        'course_title': title,
        'course_desc': desc,
        'num_units': credits_text,
        'dept_name': dept_name,
        'inst_ipeds': None,     # Placeholder if you want to add later
        'metadata': metadata,
        'source_url': url,
        'extraction_timestamp': time.strftime("%Y-%m-%d %H:%M:%S")
    }

def save_to_json(data, filepath, lock=None):
    try:
        if lock:
            with lock:
                with open(filepath, 'w', encoding='utf-8') as f:
                    json.dump(data, f, indent=2, ensure_ascii=False)
                print(f"Saved {len(data)} records to {filepath}")
        else:
            with open(filepath, 'w', encoding='utf-8') as f:
                json.dump(data, f, indent=2, ensure_ascii=False)
            print(f"Saved {len(data)} records to {filepath}")
    except Exception as e:
        print(f"Error saving JSON: {e}")

def extract_single_course(course_url, translations, delay=0.1):
    """Extract a single course using its own webdriver instance."""
    options = Options()
    options.add_argument("--headless")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    
    driver = webdriver.Chrome(options=options)
    
    try:
        driver.get(course_url)
        time.sleep(delay)
        
        page_source = driver.page_source
        parsed = parse_course_preview_html(page_source, course_url, translations)
        return parsed
    except Exception as e:
        print(f"Error extracting course {course_url}: {e}")
        return None
    finally:
        driver.quit()

def crawl_courses(base_catalog_url_template, base_course_url_prefix, output_file, start_page=0, end_page=92, 
                 max_workers=4, delay_between_requests=0.1, batch_size=50):
    """
    Parallelized course crawler with configurable parameters.
    
    Args:
        max_workers: Number of parallel browser instances (default: 4)
        delay_between_requests: Delay between requests in seconds (default: 0.1)
        batch_size: Number of courses to process before saving (default: 50)
    """
    print(f"Starting parallelized crawl with {max_workers} workers, {delay_between_requests}s delay, batch size {batch_size}")
    
    # Load translations for department names
    try:
        script_dir = os.path.dirname(os.path.abspath(__file__))
    except NameError:
        script_dir = os.getcwd()
    
    translations_path = os.path.join(script_dir, 'translations.json')
    translations = load_translations(translations_path)
    print(f"Loaded {len(translations)} department translations from {translations_path}")

    # Setup for catalog page collection
    options = Options()
    options.add_argument("--headless")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    driver = webdriver.Chrome(options=options)

    visited_courses = set()
    all_extracted = []
    file_lock = Lock()
    total_course_count = 0

    # Process each catalog page one by one
    for page_num in range(start_page, end_page + 1):
        catalog_url = base_catalog_url_template.format(page_number=page_num)
        print(f"\nVisiting catalog page {page_num}: {catalog_url}")
        
        # Collect course links from current catalog page
        current_page_course_links = set()
        try:
            driver.get(catalog_url)
            time.sleep(0.1)

            links = driver.find_elements(By.CSS_SELECTOR, "a[href]")
            for link in links:
                href = link.get_attribute('href')
                if href and href.startswith(base_course_url_prefix):
                    if href not in visited_courses:
                        current_page_course_links.add(href)
            
            print(f"  Found {len(current_page_course_links)} new course links on this page.")
        except Exception as e:
            print(f"  Error visiting catalog page {catalog_url}: {e}")
            continue

        if not current_page_course_links:
            continue

        # Process courses from current catalog page in parallel
        course_urls = list(current_page_course_links)
        print(f"\nProcessing {len(course_urls)} courses from page {page_num} with {max_workers} workers...")
        
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            # Submit all course extraction tasks
            future_to_url = {
                executor.submit(extract_single_course, url, translations, delay_between_requests): url 
                for url in course_urls
            }
            
            # Process completed tasks
            completed_count = 0
            batch_results = []
            
            for future in as_completed(future_to_url):
                course_url = future_to_url[future]
                completed_count += 1
                total_course_count += 1
                
                try:
                    parsed = future.result()
                    if parsed:
                        print(f"[{completed_count}/{len(course_urls)}] [Total: {total_course_count}] Extracted: {parsed['course_prefix']} {parsed['course_number']} - {parsed['course_title']}")
                        batch_results.append(parsed)
                        all_extracted.append(parsed)
                    else:
                        print(f"[{completed_count}/{len(course_urls)}] [Total: {total_course_count}] Failed to parse: {course_url}")
                    
                    visited_courses.add(course_url)
                    
                    # Save in batches to prevent data loss while maintaining performance
                    if len(batch_results) >= batch_size or completed_count == len(course_urls):
                        save_to_json(all_extracted, output_file, file_lock)
                        batch_results = []
                        
                except Exception as e:
                    print(f"[{completed_count}/{len(course_urls)}] [Total: {total_course_count}] Error processing {course_url}: {e}")
        
        print(f"\nCompleted catalog page {page_num}. Total courses extracted so far: {len(all_extracted)}")

    driver.quit()
    print(f"\nParallelized crawling finished. Extracted {len(all_extracted)} courses total.")
    save_to_json(all_extracted, output_file, file_lock)

if __name__ == "__main__":
    BASE_CATALOG_URL_TEMPLATE = (
        "https://hilo.hawaii.edu/catalog/undergraduate-courses"
    )
    BASE_COURSE_URL_PREFIX = "https://catalog.manoa.hawaii.edu/preview_course_nopop.php?catoid=2&coid="
    OUTPUT_FILE = "extracted_coursesV2.json"

    # Parallelization parameters - adjust these for speed vs. server load balance
    MAX_WORKERS = 50        # Number of parallel browser instances (higher = faster, but more resource intensive)
    DELAY = 0.05          # Delay between requests in seconds (lower = faster, but higher server load)
    BATCH_SIZE = 100       # Save frequency (lower = more frequent saves, higher = better performance)

    crawl_courses(
        BASE_CATALOG_URL_TEMPLATE, 
        BASE_COURSE_URL_PREFIX, 
        OUTPUT_FILE, 
        start_page=0, 
        end_page=92,
        max_workers=MAX_WORKERS,
        delay_between_requests=DELAY,
        batch_size=BATCH_SIZE
    )

# %%
import os
import json
import time
import fitz  # PyMuPDF
import shutil
import tempfile
from urllib.parse import urljoin, urlparse, parse_qs
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import undetected_chromedriver as uc

# Setup output filename
# measure_url = "https://www.capitol.hawaii.gov/session/measure_indiv.aspx?billtype=HB&billnumber=727&year=2025"
measure_url = "https://www.capitol.hawaii.gov/session/measure_indiv.aspx?billtype=HB&billnumber=400&year=2025"
parsed = urlparse(measure_url)
params = parse_qs(parsed.query)
billtype = params.get("billtype", ["UNKNOWN"])[0]
billnumber = params.get("billnumber", ["UNKNOWN"])[0]
year = params.get("year", ["UNKNOWN"])[0]
output_filename = f"{billtype}_{billnumber}_{year}.json"

# Setup download directory
download_dir = tempfile.mkdtemp()

options = uc.ChromeOptions()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "plugins.always_open_pdf_externally": True
})
driver = uc.Chrome(options=options)

def clean_html_text(html):
    soup = BeautifulSoup(html, "html.parser")
    for tag in soup(["script", "style", "noscript"]):
        tag.decompose()
    return soup.get_text(separator="\n", strip=True)

def extract_pdf_text_from_file(file_path):
    try:
        doc = fitz.open(file_path)
        text = "\n".join(page.get_text() for page in doc)
        doc.close()
        return text
    except Exception as e:
        return f"[ERROR extracting PDF text: {e}]"

try:
    driver.get(measure_url)
    time.sleep(0.1)

    # Collect all links inside main-content
    main = driver.find_element(By.ID, "main-content")
    a_tags = main.find_elements(By.XPATH, ".//a[@href]")
    base_url = measure_url
    raw_links = [urljoin(base_url, a.get_attribute("href")) for a in a_tags]
    filtered = [u for u in raw_links if u.lower().endswith((".htm", ".pdf"))]

    # Prefer .htm if both .htm and .pdf exist for same base
    unique_docs = {}
    for link in filtered:
        path = urlparse(link).path
        base = os.path.splitext(os.path.basename(path))[0]
        key = os.path.dirname(path) + "/" + base
        ext = os.path.splitext(path)[1].lower()
        if ext == ".htm":
            unique_docs[key] = link
        elif ext == ".pdf" and key not in unique_docs:
            unique_docs[key] = link

    results = []
    for doc_url in unique_docs.values():
        print(f"Processing: {doc_url}")
        if doc_url.lower().endswith(".htm"):
            driver.get(doc_url)
            time.sleep(3)
            html = driver.page_source
            text = clean_html_text(html)
            results.append({"url": doc_url, "text": text})
        elif doc_url.lower().endswith(".pdf"):
            # Remove old files first
            for f in os.listdir(download_dir):
                os.remove(os.path.join(download_dir, f))
            # Click the PDF link
            driver.get(measure_url)  # Reload base page to stay consistent
            time.sleep(3)
            link_el = driver.find_element(By.XPATH, f'//a[@href="{urlparse(doc_url).path}"]')
            link_el.click()
            time.sleep(5)  # Wait for download

            # Find the downloaded PDF file
            downloaded_pdf = next((os.path.join(download_dir, f)
                                   for f in os.listdir(download_dir)
                                   if f.lower().endswith(".pdf")), None)
            if downloaded_pdf:
                text = extract_pdf_text_from_file(downloaded_pdf)
                results.append({"url": doc_url, "text": text})
            else:
                results.append({"url": doc_url, "text": "[ERROR: PDF not downloaded]"})

    # Save results
    with open(output_filename, "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

    print(f"✅ Saved to {output_filename}")

finally:
    driver.quit()
    shutil.rmtree(download_dir)
# Out:
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/bills/HB400_CD1_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/bills/GM1329_.PDF
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/bills/HB400_SD2_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/bills/HB400_HD1_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/bills/HB400_SD1_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/bills/HB400_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/CommReports/HB400_HSCR286_.htm
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/CommReports/HB400_HD1_HSCR1171_.htm
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/CommReports/HB400_SD1_SSCR1253_.htm
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/CommReports/HB400_SD2_SSCR1841_.htm
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/CommReports/HB400_CD1_CCR157_.htm
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/Testimony/HB400_TESTIMONY_JHA_01-30-25_.PDF
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/Testimony/HB400_TESTIMONY_FIN_03-05-25_.PDF
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/Testimony/HB400_HD1_TESTIMONY_JDC_03-19-25_.PDF
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/Testimony/HB400_SD1_TESTIMONY_WAM_03-31-25_.PDF
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/hearingnotices/HEARING_JHA_01-30-25_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/hearingnotices/HEARING_FIN_03-05-25_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/hearingnotices/HEARING_JDC_03-19-25_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/hearingnotices/HEARING_WAM_03-31-25_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/hearingnotices/CONF_JHA_04-17-25_2_.HTM
# Processing: https://www.capitol.hawaii.gov/sessions/session2025/hearingnotices/CONF_JHA_04-21-25_RECONVENE_2_.HTM
# ✅ Saved to HB_400_2025.json
