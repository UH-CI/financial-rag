# %%
import json
import chromadb

# %% [markdown]
# # Overview
# The following code cells up to Model 2 are for testing. Scroll down to Model 2 to start.
#
# Summary of what this notebook does:
# I experimented with some preprocessing for improving the way documents are stored in the vector database.
# First, I extracted the text from documents using two methods:
# * Camelot -- used for extracting tables from PDFs
# * PDFPlumber -- used for extracting text from PDFs
#
# I used the two methods because PDFplumber didn't seem like it was performing well on tables.
# Camelot performed better, but was not perfect.
# In some pages, PDFplumber contained extra information that Camelot was unable to pick up.
# In some pages, Camelot extracted the correct numbers.
#
# So I extract the text using both methods.
# Outputs are stored in /model_outputs/text_extraction
#
# Second I did a step that may have not mattered, which was to create a model to classify whether a PDF page had a budget table or not.
# I manually labeled the data, created a classification model using prompt engineering with Gemini, which classified the pages.
#
# /model_outputs/model2_performance contains the performance of the model.
# Outputs are stored in /model_outputs/page_classifications
#
# Thirdly, I used Gemini to look at the extractions and create:
# budget items -- for pages with a budget table
# EX:
# ```
# {
#   "item_number": "1",
#   "program": "General Support for Economic Development",
#   "program_id": "BED116",
#   "expending_agency": "Department of Business and Economic Development",
#   "fiscal_year_2025_2026_amount": "1234567",
#   "appropriations_mof_2025_2026": "A",
#   "fiscal_year_2026_2027_amount": "1456789",
#   "appropriations_mof_2026_2027": "A",
#   "document_name": "HB300",
#   "page_number": 15,
#   "extraction_method": "gemini_dual",
#   "classification_prediction": "budget_table",
#   "classification_confidence": "high"
# }
# ```
# text items -- for pages with just text
# EX:
# ```
# {
#   "text": "This is the cleaned and formatted text content from the page. It represents the best extraction (either camelot or pdfplumber) based on the AI classification, with formatting cleaned up while preserving original content.",
#   "document_name": "HB300",
#   "page_number": 15,
#   "extraction_method": "gemini_dual",
#   "classification_prediction": "text",
#   "classification_confidence": "high"
# }
# ```

# %%
def setup_test_chromadb(collection_name="test_budget", reset=True):
    """Set up a ChromaDB client and collection for testing"""
    
    # Create persistent client (newer API)
    client = chromadb.PersistentClient(path="./test_chroma_db")
    
    # Reset collection if it exists
    if reset:
        try:
            client.delete_collection(collection_name)
        except:
            pass
    
    # Create collection
    collection = client.create_collection(
        name=collection_name,
        metadata={"description": "Test budget documents", "hnsw:space": "cosine"}
    )
    
    return client, collection

# Usage:
client, collection = setup_test_chromadb()
print(f"Created collection: {collection.name}")
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Created collection: test_budget

# %%
from sentence_transformers import SentenceTransformer

print("🤖 Loading sentence transformer model...")
model = SentenceTransformer('all-MiniLM-L6-v2')
print("✅ Model loaded successfully")
# Out:
# 🤖 Loading sentence transformer model...
# ✅ Model loaded successfully

# %%
def ingest_budget_json(json_file_path, collection):
    """
    Simple function to ingest budget items from structured JSON into ChromaDB
    Uses the existing budget_items structure from your JSON files
    """
    
    print(f"🔍 Loading JSON file: {json_file_path}")
    
    # Load the JSON file
    with open(json_file_path, 'r') as f:
        data = json.load(f)
    
    # Get budget items from the JSON
    budget_items = data.get('budget_items', [])
    
    print(f"✅ Found {len(budget_items)} budget items in {json_file_path}")
    
    # Prepare data for ChromaDB
    documents = []
    metadatas = []
    ids = []
    
    print("📋 Processing budget items...")
    for i, item in enumerate(budget_items):
        # Show progress every 100 items
        if i % 100 == 0:
            print(f"  📊 Processing item {i+1}/{len(budget_items)}")
        
        # Create document text (similar to your existing system)
        doc_text = f"Department: {item.get('department', 'Unknown')} | "
        if item.get('program'):
            doc_text += f"Program: {item.get('program')} | "
        doc_text += f"Amount: {item.get('amount_formatted', 'Unknown')} | "
        doc_text += f"Fund Type: {item.get('fund_type', 'Unknown')}"
        
        documents.append(doc_text)
        
        # Create metadata (clean out None values)
        metadata = {
            'budget_department': item.get('department', 'Unknown'),
            'budget_program': item.get('program') or 'N/A',
            'budget_amount': item.get('amount', 0),
            'budget_fund_type': item.get('fund_type', 'Unknown'),
            'budget_fund_code': item.get('fund_code', 'Unknown'),
            'budget_fiscal_year': item.get('fiscal_year', 'Unknown'),
            'budget_positions': item.get('positions') or 0,
            'budget_appropriation_type': item.get('appropriation_type', 'Unknown'),
            'chunk_type': 'budget_item'
        }
        
        # Convert all values to ChromaDB-compatible types
        clean_metadata = {}
        for key, value in metadata.items():
            if value is None:
                continue
            elif isinstance(value, (str, int, float, bool)):
                clean_metadata[key] = value
            else:
                clean_metadata[key] = str(value)
        
        metadatas.append(clean_metadata)
        ids.append(f"budget_item_{i}")
    
    print(f"✅ Processed all {len(documents)} budget items")
    
    # Show sample of first few items for verification
    print("\n📝 Sample of processed items:")
    for i in range(min(3, len(documents))):
        print(f"  {i+1}. {documents[i][:100]}...")
        print(f"     Dept: {metadatas[i]['budget_department']}, Amount: ${metadatas[i]['budget_amount']:,}")
    
    # Generate embeddings
    print(f"\n🧠 Generating embeddings for {len(documents)} documents...")
    embeddings = model.encode(documents, show_progress_bar=True).tolist()
    print("✅ Embeddings generated successfully")
    
    # Add to ChromaDB
    print("💾 Adding documents to ChromaDB...")
    
    # Check collection state before adding
    initial_count = collection.count()
    print(f"  Collection had {initial_count} documents before adding")
    
    collection.add(
        documents=documents,
        metadatas=metadatas,
        embeddings=embeddings,
        ids=ids
    )
    
    # Check collection state after adding
    final_count = collection.count()
    print(f"  Collection now has {final_count} documents")
    print(f"  Added {final_count - initial_count} new documents")
    
    print(f"\n🎉 Successfully added {len(documents)} budget items to ChromaDB!")
    
    
    
    return len(documents)

# Usage:
# client, collection = setup_test_chromadb()
count = ingest_budget_json("../output/HB300__hybrid_extraction_structured.json", collection)
print(f"Collection now has {collection.count()} documents")
# Out:
# 🔍 Loading JSON file: ../output/HB300__hybrid_extraction_structured.json
# ✅ Found 785 budget items in ../output/HB300__hybrid_extraction_structured.json
# 📋 Processing budget items...
#   📊 Processing item 1/785
#   📊 Processing item 101/785
#   📊 Processing item 201/785
#   📊 Processing item 301/785
#   📊 Processing item 401/785
#   📊 Processing item 501/785
#   📊 Processing item 601/785
#   📊 Processing item 701/785
# ✅ Processed all 785 budget items
#
# 📝 Sample of processed items:
#   1. Department: Department of Business, Economic Development and Tourism | Program: Strategic Marketing ...
#      Dept: Department of Business, Economic Development and Tourism, Amount: $3,028,040
#   2. Department: Department of Business, Economic Development and Tourism | Program: Strategic Marketing ...
#      Dept: Department of Business, Economic Development and Tourism, Amount: $700,000
#   3. Department: Department of Business, Economic Development and Tourism | Program: Strategic Marketing ...
#      Dept: Department of Business, Economic Development and Tourism, Amount: $1,823,499
#
# 🧠 Generating embeddings for 785 documents...
# Batches: 100%|██████████| 25/25 [00:03<00:00,  8.06it/s]
# Failed to send telemetry event CollectionAddEvent: capture() takes 1 positional argument but 3 were given
# ✅ Embeddings generated successfully
# 💾 Adding documents to ChromaDB...
#   Collection had 0 documents before adding
#   Collection now has 785 documents
#   Added 785 new documents
#
# 🎉 Successfully added 785 budget items to ChromaDB!
# Collection now has 785 documents

# %%
def query_budget(collection, query_text, n_results=100):
    """Simple function to query the budget vector store"""
    
    results = collection.query(
        query_texts=[query_text],
        n_results=n_results
    )
    
    # Filter results if distances are greater than 0.5
    if results['documents'][0]:  # Check if there are any results
        filtered_docs = []
        filtered_meta = []
        filtered_distances = []
        
        for doc, meta, dist in zip(results['documents'][0], results['metadatas'][0], results['distances'][0]):
            if dist <= 0.70:
                filtered_docs.append(doc)
                filtered_meta.append(meta)
                filtered_distances.append(dist)
        
        # Replace the original lists with filtered ones
        results['documents'] = [filtered_docs]
        results['metadatas'] = [filtered_meta]
        results['distances'] = [filtered_distances]

    # Print results
    if results['documents'][0]:
        print(f"Found {len(results['documents'][0])} results for: '{query_text}'")
        for i, (doc, meta, dist) in enumerate(zip(results['documents'][0], results['metadatas'][0], results['distances'][0])):
            dept = meta['budget_department']
            print(f"{i+1}. {doc} - (distance: {dist:.3f})")
    else:
        print(f"No results found for: '{query_text}' within distance threshold of 0.5")
    
    return results

# Usage:
query_budget(collection, "education")
# query_budget(collection, "transportation funding")
# Out:
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Found 21 results for: 'education'
# 1. Department: School Facilities Authority | Program: Education Workforce Housing, Statewide | Amount: $8,000,000 | Fund Type: Capital Improvement - (distance: 0.627)
# 2. Department: School Facilities Authority | Program: Education Workforce Housing, Statewide | Amount: $12,000,000 | Fund Type: Capital Improvement - (distance: 0.630)
# 3. Department: Education | Program: School Facilities Authority | Amount: $112,000,000 | Fund Type: Capital Fund - (distance: 0.632)
# 4. Department: Education | Program: School Support | Amount: $4,000,000 | Fund Type: General Fund - (distance: 0.640)
# 5. Department: School Facilities Authority | Program: Honouliuli Middle School, Oahu | Amount: $3,000,000 | Fund Type: Capital Improvement - (distance: 0.642)
# 6. Department: Education | Program: School Support | Amount: $1,000,150,000 | Fund Type: Other Fund - (distance: 0.646)
# 7. Department: Post-Secondary Education Authorization | Amount: $249,052 | Fund Type: Special Fund - (distance: 0.654)
# 8. Department: Education | Program: School Support | Amount: $111,597,927 | Fund Type: Other Fund - (distance: 0.659)
# 9. Department: Education | Program: School Support | Amount: $74,600,000 | Fund Type: Other Fund - (distance: 0.666)
# 10. Department: Education | Program: School Support | Amount: $32,320,919,069 | Fund Type: General Fund - (distance: 0.669)
# 11. Department: Department of Education | Program: School-Based Budgeting | Amount: $20,000,000 | Fund Type: Special Fund - (distance: 0.671)
# 12. Department: Department of Education | Program: School-Based Budgeting | Amount: $20,000,000 | Fund Type: Special Fund - (distance: 0.671)
# 13. Department: Department of Education | Program: School-Based Budgeting | Amount: $2,000,000 | Fund Type: Special Fund - (distance: 0.672)
# 14. Department: Department of Education | Program: School-Based Budgeting | Amount: $3,000,000 | Fund Type: Special Fund - (distance: 0.675)
# 15. Department: Education | Program: School-Based Budgeting | Amount: $167,203,642 | Fund Type: Other Fund - (distance: 0.678)
# 16. Department: Education | Program: School-Based Budgeting | Amount: $13,390,000 | Fund Type: Other Fund - (distance: 0.679)
# 17. Department: Education | Program: School Community Services | Amount: $5,598,465 | Fund Type: General Fund - (distance: 0.683)
# 18. Department: Education | Program: School Facilities Authority | Amount: $1,731,283 | Fund Type: General Fund - (distance: 0.683)
# 19. Department: Education | Program: State Administration | Amount: $49,433,158 | Fund Type: General Fund - (distance: 0.688)
# 20. Department: Education | Program: School-Based Budgeting | Amount: $21,414,657 | Fund Type: Other Fund - (distance: 0.692)
# 21. Department: Education | Program: School-Based Budgeting | Amount: $1,299,597,395 | Fund Type: General Fund - (distance: 0.695)
# {'ids': [['budget_item_720',
#    'budget_item_719',
#    'budget_item_404',
#    'budget_item_397',
#    'budget_item_717',
#    'budget_item_401',
#    'budget_item_554',
#    'budget_item_402',
#    'budget_item_400',
#    'budget_item_398',
#    'budget_item_713',
#    'budget_item_715',
#    'budget_item_714',
#    'budget_item_716',
#    'budget_item_382',
#    'budget_item_384',
#    'budget_item_405',
#    'budget_item_403',
#    'budget_item_394',
#    'budget_item_383',
#    'budget_item_380',
#    'budget_item_399',
#    'budget_item_393',
#    'budget_item_395',
#    'budget_item_387',
#    'budget_item_385',
#    'budget_item_433',
#    'budget_item_388',
#    'budget_item_416',
#    'budget_item_392',
#    'budget_item_418',
#    'budget_item_390',
#    'budget_item_396',
#    'budget_item_381',
#    'budget_item_718',
#    'budget_item_391',
#    'budget_item_442',
#    'budget_item_424',
#    'budget_item_417',
#    'budget_item_412',
#    'budget_item_410',
#    'budget_item_389',
#    'budget_item_413',
#    'budget_item_432',
#    'budget_item_386',
#    'budget_item_431',
#    'budget_item_449',
#    'budget_item_414',
#    'budget_item_423',
#    'budget_item_466',
#    'budget_item_634',
#    'budget_item_448',
#    'budget_item_458',
#    'budget_item_451',
#    'budget_item_453',
#    'budget_item_415',
#    'budget_item_411',
#    'budget_item_707',
#    'budget_item_708',
#    'budget_item_657',
#    'budget_item_450',
#    'budget_item_425',
#    'budget_item_436',
#    'budget_item_422',
#    'budget_item_633',
#    'budget_item_465',
#    'budget_item_438',
#    'budget_item_437',
#    'budget_item_687',
#    'budget_item_115',
#    'budget_item_464',
#    'budget_item_434',
#    'budget_item_430',
#    'budget_item_551',
#    'budget_item_435',
#    'budget_item_609',
#    'budget_item_457',
#    'budget_item_429',
#    'budget_item_443',
#    'budget_item_336',
#    'budget_item_608',
#    'budget_item_439',
#    'budget_item_114',
#    'budget_item_441',
#    'budget_item_446',
#    'budget_item_444',
#    'budget_item_335',
#    'budget_item_689',
#    'budget_item_38',
#    'budget_item_447',
#    'budget_item_428',
#    'budget_item_119',
#    'budget_item_124',
#    'budget_item_129',
#    'budget_item_136',
#    'budget_item_141',
#    'budget_item_168',
#    'budget_item_440',
#    'budget_item_109',
#    'budget_item_305']],
#  'embeddings': None,
#  'documents': [['Department: School Facilities Authority | Program: Education Workforce Housing, Statewide | Amount: $8,000,000 | Fund Type: Capital Improvement',
#    'Department: School Facilities Authority | Program: Education Workforce Housing, Statewide | Amount: $12,000,000 | Fund Type: Capital Improvement',
#    'Department: Education | Program: School Facilities Authority | Amount: $112,000,000 | Fund Type: Capital Fund',
#    'Department: Education | Program: School Support | Amount: $4,000,000 | Fund Type: General Fund',
#    'Department: School Facilities Authority | Program: Honouliuli Middle School, Oahu | Amount: $3,000,000 | Fund Type: Capital Improvement',
#    'Department: Education | Program: School Support | Amount: $1,000,150,000 | Fund Type: Other Fund',
#    'Department: Post-Secondary Education Authorization | Amount: $249,052 | Fund Type: Special Fund',
#    'Department: Education | Program: School Support | Amount: $111,597,927 | Fund Type: Other Fund',
#    'Department: Education | Program: School Support | Amount: $74,600,000 | Fund Type: Other Fund',
#    'Department: Education | Program: School Support | Amount: $32,320,919,069 | Fund Type: General Fund',
#    'Department: Department of Education | Program: School-Based Budgeting | Amount: $20,000,000 | Fund Type: Special Fund',
#    'Department: Department of Education | Program: School-Based Budgeting | Amount: $20,000,000 | Fund Type: Special Fund',
#    'Department: Department of Education | Program: School-Based Budgeting | Amount: $2,000,000 | Fund Type: Special Fund',
#    'Department: Department of Education | Program: School-Based Budgeting | Amount: $3,000,000 | Fund Type: Special Fund',
#    'Department: Education | Program: School-Based Budgeting | Amount: $167,203,642 | Fund Type: Other Fund',
#    'Department: Education | Program: School-Based Budgeting | Amount: $13,390,000 | Fund Type: Other Fund',
#    'Department: Education | Program: School Community Services | Amount: $5,598,465 | Fund Type: General Fund',
#    'Department: Education | Program: School Facilities Authority | Amount: $1,731,283 | Fund Type: General Fund',
#    'Department: Education | Program: State Administration | Amount: $49,433,158 | Fund Type: General Fund',
#    'Department: Education | Program: School-Based Budgeting | Amount: $21,414,657 | Fund Type: Other Fund',
#    'Department: Education | Program: School-Based Budgeting | Amount: $1,299,597,395 | Fund Type: General Fund']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'budget_amount': 8000000,
#     'budget_fund_code': 'C',
#     'budget_fiscal_year': '2026-2027',
#     'budget_positions': 0,
#     'budget_department': 'School Facilities Authority',
#     'budget_program': 'Education Workforce Housing, Statewide',
#     'chunk_type': 'budget_item',
#     'budget_appropriation_type': 'Capital',
#     'budget_fund_type': 'Capital Improvement'},
#    {'budget_fiscal_year': '2025-2026',
#     'budget_department': 'School Facilities Authority',
#     'budget_amount': 12000000,
#     'budget_fund_code': 'C',
#     'budget_program': 'Education Workforce Housing, Statewide',
#     'chunk_type': 'budget_item',
#     'budget_appropriation_type': 'Capital',
#     'budget_fund_type': 'Capital Improvement',
#     'budget_positions': 0},
#    {'chunk_type': 'budget_item',
#     'budget_program': 'School Facilities Authority',
#     'budget_positions': 0,
#     'budget_amount': 112000000,
#     'budget_appropriation_type': 'Investment: Capital',
#     'budget_fund_type': 'Capital Fund',
#     'budget_fund_code': 'C',
#     'budget_fiscal_year': '2025-2026',
#     'budget_department': 'Education'},
#    {'budget_positions': 5.0,
#     'budget_amount': 4000000,
#     'budget_appropriation_type': 'Operating-Current Lease Payments',
#     'budget_fund_code': 'A',
#     'budget_fund_type': 'General Fund',
#     'budget_fiscal_year': '2025-2026',
#     'chunk_type': 'budget_item',
#     'budget_department': 'Education',
#     'budget_program': 'School Support'},
#    {'budget_program': 'Honouliuli Middle School, Oahu',
#     'budget_positions': 0,
#     'chunk_type': 'budget_item',
#     'budget_fund_type': 'Capital Improvement',
#     'budget_fiscal_year': '2025-2026',
#     'budget_department': 'School Facilities Authority',
#     'budget_appropriation_type': 'Capital',
#     'budget_fund_code': 'C',
#     'budget_amount': 3000000},
#    {'budget_amount': 1000150000,
#     'budget_fund_type': 'Other Fund',
#     'budget_fund_code': 'R',
#     'budget_fiscal_year': '2025-2026',
#     'budget_department': 'Education',
#     'budget_appropriation_type': 'Operating',
#     'budget_program': 'School Support',
#     'budget_positions': 2.0,
#     'chunk_type': 'budget_item'},
#    {'budget_appropriation_type': 'Operating',
#     'budget_program': 'N/A',
#     'budget_fund_type': 'Special Fund',
#     'budget_department': 'Post-Secondary Education Authorization',
#     'budget_positions': 1.0,
#     'budget_amount': 249052,
#     'chunk_type': 'budget_item',
#     'budget_fiscal_year': '2025-2026',
#     'budget_fund_code': 'B'},
#    {'budget_program': 'School Support',
#     'budget_fund_type': 'Other Fund',
#     'budget_fiscal_year': '2025-2026',
#     'budget_department': 'Education',
#     'budget_positions': 0,
#     'budget_amount': 111597927,
#     'budget_fund_code': 'W',
#     'budget_appropriation_type': 'Operating',
#     'chunk_type': 'budget_item'},
#    {'chunk_type': 'budget_item',
#     'budget_program': 'School Support',
#     'budget_appropriation_type': 'Operating',
#     'budget_positions': 0,
#     'budget_fund_type': 'Other Fund',
#     'budget_department': 'Education',
#     'budget_fiscal_year': '2025-2026',
#     'budget_amount': 74600000,
#     'budget_fund_code': 'N'},
#    {'budget_fiscal_year': '2025-2026',
#     'chunk_type': 'budget_item',
#     'budget_appropriation_type': 'Operating',
#     'budget_fund_type': 'General Fund',
#     'budget_fund_code': 'A',
#     'budget_amount': 32320919069,
#     'budget_program': 'School Support',
#     'budget_positions': 11.0,
#     'budget_department': 'Education'},
#    {'budget_positions': 0,
#     'budget_fund_type': 'Special Fund',
#     'budget_program': 'School-Based Budgeting',
#     'budget_appropriation_type': 'Capital',
#     'chunk_type': 'budget_item',
#     'budget_fund_code': 'C',
#     'budget_fiscal_year': '2025-2026',
#     'budget_amount': 20000000,
#     'budget_department': 'Department of Education'},
#    {'chunk_type': 'budget_item',
#     'budget_appropriation_type': 'Capital',
#     'budget_amount': 20000000,
#     'budget_program': 'School-Based Budgeting',
#     'budget_fund_type': 'Special Fund',
#     'budget_positions': 0,
#     'budget_fund_code': 'C',
#     'budget_fiscal_year': '2025-2026',
#     'budget_department': 'Department of Education'},
#    {'budget_fund_code': 'C',
#     'budget_positions': 0,
#     'budget_program': 'School-Based Budgeting',
#     'budget_amount': 2000000,
#     'budget_department': 'Department of Education',
#     'chunk_type': 'budget_item',
#     'budget_fund_type': 'Special Fund',
#     'budget_fiscal_year': '2025-2026',
#     'budget_appropriation_type': 'Capital'},
#    {'budget_positions': 0,
#     'budget_fiscal_year': '2025-2026',
#     'budget_amount': 3000000,
#     'chunk_type': 'budget_item',
#     'budget_department': 'Department of Education',
#     'budget_fund_code': 'C',
#     'budget_fund_type': 'Special Fund',
#     'budget_appropriation_type': 'Capital',
#     'budget_program': 'School-Based Budgeting'},
#    {'budget_positions': 0,
#     'budget_fund_type': 'Other Fund',
#     'budget_appropriation_type': 'Operating',
#     'budget_fiscal_year': '2025-2026',
#     'budget_amount': 167203642,
#     'chunk_type': 'budget_item',
#     'budget_department': 'Education',
#     'budget_program': 'School-Based Budgeting',
#     'budget_fund_code': 'N'},
#    {'budget_positions': 0,
#     'chunk_type': 'budget_item',
#     'budget_program': 'School-Based Budgeting',
#     'budget_fund_code': 'T',
#     'budget_fiscal_year': '2025-2026',
#     'budget_appropriation_type': 'Operating',
#     'budget_fund_type': 'Other Fund',
#     'budget_department': 'Education',
#     'budget_amount': 13390000},
#    {'budget_department': 'Education',
#     'budget_fund_type': 'General Fund',
#     'chunk_type': 'budget_item',
#     'budget_positions': 600,
#     'budget_amount': 5598465,
#     'budget_fiscal_year': '2025-2026',
#     'budget_appropriation_type': 'Operating',
#     'budget_program': 'School Community Services',
#     'budget_fund_code': 'A'},
#    {'budget_amount': 1731283,
#     'budget_department': 'Education',
#     'budget_fiscal_year': '2025-2026',
#     'budget_program': 'School Facilities Authority',
#     'chunk_type': 'budget_item',
#     'budget_fund_type': 'General Fund',
#     'budget_fund_code': 'A',
#     'budget_appropriation_type': 'Operating',
#     'budget_positions': 12.0},
#    {'chunk_type': 'budget_item',
#     'budget_fund_code': 'A',
#     'budget_appropriation_type': 'Operating',
#     'budget_fund_type': 'General Fund',
#     'budget_positions': 7.0,
#     'budget_amount': 49433158,
#     'budget_fiscal_year': '2025-2026',
#     'budget_department': 'Education',
#     'budget_program': 'State Administration'},
#    {'budget_positions': 0,
#     'budget_fiscal_year': '2025-2026',
#     'budget_fund_type': 'Other Fund',
#     'budget_amount': 21414657,
#     'budget_program': 'School-Based Budgeting',
#     'budget_fund_code': 'P',
#     'budget_department': 'Education',
#     'chunk_type': 'budget_item',
#     'budget_appropriation_type': 'Operating'},
#    {'budget_program': 'School-Based Budgeting',
#     'budget_fiscal_year': '2025-2026',
#     'budget_fund_code': 'A',
#     'budget_appropriation_type': 'Operating',
#     'budget_fund_type': 'General Fund',
#     'budget_amount': 1299597395,
#     'chunk_type': 'budget_item',
#     'budget_positions': 1.0,
#     'budget_department': 'Education'}]],
#  'distances': [[0.6266041398048401,
#    0.6303037405014038,
#    0.6320401430130005,
#    0.6403554677963257,
#    0.6420594453811646,
#    0.6458503603935242,
#    0.6536046266555786,
#    0.659355640411377,
#    0.6658738851547241,
#    0.668730616569519,
#    0.6705171465873718,
#    0.6705171465873718,
#    0.6716195344924927,
#    0.6748361587524414,
#    0.6784186363220215,
#    0.6790896654129028,
#    0.6830323338508606,
#    0.683451771736145,
#    0.6882137060165405,
#    0.6919903755187988,
#    0.6947504878044128]]}

# %%
import camelot
import pdfplumber
import json
import os
from pathlib import Path

def extract_pdf_dual_method(pdf_path):
    """
    Extract text from each page using both Camelot and pdfplumber
    
    Args:
        pdf_path (str): Path to the PDF file
        
    Returns:
        str: Path to the generated JSON file
    """
    
    # Setup output path
    pdf_file = Path(pdf_path)
    output_dir = pdf_file.parent
    output_file = output_dir / f"{pdf_file.stem}_dual_extraction.json"
    
    print(f"📄 Processing PDF: {pdf_path}")
    
    # Open PDF with pdfplumber to get page count
    with pdfplumber.open(pdf_path) as pdf:
        total_pages = len(pdf.pages)
        print(f"📊 Total pages: {total_pages}")
        
        results = []
        
        for page_num in range(1, total_pages + 1):  # Camelot uses 1-based indexing
            print(f"🔄 Processing page {page_num}/{total_pages}")
            
            page_data = {
                "page_number": page_num,
                "camelot_text": "",
                "pdfplumber_text": ""
            }
            
            # Extract with Camelot (tables)
            try:
                tables = camelot.read_pdf(pdf_path, pages=str(page_num), flavor='lattice')
                camelot_text = ""
                
                if len(tables) > 0:
                    for i, table in enumerate(tables):
                        camelot_text += f"Table {i+1}:\n"
                        camelot_text += table.df.to_string(index=False) + "\n\n"
                else:
                    # Try stream flavor if lattice finds no tables
                    tables = camelot.read_pdf(pdf_path, pages=str(page_num), flavor='stream')
                    for i, table in enumerate(tables):
                        camelot_text += f"Table {i+1}:\n"
                        camelot_text += table.df.to_string(index=False) + "\n\n"
                
                page_data["camelot_text"] = camelot_text.strip()
                
            except Exception as e:
                print(f"⚠️  Camelot error on page {page_num}: {e}")
                page_data["camelot_text"] = f"Error: {str(e)}"
            
            # Extract with pdfplumber (all text)
            try:
                page = pdf.pages[page_num - 1]  # pdfplumber uses 0-based indexing
                pdfplumber_text = page.extract_text() or ""
                page_data["pdfplumber_text"] = pdfplumber_text.strip()
                
            except Exception as e:
                print(f"⚠️  pdfplumber error on page {page_num}: {e}")
                page_data["pdfplumber_text"] = f"Error: {str(e)}"
            
            results.append(page_data)
    
    # Save to JSON
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)
    
    print(f"✅ Extraction complete! Output saved to: {output_file}")
    return str(output_file)

documents = ["HB300_CD1_.pdf", "HB300_HD1_.pdf", "HB300_SD1_.pdf"]
# Usage:
for idx, document in enumerate(documents):
    print(f"Processing {document}, {idx+1} of {len(documents)}")
    output_path = extract_pdf_dual_method(f"{document}")
# Out:
# Processing HB300_CD1_.pdf, 1 of 3
# 📄 Processing PDF: HB300_CD1_.pdf
# 📊 Total pages: 196
# 🔄 Processing page 1/196
# 🔄 Processing page 2/196
# 🔄 Processing page 3/196
# 🔄 Processing page 4/196
# 🔄 Processing page 5/196
# 🔄 Processing page 6/196
# 🔄 Processing page 7/196
# 🔄 Processing page 8/196
# 🔄 Processing page 9/196
# 🔄 Processing page 10/196
# 🔄 Processing page 11/196
# 🔄 Processing page 12/196
# 🔄 Processing page 13/196
# 🔄 Processing page 14/196
# 🔄 Processing page 15/196
# 🔄 Processing page 16/196
# 🔄 Processing page 17/196
# 🔄 Processing page 18/196
# 🔄 Processing page 19/196
# 🔄 Processing page 20/196
# 🔄 Processing page 21/196
# 🔄 Processing page 22/196
# 🔄 Processing page 23/196
# 🔄 Processing page 24/196
# 🔄 Processing page 25/196
# 🔄 Processing page 26/196
# 🔄 Processing page 27/196
# 🔄 Processing page 28/196
# 🔄 Processing page 29/196
# 🔄 Processing page 30/196
# 🔄 Processing page 31/196
# 🔄 Processing page 32/196
# 🔄 Processing page 33/196
# 🔄 Processing page 34/196
# 🔄 Processing page 35/196
# 🔄 Processing page 36/196
# 🔄 Processing page 37/196
# 🔄 Processing page 38/196
# 🔄 Processing page 39/196
# 🔄 Processing page 40/196
# 🔄 Processing page 41/196
# 🔄 Processing page 42/196
# 🔄 Processing page 43/196
# 🔄 Processing page 44/196
# 🔄 Processing page 45/196
# 🔄 Processing page 46/196
# 🔄 Processing page 47/196
# 🔄 Processing page 48/196
# 🔄 Processing page 49/196
# 🔄 Processing page 50/196
# 🔄 Processing page 51/196
# 🔄 Processing page 52/196
# 🔄 Processing page 53/196
# 🔄 Processing page 54/196
# 🔄 Processing page 55/196
# 🔄 Processing page 56/196
# 🔄 Processing page 57/196
# 🔄 Processing page 58/196
# 🔄 Processing page 59/196
# 🔄 Processing page 60/196
# 🔄 Processing page 61/196
# 🔄 Processing page 62/196
# 🔄 Processing page 63/196
# 🔄 Processing page 64/196
# 🔄 Processing page 65/196
# 🔄 Processing page 66/196
# 🔄 Processing page 67/196
# 🔄 Processing page 68/196
# 🔄 Processing page 69/196
# 🔄 Processing page 70/196
# 🔄 Processing page 71/196
# 🔄 Processing page 72/196
# 🔄 Processing page 73/196
# 🔄 Processing page 74/196
# 🔄 Processing page 75/196
# 🔄 Processing page 76/196
# 🔄 Processing page 77/196
# 🔄 Processing page 78/196
# 🔄 Processing page 79/196
# 🔄 Processing page 80/196
# 🔄 Processing page 81/196
# 🔄 Processing page 82/196
# 🔄 Processing page 83/196
# 🔄 Processing page 84/196
# 🔄 Processing page 85/196
# 🔄 Processing page 86/196
# 🔄 Processing page 87/196
# 🔄 Processing page 88/196
# 🔄 Processing page 89/196
# 🔄 Processing page 90/196
# 🔄 Processing page 91/196
# 🔄 Processing page 92/196
# 🔄 Processing page 93/196
# 🔄 Processing page 94/196
# 🔄 Processing page 95/196
# 🔄 Processing page 96/196
# 🔄 Processing page 97/196
# 🔄 Processing page 98/196
# 🔄 Processing page 99/196
# 🔄 Processing page 100/196
# 🔄 Processing page 101/196
# 🔄 Processing page 102/196
# 🔄 Processing page 103/196
# 🔄 Processing page 104/196
# 🔄 Processing page 105/196
# 🔄 Processing page 106/196
# 🔄 Processing page 107/196
# 🔄 Processing page 108/196
# 🔄 Processing page 109/196
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 86
#      84 for idx, document in enumerate(documents):
#      85     print(f"Processing {document}, {idx+1} of {len(documents)}")
# ---> 86     output_path = extract_pdf_dual_method(f"{document}")
#
# Cell In[63], line 43, in extract_pdf_dual_method(pdf_path)
#      41 # Extract with Camelot (tables)
#      42 try:
# ---> 43     tables = camelot.read_pdf(pdf_path, pages=str(page_num), flavor='lattice')
#      44     camelot_text = ""
#      46     if len(tables) > 0:
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/camelot/io.py:134, in read_pdf(filepath, pages, password, flavor, suppress_stdout, parallel, layout_kwargs, debug, **kwargs)
#     132 p = PDFHandler(filepath, pages=pages, password=password, debug=debug)
#     133 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 134 tables = p.parse(
#     135     flavor=flavor,
#     136     suppress_stdout=suppress_stdout,
#     137     parallel=parallel,
#     138     layout_kwargs=layout_kwargs,
#     139     **kwargs,
#     140 )
#     141 return tables
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/camelot/handlers.py:257, in PDFHandler.parse(self, flavor, suppress_stdout, parallel, layout_kwargs, **kwargs)
#     255     else:
#     256         for p in self.pages:
# --> 257             t = self._parse_page(
#     258                 p, tempdir, parser, suppress_stdout, layout_kwargs
#     259             )
#     260             tables.extend(t)
#     262 return TableList(sorted(tables))
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/camelot/handlers.py:301, in PDFHandler._parse_page(self, page, tempdir, parser, suppress_stdout, layout_kwargs)
#     290 page_path = os.path.join(tempdir, f"page-{page}.pdf")
#     291 parser.prepare_page_parse(
#     292     page_path,
#     293     layout,
#    (...)    299     layout_kwargs=layout_kwargs,
#     300 )
# --> 301 tables = parser.extract_tables()
#     302 return tables
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/camelot/parsers/base.py:223, in BaseParser.extract_tables(self)
#     219     return []
#     221 # Identify plausible areas within the doc where tables lie,
#     222 # populate table_bbox keys with these areas.
# --> 223 self._generate_table_bbox()
#     225 _tables = []
#     226 # sort tables based on y-coord
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/camelot/parsers/lattice.py:262, in Lattice._generate_table_bbox(self)
#     253     regions = scale_areas(self.table_regions)
#     255 vertical_mask, vertical_segments = find_lines(
#     256     self.threshold,
#     257     regions=regions,
#    (...)    260     iterations=self.iterations,
#     261 )
# --> 262 horizontal_mask, horizontal_segments = find_lines(
#     263     self.threshold,
#     264     regions=regions,
#     265     direction="horizontal",
#     266     line_scale=self.line_scale,
#     267     iterations=self.iterations,
#     268 )
#     270 contours = find_contours(vertical_mask, horizontal_mask)
#     271 table_bbox = find_joints(contours, vertical_mask, horizontal_mask)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/camelot/image_processing.py:84, in find_lines(threshold, regions, direction, line_scale, iterations)
#      81 el, size = create_structuring_element(threshold, direction, line_scale)
#      82 threshold = apply_region_mask(threshold, regions)
# ---> 84 processed_threshold = process_image(threshold, el, iterations)
#      85 contours, _ = cv2.findContours(
#      86     processed_threshold.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
#      87 )
#      89 lines = extract_lines_from_contours(contours, direction)
#
# File ~/miniforge3/envs/house_finance_env/lib/python3.11/site-packages/camelot/image_processing.py:167, in process_image(threshold, el, iterations)
#     149 """
#     150 Apply morphological operations to the threshold image.
#     151
#    (...)    164     The processed threshold image.
#     165 """
#     166 threshold = cv2.erode(threshold, el)
# --> 167 threshold = cv2.dilate(threshold, el)
#     168 dmask = cv2.dilate(threshold, el, iterations=iterations)
#     170 return dmask
#
# KeyboardInterrupt:

# %% [markdown]
# # Model #1
#
# This model is classifying each page as either table or text.
# The model is using gemini-1.5-flash model to classify as either table or text
# Works okay, but the document contains tables that are NOT budget items
# whereas I want to only classify as budget items, not necessarily table...

# %%
import json
import google.generativeai as genai
from typing import List, Dict, Any

def classify_pages_with_gemini(json_file_path: str, api_key: str) -> List[Dict[str, Any]]:
    """
    Classify each page in the dual extraction JSON as 'table' or 'text' using Gemini
    
    Args:
        json_file_path (str): Path to the HB300__dual_extraction.json file
        api_key (str): Your Gemini API key
        
    Returns:
        List[Dict]: List of page classifications with analysis
    """
    
    # Configure Gemini
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel('gemini-1.5-flash')
    
    # Load the JSON data
    with open(json_file_path, 'r') as f:
        pages_data = json.load(f)
    
    results = []
    total_pages = len(pages_data)
    
    print(f"🔍 Analyzing {total_pages} pages with Gemini...")
    
    for i, page_data in enumerate(pages_data, 1):
        page_num = page_data['page_number']
        camelot_text = page_data.get('camelot_text', '')
        pdfplumber_text = page_data.get('pdfplumber_text', '')
        
        print(f"📄 Processing page {page_num} ({i}/{total_pages})")
        
        # Create prompt for Gemini
        prompt = f"""
Analyze the following PDF page extractions and classify the page as either "table" or "text":

CAMELOT EXTRACTION (table-focused):
{camelot_text[:2000]}...

PDFPLUMBER EXTRACTION (all text):
{pdfplumber_text[:2000]}...

Based on both extractions, determine:
1. Is this page primarily a TABLE or TEXT document?
2. Provide a confidence score (0-100%)
3. Give a brief reason for your classification
4. Do NOT classify the translation tables as tables -- they are text
5. I am classifying budget items, not translation tables -- a good indicator is if they have budget amounts

Respond in this exact JSON format:
{{
    "classification": "table" or "text",
    "confidence": 85,
    "reason": "Brief explanation of why you classified it this way"
}}
"""
        
        try:
            # Get Gemini response
            response = model.generate_content(prompt)
            response_text = response.text.strip()
            
            # Try to parse JSON from response
            if response_text.startswith('```json'):
                response_text = response_text.replace('```json', '').replace('```', '').strip()
            
            analysis = json.loads(response_text)
            
            result = {
                'page_number': page_num,
                'classification': analysis.get('classification', 'unknown'),
                'confidence': analysis.get('confidence', 0),
                'reason': analysis.get('reason', 'No reason provided'),
                'camelot_length': len(camelot_text),
                'pdfplumber_length': len(pdfplumber_text),
                'status': 'success'
            }
            
        except Exception as e:
            print(f"⚠️  Error analyzing page {page_num}: {e}")
            result = {
                'page_number': page_num,
                'classification': 'error',
                'confidence': 0,
                'reason': f'Error: {str(e)}',
                'camelot_length': len(camelot_text),
                'pdfplumber_length': len(pdfplumber_text),
                'status': 'error'
            }
        
        results.append(result)
        
        # Print progress
        if result['status'] == 'success':
            print(f"   ✅ {result['classification'].upper()} ({result['confidence']}%) - {result['reason'][:50]}...")
        else:
            print(f"   ❌ ERROR - {result['reason']}")
    
    # Summary
    successful = [r for r in results if r['status'] == 'success']
    table_count = len([r for r in successful if r['classification'] == 'table'])
    text_count = len([r for r in successful if r['classification'] == 'text'])
    
    print(f"\n📊 SUMMARY:")
    print(f"   📄 Total pages: {total_pages}")
    print(f"   ✅ Successfully analyzed: {len(successful)}")
    print(f"   📋 Table pages: {table_count}")
    print(f"   📝 Text pages: {text_count}")
    print(f"   ❌ Errors: {total_pages - len(successful)}")
    
    return results

# Usage:
results = classify_pages_with_gemini('HB300__dual_extraction.json', 'AIzaSyAdmHIhoIPCg9gdWCfjTBMVetVy4xgAGLw')
# 
# # Save results
with open('page_classifications.json', 'w') as f:
    json.dump(results, f, indent=2)
# Out:
# 🔍 Analyzing 154 pages with Gemini...
# 📄 Processing page 1 (1/154)
#    ✅ TEXT (95%) - While the CAMELOT extraction shows a numbered list...
# 📄 Processing page 2 (2/154)
#    ✅ TABLE (95%) - Both extractions show the same data, structured in...
# 📄 Processing page 3 (3/154)
#    ✅ TEXT (95%) - Although CAMELOT produced a table-like structure, ...
# 📄 Processing page 4 (4/154)
#    ✅ TEXT (95%) - While the Camelot extraction shows some tabular st...
# 📄 Processing page 5 (5/154)
#    ✅ TABLE (95%) - Both extractions show a structured format with row...
# 📄 Processing page 6 (6/154)
#    ✅ TABLE (95%) - Both extractions show structured data with columns...
# 📄 Processing page 7 (7/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 8 (8/154)
#    ✅ TABLE (95%) - The Camelot extraction clearly shows a structured ...
# 📄 Processing page 9 (9/154)
#    ✅ TABLE (95%) - The Camelot extraction clearly shows a structured ...
# 📄 Processing page 10 (10/154)
#    ✅ TABLE (95%) - Both extractions show structured data with column ...
# 📄 Processing page 11 (11/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 12 (12/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 13 (13/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 14 (14/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows structured da...
# 📄 Processing page 15 (15/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 16 (16/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 17 (17/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 18 (18/154)
#    ✅ TABLE (95%) - Both extractions show evidence of tabular data.  T...
# 📄 Processing page 19 (19/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 20 (20/154)
#    ✅ TABLE (95%) - The Camelot extraction clearly shows a structured ...
# 📄 Processing page 21 (21/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 22 (22/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 23 (23/154)
#    ✅ TABLE (95%) - Both extractions show structured data with columns...
# 📄 Processing page 24 (24/154)
#    ✅ TABLE (95%) - Both extractions show structured data with columns...
# 📄 Processing page 25 (25/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 26 (26/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 27 (27/154)
#    ✅ TABLE (95%) - Both extractions show numerical data organized in ...
# 📄 Processing page 28 (28/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 29 (29/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 30 (30/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 31 (31/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 32 (32/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows structured ta...
# 📄 Processing page 33 (33/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 34 (34/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 35 (35/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 36 (36/154)
#    ✅ TABLE (95%) - Both extractions show structured data with columns...
# 📄 Processing page 37 (37/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 38 (38/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 39 (39/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 40 (40/154)
#    ✅ TABLE (95%) - Both extractions show structured data with columns...
# 📄 Processing page 41 (41/154)
#    ✅ TABLE (95%) - Both extractions show structured data with columns...
# 📄 Processing page 42 (42/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 43 (43/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 44 (44/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 45 (45/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 46 (46/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 47 (47/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 48 (48/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 49 (49/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 50 (50/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 51 (51/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 52 (52/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 53 (53/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 54 (54/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 55 (55/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 56 (56/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows structured ta...
# 📄 Processing page 57 (57/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 58 (58/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 59 (59/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 60 (60/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 61 (61/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows structured ta...
# 📄 Processing page 62 (62/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 63 (63/154)
#    ✅ TEXT (95%) - While CAMELOT's output is structured in a tabular ...
# 📄 Processing page 64 (64/154)
#    ✅ TEXT (95%) - While Camelot's extraction shows a numbered list t...
# 📄 Processing page 65 (65/154)
#    ✅ TEXT (95%) - While the Camelot extraction attempts to structure...
# 📄 Processing page 66 (66/154)
#    ✅ TEXT (95%) - Although Camelot's extraction shows some table-lik...
# 📄 Processing page 67 (67/154)
#    ✅ TABLE (95%) - Both extractions show the same structured data, re...
# 📄 Processing page 68 (68/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 69 (69/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 70 (70/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 71 (71/154)
#    ✅ TEXT (95%) - While CAMELOT's extraction shows a tabular structu...
# 📄 Processing page 72 (72/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 73 (73/154)
#    ✅ TABLE (95%) - Both extractions reveal structured data with numer...
# 📄 Processing page 74 (74/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 75 (75/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 76 (76/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 77 (77/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 78 (78/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 79 (79/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 80 (80/154)
#    ✅ TABLE (95%) - Both extractions show a structured format with num...
# 📄 Processing page 81 (81/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows structured ta...
# 📄 Processing page 82 (82/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows two tables wi...
# 📄 Processing page 83 (83/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows structured ta...
# 📄 Processing page 84 (84/154)
#    ✅ TABLE (95%) - Both extractions show evidence of tabular data.  T...
# 📄 Processing page 85 (85/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 86 (86/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 87 (87/154)
#    ✅ TABLE (95%) - Both extractions show structured data with labeled...
# 📄 Processing page 88 (88/154)
#    ✅ TABLE (95%) - Both extractions show data organized in a tabular ...
# 📄 Processing page 89 (89/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 90 (90/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 91 (91/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 92 (92/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 93 (93/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 94 (94/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 95 (95/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 96 (96/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 97 (97/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 98 (98/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 99 (99/154)
#    ✅ TABLE (95%) - Both extractions show evidence of a table.  The CA...
# 📄 Processing page 100 (100/154)
#    ✅ TABLE (95%) - The Camelot extraction clearly shows a table struc...
# 📄 Processing page 101 (101/154)
#    ✅ TABLE (95%) - Both extractions show structured data with column ...
# 📄 Processing page 102 (102/154)
#    ✅ TABLE (95%) - The Camelot extraction clearly shows a structured ...
# 📄 Processing page 103 (103/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 104 (104/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 105 (105/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 106 (106/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 107 (107/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 108 (108/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 109 (109/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 110 (110/154)
#    ✅ TABLE (95%) - Both extractions show structured data with labeled...
# 📄 Processing page 111 (111/154)
#    ✅ TABLE (95%) - Both extractions show structured data with identif...
# 📄 Processing page 112 (112/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 113 (113/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 114 (114/154)
#    ✅ TABLE (95%) - Both extractions show structured data with columns...
# 📄 Processing page 115 (115/154)
#    ✅ TABLE (95%) - Both extractions show a structured format with col...
# 📄 Processing page 116 (116/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numeric...
# 📄 Processing page 117 (117/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 118 (118/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a table struc...
# 📄 Processing page 119 (119/154)
#    ✅ TABLE (95%) - Both extractions show evidence of tabular data.  T...
# 📄 Processing page 120 (120/154)
#    ✅ TABLE (85%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 121 (121/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows two tables wi...
# 📄 Processing page 122 (122/154)
#    ✅ TABLE (95%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 123 (123/154)
#    ✅ TABLE (95%) - Both extractions show structured data with numbere...
# 📄 Processing page 124 (124/154)
#    ✅ TABLE (90%) - The CAMELOT extraction clearly shows a structured ...
# 📄 Processing page 125 (125/154)
#    ✅ TABLE (95%) - Both extractions show structured data with headers...
# 📄 Processing page 126 (126/154)
#    ✅ TABLE (95%) - Both extractions show a significant portion of the...
# 📄 Processing page 127 (127/154)
#    ✅ TEXT (95%) - While CamelOT extracts the text into a table-like ...
# 📄 Processing page 128 (128/154)
#    ✅ TEXT (95%) - While CAMELOT's extraction shows a table structure...
# 📄 Processing page 129 (129/154)
#    ✅ TEXT (95%) - While Camelot's extraction shows a tabular structu...
# 📄 Processing page 130 (130/154)
#    ✅ TEXT (95%) - While CAMELOT's output shows a numbered list,  it ...
# 📄 Processing page 131 (131/154)
#    ✅ TEXT (95%) - While Camelot extracts the text into a tabular for...
# 📄 Processing page 132 (132/154)
#    ✅ TEXT (95%) - While Camelot extracts the text into a table-like ...
# 📄 Processing page 133 (133/154)
#    ✅ TEXT (95%) - While the Camelot extraction shows a tabular struc...
# 📄 Processing page 134 (134/154)
#    ✅ TEXT (95%) - While Camelot's extraction shows some tabular stru...
# 📄 Processing page 135 (135/154)
#    ✅ TEXT (95%) - While the Camelot extraction attempts to structure...
# 📄 Processing page 136 (136/154)
#    ✅ TEXT (95%) - Although Camelot's extraction attempts to organize...
# 📄 Processing page 137 (137/154)
#    ✅ TEXT (95%) - While Camelot's extraction attempts to organize th...
# 📄 Processing page 138 (138/154)
#    ✅ TEXT (95%) - While Camelot produced a table-like output,  it's ...
# 📄 Processing page 139 (139/154)
#    ✅ TEXT (95%) - While the CAMELOT extraction presents the text in ...
# 📄 Processing page 140 (140/154)
#    ✅ TEXT (95%) - Both extractions show primarily continuous text, s...
# 📄 Processing page 141 (141/154)
#    ✅ TEXT (95%) - While Camelot produced extractions that resemble t...
# 📄 Processing page 142 (142/154)
#    ✅ TEXT (95%) - While Camelot's extraction attempts to structure t...
# 📄 Processing page 143 (143/154)
#    ✅ TEXT (95%) - While Camelot's extraction attempts to structure t...
# 📄 Processing page 144 (144/154)
#    ✅ TEXT (95%) - While the Camelot extraction attempts to structure...
# 📄 Processing page 145 (145/154)
#    ✅ TEXT (95%) - While the Camelot extraction attempts to structure...
# 📄 Processing page 146 (146/154)
#    ✅ TEXT (95%) - While Camelot's extraction shows a table structure...
# 📄 Processing page 147 (147/154)
#    ✅ TEXT (95%) - While Camelot extracts the text in a tabular forma...
# 📄 Processing page 148 (148/154)
#    ✅ TEXT (95%) - While Camelot's extraction shows a tabular structu...
# 📄 Processing page 149 (149/154)
#    ✅ TEXT (95%) - Although Camelot produced a table-like output, the...
# 📄 Processing page 150 (150/154)
#    ✅ TEXT (95%) - Although Camelot produced a table structure, the d...
# 📄 Processing page 151 (151/154)
#    ✅ TEXT (95%) - Although Camelot produced a table structure with n...
# 📄 Processing page 152 (152/154)
#    ✅ TABLE (95%) - Both extractions show structured data representing...
# 📄 Processing page 153 (153/154)
#    ✅ TEXT (95%) - While Camelot's extraction shows a numbered 'Table...
# 📄 Processing page 154 (154/154)
#    ✅ TEXT (95%) - While CAMELOT produced a table structure with numb...
#
# 📊 SUMMARY:
#    📄 Total pages: 154
#    ✅ Successfully analyzed: 154
#    📋 Table pages: 119
#    📝 Text pages: 35
#    ❌ Errors: 0

# %% [markdown]
# # Model # 2
#
# The following model will read the camelot & PDFPlumber versions and calssify
# whether the text are budget items or text

# %%
import json
import google.generativeai as genai
from typing import List, Dict, Any

def classify_pages_with_gemini(json_file_path: str, api_key: str) -> List[Dict[str, Any]]:
    """
    Classify each page in the dual extraction JSON as 'table' or 'text' using Gemini
    
    Args:
        json_file_path (str): Path to the HB300__dual_extraction.json file
        api_key (str): Your Gemini API key
        
    Returns:
        List[Dict]: List of page classifications with analysis
    """
    
    # Configure Gemini
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel('gemini-1.5-flash')
    
    # Load the JSON data
    with open(json_file_path, 'r') as f:
        pages_data = json.load(f)
    
    results = []
    total_pages = len(pages_data)
    
    print(f"🔍 Analyzing {total_pages} pages with Gemini...")
    
    for i, page_data in enumerate(pages_data, 1):
        page_num = page_data['page_number']
        camelot_text = page_data.get('camelot_text', '')
        pdfplumber_text = page_data.get('pdfplumber_text', '')
        
        print(f"📄 Processing page {page_num} ({i}/{total_pages})")
        
        # Updated prompt for budget item classification
        prompt = f"""
        Analyze the following PDF page extractions and classify the page as either "budget_table" or "text":

        CAMELOT EXTRACTION (table-focused):
        {camelot_text[:2000]}...

        PDFPLUMBER EXTRACTION (all text):
        {pdfplumber_text[:2000]}...

        You are specifically looking for BUDGET ITEM TABLES that contain financial appropriations data.

        BUDGET ITEM TABLES typically contain:
        - Department names (e.g., "Department of Education", "Department of Health")
        - Program names and IDs (e.g., "BED100", "EDN200")
        - Dollar amounts/appropriations (e.g., "$3,028,040", "2,500,000")
        - Fund types (e.g., "General Fund", "Special Fund")
        - Fund codes (A, B, C, etc.)
        - Position counts (FTE positions)
        - Appropriation types ("Operating", "Capital")
        - Fiscal years (e.g., "2025-2027")

        DO NOT classify as "budget_table":
        - Translation/definition tables (department abbreviations, fund code meanings)
        - General text content
        - Headers, titles, or introductory text
        - Legal language or bill text

        Based on both extractions, determine:
        1. Is this page primarily a BUDGET_TABLE (containing actual budget line items with dollar amounts) or TEXT?
        2. Provide a confidence score (0-100%)
        3. Give a brief reason focusing on what budget elements you found or didn't find

        Respond in this exact JSON format:
        {{
            "classification": "budget_table" or "text",
            "confidence": 85,
            "reason": "Brief explanation focusing on budget elements found"
        }}
        """
        
        try:
            # Get Gemini response
            response = model.generate_content(prompt)
            response_text = response.text.strip()
            
            # Try to parse JSON from response
            if response_text.startswith('```json'):
                response_text = response_text.replace('```json', '').replace('```', '').strip()
            
            analysis = json.loads(response_text)
            
            result = {
                'page_number': page_num,
                'classification': analysis.get('classification', 'unknown'),
                'confidence': analysis.get('confidence', 0),
                'reason': analysis.get('reason', 'No reason provided'),
                'camelot_length': len(camelot_text),
                'pdfplumber_length': len(pdfplumber_text),
                'status': 'success'
            }
            
        except Exception as e:
            print(f"⚠️  Error analyzing page {page_num}: {e}")
            result = {
                'page_number': page_num,
                'classification': 'error',
                'confidence': 0,
                'reason': f'Error: {str(e)}',
                'camelot_length': len(camelot_text),
                'pdfplumber_length': len(pdfplumber_text),
                'status': 'error'
            }
        
        results.append(result)
        
        # Print progress
        if result['status'] == 'success':
            print(f"   ✅ {result['classification'].upper()} ({result['confidence']}%) - {result['reason'][:50]}...")
        else:
            print(f"   ❌ ERROR - {result['reason']}")
    
    # Summary
    successful = [r for r in results if r['status'] == 'success']
    table_count = len([r for r in successful if r['classification'] == 'table'])
    text_count = len([r for r in successful if r['classification'] == 'text'])
    
    print(f"\n📊 SUMMARY:")
    print(f"   📄 Total pages: {total_pages}")
    print(f"   ✅ Successfully analyzed: {len(successful)}")
    print(f"   📋 Table pages: {table_count}")
    print(f"   📝 Text pages: {text_count}")
    print(f"   ❌ Errors: {total_pages - len(successful)}")
    
    return results

jsons = ["HB300_CD1__dual_extraction.json", "HB300_HD1__dual_extraction.json", "HB300_SD1__dual_extraction.json"]

for idx, output in enumerate(jsons):
    results = classify_pages_with_gemini(f"{output}", 'AIzaSyAdmHIhoIPCg9gdWCfjTBMVetVy4xgAGLw')
    with open(f'page_classifications_{idx}.json', 'w') as f:
        json.dump(results, f, indent=2)
# Out:
# 🔍 Analyzing 196 pages with Gemini...
# 📄 Processing page 1 (1/196)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 2 (2/196)
#    ✅ TEXT (95%) - The provided extractions contain department names,...
# 📄 Processing page 3 (3/196)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 4 (4/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 5 (5/196)
#    ✅ TEXT (95%) - Neither extraction shows any actual budget line it...
# 📄 Processing page 6 (6/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 7 (7/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 8 (8/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 9 (9/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 10 (10/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with clear budget li...
# 📄 Processing page 11 (11/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 12 (12/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 13 (13/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table with clear budget li...
# 📄 Processing page 14 (14/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (TR...
# 📄 Processing page 15 (15/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (TR...
# 📄 Processing page 16 (16/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with clear budget li...
# 📄 Processing page 17 (17/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 18 (18/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 19 (19/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with Program IDs (e....
# 📄 Processing page 20 (20/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 21 (21/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 22 (22/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (HT...
# 📄 Processing page 23 (23/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 24 (24/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain numerous budget line item...
# 📄 Processing page 25 (25/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 26 (26/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain program IDs (e.g., HTH9O6...
# 📄 Processing page 27 (27/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 28 (28/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 29 (29/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table structure wi...
# 📄 Processing page 30 (30/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 31 (31/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 32 (32/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 33 (33/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 34 (34/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 35 (35/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 36 (36/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 37 (37/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 38 (38/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 39 (39/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 40 (40/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 41 (41/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with Program IDs (e....
# 📄 Processing page 42 (42/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 43 (43/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 44 (44/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 45 (45/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain numerous budget line item...
# 📄 Processing page 46 (46/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 47 (47/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show numerous budget line items w...
# 📄 Processing page 48 (48/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 49 (49/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 50 (50/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 51 (51/196)
#    ✅ TEXT (95%) - While the extractions contain some budget-related ...
# 📄 Processing page 52 (52/196)
#    ✅ TEXT (95%) - While the extractions mention a dollar amount ($1,...
# 📄 Processing page 53 (53/196)
#    ✅ TEXT (90%) - While both extractions mention dollar amounts ($1,...
# 📄 Processing page 54 (54/196)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 55 (55/196)
#    ✅ TEXT (90%) - While both extractions mention dollar amounts and ...
# 📄 Processing page 56 (56/196)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
# 📄 Processing page 57 (57/196)
#    ✅ TEXT (95%) - Neither extraction contains actual budget line ite...
# 📄 Processing page 58 (58/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 59 (59/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show multiple budget line items w...
# 📄 Processing page 60 (60/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show multiple budget line items w...
# 📄 Processing page 61 (61/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show dollar amounts ($100,000.00,...
# 📄 Processing page 62 (62/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 63 (63/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 64 (64/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of entities (Hawaii S...
# 📄 Processing page 65 (65/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with line items incl...
# 📄 Processing page 66 (66/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of entries with line ...
# 📄 Processing page 67 (67/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show multiple budget line...
# 📄 Processing page 68 (68/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of entities (e.g., KO...
# 📄 Processing page 69 (69/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of entities (e.g., Le...
# 📄 Processing page 70 (70/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 71 (71/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions reveal multiple budget line items...
# 📄 Processing page 72 (72/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of entities (PACIFIC ...
# 📄 Processing page 73 (73/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show multiple budget line items w...
# 📄 Processing page 74 (74/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show multiple budget line...
# 📄 Processing page 75 (75/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 76 (76/196)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a dollar amount ($100,000.00...
# 📄 Processing page 77 (77/196)
#    ✅ TEXT (95%) - Neither extraction contains actual budget line ite...
# 📄 Processing page 78 (78/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with progr...
# 📄 Processing page 79 (79/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget item numbers (e.g., A...
# 📄 Processing page 80 (80/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with corr...
# 📄 Processing page 81 (81/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 82 (82/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of projects with asso...
# 📄 Processing page 83 (83/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget item numbers, project...
# 📄 Processing page 84 (84/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 85 (85/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show consistent budget informatio...
# 📄 Processing page 86 (86/196)
#    ✅ TEXT (90%) - Neither extraction contains actual dollar amounts ...
# 📄 Processing page 87 (87/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 88 (88/196)
#    ✅ TEXT (90%) - While the extractions show project names, descript...
# 📄 Processing page 89 (89/196)
#    ✅ TEXT (90%) - While the extractions show project names, descript...
# 📄 Processing page 90 (90/196)
#    ✅ TEXT (95%) - Neither extraction contains actual dollar amounts ...
# 📄 Processing page 91 (91/196)
#    ✅ TEXT (95%) - While the extractions mention budget items and fis...
# 📄 Processing page 92 (92/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 93 (93/196)
#    ✅ TEXT (90%) - While the extractions show project names, descript...
# 📄 Processing page 94 (94/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project names, descriptions,...
# 📄 Processing page 95 (95/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 96 (96/196)
#    ✅ TEXT (90%) - While the extractions show budget-related informat...
# 📄 Processing page 97 (97/196)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a list of projects with asso...
# 📄 Processing page 98 (98/196)
#    ✅ TEXT (95%) - While the extractions show project names, descript...
# 📄 Processing page 99 (99/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project titles, agency names...
# 📄 Processing page 100 (100/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal project IDs (TRN102, TRN11...
# 📄 Processing page 101 (101/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project names, IDs (TRN numb...
# 📄 Processing page 102 (102/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions reveal data consistent with budge...
# 📄 Processing page 103 (103/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 104 (104/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget data.  PDFPlumber pro...
# 📄 Processing page 105 (105/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (TRN301, TRN303)...
# 📄 Processing page 106 (106/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project names, IDs (TRN numb...
# 📄 Processing page 107 (107/196)
#    ✅ TEXT (90%) - While the extractions show project descriptions an...
# 📄 Processing page 108 (108/196)
#    ✅ BUDGET_TABLE (85%) - Both extractions show project names, IDs (TRN numb...
# 📄 Processing page 109 (109/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget-related information. ...
# 📄 Processing page 110 (110/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 111 (111/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget line items with proje...
# 📄 Processing page 112 (112/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 113 (113/196)
#    ✅ BUDGET_TABLE (85%) - Both extractions show project titles, IDs (TRN num...
# 📄 Processing page 114 (114/196)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a table with project IDs (e....
# 📄 Processing page 115 (115/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 116 (116/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a table structure with proje...
# 📄 Processing page 117 (117/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 118 (118/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table structure with proje...
# 📄 Processing page 119 (119/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items (projects ...
# 📄 Processing page 120 (120/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget-like data.  CamelOT p...
# 📄 Processing page 121 (121/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget line items with proje...
# 📄 Processing page 122 (122/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget items with project ti...
# 📄 Processing page 123 (123/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 124 (124/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a budget item (Watershed Pro...
# 📄 Processing page 125 (125/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 126 (126/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal budget line items with dol...
# 📄 Processing page 127 (127/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 128 (128/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show multiple budget line items w...
# 📄 Processing page 129 (129/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with proje...
# 📄 Processing page 130 (130/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with progr...
# 📄 Processing page 131 (131/196)
#    ✅ BUDGET_TABLE (80%) - The PDFPlumber extraction clearly shows budget ite...
# 📄 Processing page 132 (132/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show tables with project titles, ...
# 📄 Processing page 133 (133/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with progr...
# 📄 Processing page 134 (134/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 135 (135/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal budget data.  PDFPlumber p...
# 📄 Processing page 136 (136/196)
#    ✅ BUDGET_TABLE (85%) - Both extractions show budget line items with proje...
# 📄 Processing page 137 (137/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 138 (138/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of projects with asso...
# 📄 Processing page 139 (139/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget-related information. ...
# 📄 Processing page 140 (140/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 141 (141/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 142 (142/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget information.  PDFPlum...
# 📄 Processing page 143 (143/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal budget information.  PDFPl...
# 📄 Processing page 144 (144/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table-like structure with ...
# 📄 Processing page 145 (145/196)
#    ✅ BUDGET_TABLE (70%) - Both extractions show budget item numbers (33 and ...
# 📄 Processing page 146 (146/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 147 (147/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget items with project ti...
# 📄 Processing page 148 (148/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget items with project ti...
# 📄 Processing page 149 (149/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget-related information. ...
# 📄 Processing page 150 (150/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget items with dollar amo...
# 📄 Processing page 151 (151/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 152 (152/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget items with dollar amo...
# 📄 Processing page 153 (153/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project names, IDs (DEF116, ...
# 📄 Processing page 154 (154/196)
#    ✅ BUDGET_TABLE (80%) - The extractions show a table with a clear structur...
# 📄 Processing page 155 (155/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget items with project ti...
# 📄 Processing page 156 (156/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 157 (157/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 158 (158/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget-related information. ...
# 📄 Processing page 159 (159/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 160 (160/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget-related information. ...
# 📄 Processing page 161 (161/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget items with dollar amo...
# 📄 Processing page 162 (162/196)
#    ✅ BUDGET_TABLE (75%) - Both extractions mention a project ('VIDINHA STADI...
# 📄 Processing page 163 (163/196)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with Item No...
# 📄 Processing page 164 (164/196)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget line items with dolla...
# 📄 Processing page 165 (165/196)
#    ✅ TEXT (90%) - While the extractions show dollar amounts ($360, $...
# 📄 Processing page 166 (166/196)
#    ✅ TEXT (95%) - Neither extraction contains any financial data suc...
# 📄 Processing page 167 (167/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 168 (168/196)
#    ✅ TEXT (90%) - While the text mentions a $40,000,000 appropriatio...
# 📄 Processing page 169 (169/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 170 (170/196)
#    ✅ TEXT (95%) - While the text mentions a specific dollar amount (...
# 📄 Processing page 171 (171/196)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal data consistent with budge...
# 📄 Processing page 172 (172/196)
#    ✅ TEXT (95%) - While both extractions mention dollar amounts ($3,...
# 📄 Processing page 173 (173/196)
#    ✅ TEXT (95%) - While both extractions mention specific dollar amo...
# 📄 Processing page 174 (174/196)
#    ✅ TEXT (95%) - Neither extraction contains a table with structure...
# 📄 Processing page 175 (175/196)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 176 (176/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 177 (177/196)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 178 (178/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 179 (179/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 180 (180/196)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 181 (181/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 182 (182/196)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions show an...
# 📄 Processing page 183 (183/196)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 184 (184/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 185 (185/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 186 (186/196)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 187 (187/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 188 (188/196)
#    ✅ TEXT (95%) - Neither extraction contains any numerical budget l...
# 📄 Processing page 189 (189/196)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 190 (190/196)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 191 (191/196)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 192 (192/196)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 193 (193/196)
#    ✅ TEXT (95%) - Neither extraction contains any numerical data rep...
# 📄 Processing page 194 (194/196)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 195 (195/196)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
# 📄 Processing page 196 (196/196)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
#
# 📊 SUMMARY:
#    📄 Total pages: 196
#    ✅ Successfully analyzed: 196
#    📋 Table pages: 0
#    📝 Text pages: 53
#    ❌ Errors: 0
# 🔍 Analyzing 174 pages with Gemini...
# 📄 Processing page 1 (1/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 2 (2/174)
#    ✅ TEXT (95%) - Both extractions show a list of departments but la...
# 📄 Processing page 3 (3/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 4 (4/174)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
# 📄 Processing page 5 (5/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 6 (6/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 7 (7/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 8 (8/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 9 (9/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show multiple budget line...
# 📄 Processing page 10 (10/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 11 (11/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 12 (12/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 13 (13/174)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a table structure with progr...
# 📄 Processing page 14 (14/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 15 (15/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table structure wi...
# 📄 Processing page 16 (16/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table structure wi...
# 📄 Processing page 17 (17/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 18 (18/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 19 (19/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 20 (20/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table structure wi...
# 📄 Processing page 21 (21/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 22 (22/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with clear budget li...
# 📄 Processing page 23 (23/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with clear budget li...
# 📄 Processing page 24 (24/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (HT...
# 📄 Processing page 25 (25/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 26 (26/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain multiple budget line item...
# 📄 Processing page 27 (27/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 28 (28/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 29 (29/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 30 (30/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain numerous budget line item...
# 📄 Processing page 31 (31/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 32 (32/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 33 (33/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain numerous budget line item...
# 📄 Processing page 34 (34/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 35 (35/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 36 (36/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 37 (37/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with Program IDs (e....
# 📄 Processing page 38 (38/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 39 (39/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (PS...
# 📄 Processing page 40 (40/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 41 (41/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (LA...
# 📄 Processing page 42 (42/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 43 (43/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 44 (44/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 45 (45/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with Program IDs (e....
# 📄 Processing page 46 (46/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 47 (47/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 48 (48/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 49 (49/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 50 (50/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (AG...
# 📄 Processing page 51 (51/174)
#    ✅ TEXT (95%) - While the extractions mention dollar amounts ($165...
# 📄 Processing page 52 (52/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 53 (53/174)
#    ✅ TEXT (95%) - Neither extraction contains actual budget line ite...
# 📄 Processing page 54 (54/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 55 (55/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 56 (56/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 57 (57/174)
#    ✅ BUDGET_TABLE (75%) - Both extractions show a table structure with proje...
# 📄 Processing page 58 (58/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 59 (59/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show budget line items wi...
# 📄 Processing page 60 (60/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 61 (61/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with proje...
# 📄 Processing page 62 (62/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show project IDs (TRN131, TRN141)...
# 📄 Processing page 63 (63/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget-related data, includi...
# 📄 Processing page 64 (64/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions contain budget-related informatio...
# 📄 Processing page 65 (65/174)
#    ✅ BUDGET_TABLE (80%) - The extractions show a table with a project ID (It...
# 📄 Processing page 66 (66/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (TRN301, TRN303)...
# 📄 Processing page 67 (67/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (TRN311, TRN331)...
# 📄 Processing page 68 (68/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (TRN341, TRN361)...
# 📄 Processing page 69 (69/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with proj...
# 📄 Processing page 70 (70/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 71 (71/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 72 (72/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 73 (73/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project names, IDs (though n...
# 📄 Processing page 74 (74/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show project IDs (36, 37, TRN561)...
# 📄 Processing page 75 (75/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 76 (76/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a table-like structure with ...
# 📄 Processing page 77 (77/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget data.  PDFPlumber pro...
# 📄 Processing page 78 (78/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items (...
# 📄 Processing page 79 (79/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show multiple tables containing b...
# 📄 Processing page 80 (80/174)
#    ✅ BUDGET_TABLE (60%) - Both extractions show a table structure with Item ...
# 📄 Processing page 81 (81/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 82 (82/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 83 (83/174)
#    ✅ TEXT (95%) - While the extractions contain project descriptions...
# 📄 Processing page 84 (84/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a budget item (Watershed Pro...
# 📄 Processing page 85 (85/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 86 (86/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 87 (87/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 88 (88/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear budget line items with...
# 📄 Processing page 89 (89/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 90 (90/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show clear budget line items with...
# 📄 Processing page 91 (91/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 92 (92/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 93 (93/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 94 (94/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 95 (95/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of projects with asso...
# 📄 Processing page 96 (96/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 97 (97/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of projects with asso...
# 📄 Processing page 98 (98/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 99 (99/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with corr...
# 📄 Processing page 100 (100/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget data.  The Camelot ex...
# 📄 Processing page 101 (101/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 102 (102/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 103 (103/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table-like structure with ...
# 📄 Processing page 104 (104/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 105 (105/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget data.  The PDFPlumber...
# 📄 Processing page 106 (106/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 107 (107/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 108 (108/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of projects with asso...
# 📄 Processing page 109 (109/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of projects with asso...
# 📄 Processing page 110 (110/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 111 (111/174)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a list of projects with asso...
# 📄 Processing page 112 (112/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with project numbers...
# 📄 Processing page 113 (113/174)
#    ✅ BUDGET_TABLE (70%) - Both extractions show a list of projects with asso...
# 📄 Processing page 114 (114/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 115 (115/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget items with IDs (84, 8...
# 📄 Processing page 116 (116/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget information.  The PDF...
# 📄 Processing page 117 (117/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 118 (118/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (e.g., UOH210, U...
# 📄 Processing page 119 (119/174)
#    ✅ BUDGET_TABLE (75%) - Both extractions show project titles, descriptions...
# 📄 Processing page 120 (120/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project titles, agency names...
# 📄 Processing page 121 (121/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (99, 100, 101), ...
# 📄 Processing page 122 (122/174)
#    ✅ TEXT (90%) - While the extractions mention budget amounts (225,...
# 📄 Processing page 123 (123/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project titles, descriptions...
# 📄 Processing page 124 (124/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 125 (125/174)
#    ✅ TEXT (90%) - Neither extraction contains actual dollar amounts ...
# 📄 Processing page 126 (126/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a table-like structure with ...
# 📄 Processing page 127 (127/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with budge...
# 📄 Processing page 128 (128/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with proj...
# 📄 Processing page 129 (129/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget-like data.  PDFPlumbe...
# 📄 Processing page 130 (130/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget-related data.  PDFPlu...
# 📄 Processing page 131 (131/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a table structure with a pro...
# 📄 Processing page 132 (132/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget items with project ti...
# 📄 Processing page 133 (133/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 134 (134/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 135 (135/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget-like data with line i...
# 📄 Processing page 136 (136/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget items with project ti...
# 📄 Processing page 137 (137/174)
#    ✅ BUDGET_TABLE (70%) - Both extractions show a project title,  'JAMES “JI...
# 📄 Processing page 138 (138/174)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project titles, funding amou...
# 📄 Processing page 139 (139/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 140 (140/174)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with Item No...
# 📄 Processing page 141 (141/174)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 142 (142/174)
#    ✅ TEXT (90%) - While the extractions mention dollar amounts ($56,...
# 📄 Processing page 143 (143/174)
#    ✅ TEXT (95%) - Neither extraction contains actual budget line ite...
# 📄 Processing page 144 (144/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 145 (145/174)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 146 (146/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 147 (147/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 148 (148/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 149 (149/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 150 (150/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 151 (151/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 152 (152/174)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 153 (153/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 154 (154/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 155 (155/174)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 156 (156/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 157 (157/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 158 (158/174)
#    ✅ TEXT (95%) - Neither extraction contains any actual budget line...
# 📄 Processing page 159 (159/174)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 160 (160/174)
#    ✅ TEXT (95%) - Neither extraction contains budget line items with...
# 📄 Processing page 161 (161/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 162 (162/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 163 (163/174)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 164 (164/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 165 (165/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 166 (166/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 167 (167/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 168 (168/174)
#    ✅ TEXT (95%) - While the extractions mention dollar amounts ($2,5...
# 📄 Processing page 169 (169/174)
#    ✅ TEXT (90%) - While both extractions mention dollar amounts and ...
# 📄 Processing page 170 (170/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 171 (171/174)
#    ✅ TEXT (95%) - Neither extraction contains any numerical data rep...
# 📄 Processing page 172 (172/174)
#    ✅ TEXT (95%) - While the Camelot extraction shows tabular data, i...
# 📄 Processing page 173 (173/174)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 174 (174/174)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
#
# 📊 SUMMARY:
#    📄 Total pages: 174
#    ✅ Successfully analyzed: 174
#    📋 Table pages: 0
#    📝 Text pages: 44
#    ❌ Errors: 0
# 🔍 Analyzing 154 pages with Gemini...
# 📄 Processing page 1 (1/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 2 (2/154)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 3 (3/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 4 (4/154)
#    ✅ TEXT (95%) - Neither extraction contains any financial data suc...
# 📄 Processing page 5 (5/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 6 (6/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program names (...
# 📄 Processing page 7 (7/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 8 (8/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show multiple budget line...
# 📄 Processing page 9 (9/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show multiple budget line...
# 📄 Processing page 10 (10/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 11 (11/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (LB...
# 📄 Processing page 12 (12/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 13 (13/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (LB...
# 📄 Processing page 14 (14/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 15 (15/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (TR...
# 📄 Processing page 16 (16/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear budget line items with...
# 📄 Processing page 17 (17/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 18 (18/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (TR...
# 📄 Processing page 19 (19/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 20 (20/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a budget table with ...
# 📄 Processing page 21 (21/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 22 (22/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (LN...
# 📄 Processing page 23 (23/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with clear budget li...
# 📄 Processing page 24 (24/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 25 (25/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 26 (26/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 27 (27/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (HT...
# 📄 Processing page 28 (28/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear budget line items.  Th...
# 📄 Processing page 29 (29/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table structure with progr...
# 📄 Processing page 30 (30/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 31 (31/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (HM...
# 📄 Processing page 32 (32/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear budget line items.  Th...
# 📄 Processing page 33 (33/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 34 (34/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program names (...
# 📄 Processing page 35 (35/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 36 (36/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain numerous budget line item...
# 📄 Processing page 37 (37/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table of budget li...
# 📄 Processing page 38 (38/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 39 (39/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 40 (40/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 41 (41/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 42 (42/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear evidence of a budget t...
# 📄 Processing page 43 (43/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a clear table structure with...
# 📄 Processing page 44 (44/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table structured w...
# 📄 Processing page 45 (45/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 46 (46/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with program...
# 📄 Processing page 47 (47/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 48 (48/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 49 (49/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 50 (50/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a table with budget ...
# 📄 Processing page 51 (51/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a clear table structure with...
# 📄 Processing page 52 (52/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions clearly show a budget table with ...
# 📄 Processing page 53 (53/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 54 (54/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 55 (55/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with program IDs (e....
# 📄 Processing page 56 (56/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table with budget line ite...
# 📄 Processing page 57 (57/154)
#    ✅ TEXT (95%) - Neither extraction contains actual budget line ite...
# 📄 Processing page 58 (58/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with progr...
# 📄 Processing page 59 (59/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show multiple budget line items w...
# 📄 Processing page 60 (60/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear budget line items with...
# 📄 Processing page 61 (61/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 62 (62/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 63 (63/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 64 (64/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal budget line items.  PDFPlu...
# 📄 Processing page 65 (65/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show multiple budget line items w...
# 📄 Processing page 66 (66/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 67 (67/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table with budget line ite...
# 📄 Processing page 68 (68/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget data.  PDFPlumber's e...
# 📄 Processing page 69 (69/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal tables with project IDs (T...
# 📄 Processing page 70 (70/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal budget information.  PDFPl...
# 📄 Processing page 71 (71/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget data, including dolla...
# 📄 Processing page 72 (72/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show multiple budget line items w...
# 📄 Processing page 73 (73/154)
#    ✅ TEXT (90%) - While both extractions mention dollar amounts (e.g...
# 📄 Processing page 74 (74/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects (TRN331, ...
# 📄 Processing page 75 (75/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (TRN361, TRN351)...
# 📄 Processing page 76 (76/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions reveal budget data.  PDFPlumber p...
# 📄 Processing page 77 (77/154)
#    ✅ BUDGET_TABLE (85%) - Both extractions show budget-related information. ...
# 📄 Processing page 78 (78/154)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a list of projects with asso...
# 📄 Processing page 79 (79/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show project names, IDs (implicit...
# 📄 Processing page 80 (80/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project IDs (30, 31), projec...
# 📄 Processing page 81 (81/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items (32 and 33...
# 📄 Processing page 82 (82/154)
#    ✅ TEXT (90%) - While the extractions show project descriptions, t...
# 📄 Processing page 83 (83/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show clear budget data:  project ...
# 📄 Processing page 84 (84/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 85 (85/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 86 (86/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a table with project titles,...
# 📄 Processing page 87 (87/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table structure with line ...
# 📄 Processing page 88 (88/154)
#    ✅ BUDGET_TABLE (85%) - Both extractions show project names (e.g., 'ANUENU...
# 📄 Processing page 89 (89/154)
#    ✅ TEXT (95%) - While both extractions mention funding amounts ('L...
# 📄 Processing page 90 (90/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 91 (91/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a budget item, 'WATERSHED PR...
# 📄 Processing page 92 (92/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 93 (93/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with corr...
# 📄 Processing page 94 (94/154)
#    ✅ BUDGET_TABLE (75%) - Both extractions show budget-related information, ...
# 📄 Processing page 95 (95/154)
#    ✅ BUDGET_TABLE (85%) - Both extractions show project names, agency (AGS),...
# 📄 Processing page 96 (96/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions contain budget line items with do...
# 📄 Processing page 97 (97/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 98 (98/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project names, funding total...
# 📄 Processing page 99 (99/154)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a table with a project ID (H...
# 📄 Processing page 100 (100/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 101 (101/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show project names, descriptions,...
# 📄 Processing page 102 (102/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with project names, ...
# 📄 Processing page 103 (103/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 104 (104/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show budget line items with assoc...
# 📄 Processing page 105 (105/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table-like structure with ...
# 📄 Processing page 106 (106/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table-like structure with ...
# 📄 Processing page 107 (107/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 108 (108/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with project titles,...
# 📄 Processing page 109 (109/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a list of projects with asso...
# 📄 Processing page 110 (110/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions contain project names (e.g., "HAW...
# 📄 Processing page 111 (111/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with budget line ite...
# 📄 Processing page 112 (112/154)
#    ✅ TEXT (90%) - While the extractions contain project descriptions...
# 📄 Processing page 113 (113/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show multiple budget line items w...
# 📄 Processing page 114 (114/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a project description consis...
# 📄 Processing page 115 (115/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show project titles, agency IDs (...
# 📄 Processing page 116 (116/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show project titles, IDs (LNR num...
# 📄 Processing page 117 (117/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 118 (118/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table with budget line ite...
# 📄 Processing page 119 (119/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table with project titles,...
# 📄 Processing page 120 (120/154)
#    ✅ BUDGET_TABLE (85%) - Both extractions show a table structure with a dep...
# 📄 Processing page 121 (121/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a table structure with proje...
# 📄 Processing page 122 (122/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a table-like structure with ...
# 📄 Processing page 123 (123/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 124 (124/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of projects with asso...
# 📄 Processing page 125 (125/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 126 (126/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 127 (127/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with proje...
# 📄 Processing page 128 (128/154)
#    ✅ BUDGET_TABLE (80%) - Both extractions show a list of projects with asso...
# 📄 Processing page 129 (129/154)
#    ✅ BUDGET_TABLE (85%) - Both extractions show budget line items with proje...
# 📄 Processing page 130 (130/154)
#    ✅ TEXT (90%) - While the extractions show project descriptions an...
# 📄 Processing page 131 (131/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show budget line items with dolla...
# 📄 Processing page 132 (132/154)
#    ✅ TEXT (95%) - While the extractions mention project names, descr...
# 📄 Processing page 133 (133/154)
#    ✅ BUDGET_TABLE (95%) - Both extractions show a table with 'Item No.', dol...
# 📄 Processing page 134 (134/154)
#    ✅ BUDGET_TABLE (90%) - Both extractions show a list of program IDs (G-64,...
# 📄 Processing page 135 (135/154)
#    ✅ TEXT (95%) - While the extractions mention dollar amounts ($5,0...
# 📄 Processing page 136 (136/154)
#    ✅ TEXT (95%) - While the text mentions dollar amounts ($55,000,00...
# 📄 Processing page 137 (137/154)
#    ✅ TEXT (90%) - While the extractions contain dollar amounts and f...
# 📄 Processing page 138 (138/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 139 (139/154)
#    ✅ TEXT (95%) - Neither extraction contains budget line items such...
# 📄 Processing page 140 (140/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 141 (141/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 142 (142/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 143 (143/154)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 144 (144/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 145 (145/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 146 (146/154)
#    ✅ TEXT (95%) - Neither extraction shows budget line items with do...
# 📄 Processing page 147 (147/154)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
# 📄 Processing page 148 (148/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 149 (149/154)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
# 📄 Processing page 150 (150/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items ...
# 📄 Processing page 151 (151/154)
#    ✅ TEXT (95%) - Neither extraction contains any budget line items,...
# 📄 Processing page 152 (152/154)
#    ✅ TEXT (95%) - Neither Camelot nor PDFPlumber extractions contain...
# 📄 Processing page 153 (153/154)
#    ✅ TEXT (95%) - Neither extraction shows any budget-related elemen...
# 📄 Processing page 154 (154/154)
#    ✅ TEXT (95%) - Neither extraction shows any budget line items wit...
#
# 📊 SUMMARY:
#    📄 Total pages: 154
#    ✅ Successfully analyzed: 154
#    📋 Table pages: 0
#    📝 Text pages: 32
#    ❌ Errors: 0

# %% [markdown]
# # Evaluate Model
# Ouputs are stored in /model_outputs/model2_performance

# %%
import pandas as pd
import json
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
import numpy as np

def evaluate_classification_performance(labels_csv_path, predictions_json_path):
    """
    Evaluate the Gemini model's page classification performance against ground truth labels
    
    Args:
        labels_csv_path (str): Path to the CSV file with ground truth labels
        predictions_json_path (str): Path to the JSON file with model predictions
        
    Returns:
        dict: Evaluation metrics and detailed results
    """
    
    # Load ground truth labels
    print("📊 Loading ground truth labels...")
    labels_df = pd.read_csv(labels_csv_path)
    
    # Load model predictions
    print("🤖 Loading model predictions...")
    with open(predictions_json_path, 'r') as f:
        predictions = json.load(f)
    
    # Create mapping: 0=budget_table, 1=text
    label_mapping = {0: 'budget_table', 1: 'text'}
    print("📝 Using mapping: 0=budget_table, 1=text")
    
    # Prepare data for comparison
    ground_truth = []
    predicted = []
    page_numbers = []
    confidences = []
    reasons = []
    
    print("🔍 Matching predictions with ground truth...")
    
    # Create a lookup dict for predictions by page number
    pred_dict = {pred['page_number']: pred for pred in predictions if pred['status'] == 'success'}
    
    for _, row in labels_df.iterrows():
        page_num = int(row.iloc[0])  # First column is page number
        true_label_code = int(row.iloc[1])  # Second column is label
        
        if true_label_code in label_mapping:
            true_label = label_mapping[true_label_code]
            
            if page_num in pred_dict:
                pred = pred_dict[page_num]
                
                ground_truth.append(true_label)
                predicted.append(pred['classification'])
                page_numbers.append(page_num)
                confidences.append(pred['confidence'])
                reasons.append(pred['reason'])
            else:
                print(f"⚠️  No prediction found for page {page_num}")
        else:
            print(f"⚠️  Unknown label code {true_label_code} for page {page_num}")
    
    if len(ground_truth) == 0:
        print("❌ No valid data to evaluate!")
        return None
    
    # Calculate metrics
    accuracy = accuracy_score(ground_truth, predicted)
    precision, recall, f1, support = precision_recall_fscore_support(
        ground_truth, predicted, average=None, labels=['text', 'budget_table']
    )
    
    # Overall metrics
    overall_precision, overall_recall, overall_f1, _ = precision_recall_fscore_support(
        ground_truth, predicted, average='weighted'
    )
    
    # Confusion matrix
    cm = confusion_matrix(ground_truth, predicted, labels=['text', 'budget_table'])
    
    # Detailed analysis
    results_df = pd.DataFrame({
        'page_number': page_numbers,
        'ground_truth': ground_truth,
        'predicted': predicted,
        'correct': [gt == pred for gt, pred in zip(ground_truth, predicted)],
        'confidence': confidences,
        'reason': reasons
    })
    
    # Find errors
    errors = results_df[results_df['correct'] == False].copy()
    
    # Calculate confidence statistics
    correct_predictions = results_df[results_df['correct'] == True]
    incorrect_predictions = results_df[results_df['correct'] == False]
    
    # Print results
    print("\n" + "="*60)
    print("📈 CLASSIFICATION EVALUATION RESULTS")
    print("="*60)
    
    print(f"\n🎯 OVERALL PERFORMANCE:")
    print(f"   Accuracy: {accuracy:.3f} ({accuracy*100:.1f}%)")
    print(f"   Precision (weighted): {overall_precision:.3f}")
    print(f"   Recall (weighted): {overall_recall:.3f}")
    print(f"   F1-Score (weighted): {overall_f1:.3f}")
    
    print(f"\n📊 PER-CLASS METRICS:")
    for i, label in enumerate(['text', 'budget_table']):
        if i < len(precision):
            print(f"   {label.upper()}:")
            print(f"      Precision: {precision[i]:.3f}")
            print(f"      Recall: {recall[i]:.3f}")
            print(f"      F1-Score: {f1[i]:.3f}")
            print(f"      Support: {support[i]} samples")
    
    print(f"\n🔢 CONFUSION MATRIX:")
    print("                 Predicted")
    print("                text  budget_table")
    print(f"Actual   text     {cm[0,0]:4d}     {cm[0,1]:4d}")
    print(f"    budget_table  {cm[1,0]:4d}     {cm[1,1]:4d}")
    
    print(f"\n📊 CONFIDENCE ANALYSIS:")
    if len(correct_predictions) > 0:
        print(f"   Correct predictions - Avg confidence: {correct_predictions['confidence'].mean():.1f}%")
    if len(incorrect_predictions) > 0:
        print(f"   Incorrect predictions - Avg confidence: {incorrect_predictions['confidence'].mean():.1f}%")
    
    if len(errors) > 0:
        print(f"\n❌ ERRORS ({len(errors)} total):")
        for _, error in errors.iterrows():
            print(f"   Page {error['page_number']}: {error['ground_truth']} → {error['predicted']} ({error['confidence']}%)")
            print(f"      Reason: {error['reason'][:80]}...")
    else:
        print(f"\n✅ PERFECT CLASSIFICATION - No errors!")
    
    # Return detailed results
    return {
        'accuracy': accuracy,
        'precision_per_class': precision,
        'recall_per_class': recall,
        'f1_per_class': f1,
        'support_per_class': support,
        'overall_precision': overall_precision,
        'overall_recall': overall_recall,
        'overall_f1': overall_f1,
        'confusion_matrix': cm,
        'results_dataframe': results_df,
        'errors': errors,
        'total_samples': len(ground_truth),
        'correct_count': sum(results_df['correct']),
        'error_count': len(errors)
    }

documents = [{"label_path": "labels/HB300_CD1_labels - Sheet1.csv", "json_path": "page_classifications_0.json"},
             {"label_path": "labels/HB300_HD1_labels - Sheet1.csv", "json_path": "page_classifications_1.json"},
             {"label_path": "labels/HB300_SD1_labels - Sheet1.csv", "json_path": "page_classifications_2.json"},
             {"label_path": "labels/HB300_labels - Sheet1.csv", "json_path": "page_classifications.json"},]

for document in documents:
    results = evaluate_classification_performance(
        document["label_path"],
        document["json_path"]
    )
# Out:
# 📊 Loading ground truth labels...
# 🤖 Loading model predictions...
# 📝 Using mapping: 0=budget_table, 1=text
# 🔍 Matching predictions with ground truth...
#
# ============================================================
# 📈 CLASSIFICATION EVALUATION RESULTS
# ============================================================
#
# 🎯 OVERALL PERFORMANCE:
#    Accuracy: 0.842 (84.2%)
#    Precision (weighted): 0.841
#    Recall (weighted): 0.842
#    F1-Score (weighted): 0.837
#
# 📊 PER-CLASS METRICS:
#    TEXT:
#       Precision: 0.830
#       Recall: 0.667
#       F1-Score: 0.739
#       Support: 66 samples
#    BUDGET_TABLE:
#       Precision: 0.846
#       Recall: 0.931
#       F1-Score: 0.886
#       Support: 130 samples
#
# 🔢 CONFUSION MATRIX:
#                  Predicted
#                 text  budget_table
# Actual   text       44       22
#     budget_table     9      121
#
# 📊 CONFIDENCE ANALYSIS:
#    Correct predictions - Avg confidence: 90.7%
#    Incorrect predictions - Avg confidence: 91.6%
#
# ❌ ERRORS (31 total):
#    Page 58: text → budget_table (95%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($225,000.0...
#    Page 59: text → budget_table (90%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($75,000.00...
#    Page 60: text → budget_table (90%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($100,000.0...
#    Page 61: text → budget_table (80%)
#       Reason: Both extractions show dollar amounts ($100,000.00, $200,000.00, $20,000.00) asso...
#    Page 62: text → budget_table (95%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($300,000.0...
#    Page 63: text → budget_table (95%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($350,000.0...
#    Page 64: text → budget_table (95%)
#       Reason: Both extractions show a list of entities (Hawaii Symphony Orchestra, Hawaii Tax ...
#    Page 65: text → budget_table (95%)
#       Reason: Both extractions show a table with line items including dollar amounts ($20,000....
#    Page 66: text → budget_table (90%)
#       Reason: Both extractions show a list of entries with line numbers (33, 34, 35, 36...), d...
#    Page 67: text → budget_table (95%)
#       Reason: Both extractions clearly show multiple budget line items with dollar amounts ($2...
#    Page 68: text → budget_table (95%)
#       Reason: Both extractions show a list of entities (e.g., KOOLAULOA HEALTH CENTER, KUALOA-...
#    Page 69: text → budget_table (90%)
#       Reason: Both extractions show a list of entities (e.g., Legal Clinic, Leilehua Alumni As...
#    Page 70: text → budget_table (95%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($375,000.0...
#    Page 71: text → budget_table (95%)
#       Reason: Both extractions reveal multiple budget line items.  They include dollar amounts...
#    Page 72: text → budget_table (90%)
#       Reason: Both extractions show a list of entities (PACIFIC TSUNAMI MUSEUM, INC., PARENTS ...
#    Page 73: text → budget_table (90%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($300,000.0...
#    Page 74: text → budget_table (95%)
#       Reason: Both extractions clearly show multiple budget line items with dollar amounts ($2...
#    Page 75: text → budget_table (95%)
#       Reason: Both extractions show multiple budget line items with dollar amounts ($75,000.00...
#    Page 76: text → budget_table (85%)
#       Reason: Both extractions show a dollar amount ($100,000.00) associated with a specific p...
#    Page 86: budget_table → text (90%)
#       Reason: Neither extraction contains actual dollar amounts or financial appropriations da...
#    Page 88: budget_table → text (90%)
#       Reason: While the extractions show project names, descriptions, and agency names, they l...
#    Page 89: budget_table → text (90%)
#       Reason: While the extractions show project names, descriptions, and what seems to be fun...
#    Page 90: budget_table → text (95%)
#       Reason: Neither extraction contains actual dollar amounts or appropriations.  While the ...
#    Page 91: budget_table → text (95%)
#       Reason: While the extractions mention budget items and fiscal years (2025-2026, 2026-202...
#    Page 93: budget_table → text (90%)
#       Reason: While the extractions show project names, descriptions, and funding sources (LBR...
#    Page 96: budget_table → text (90%)
#       Reason: While the extractions show budget-related information such as project titles, de...
#    Page 98: budget_table → text (95%)
#       Reason: While the extractions show project names, descriptions, and project IDs (numbers...
#    Page 107: budget_table → text (90%)
#       Reason: While the extractions show project descriptions and project IDs (TRN numbers),  ...
#    Page 163: text → budget_table (95%)
#       Reason: Both extractions clearly show a table with Item Nos. (program IDs), dollar amoun...
#    Page 164: text → budget_table (80%)
#       Reason: Both extractions show budget line items with dollar amounts (45,000 and 5,000). ...
#    Page 171: text → budget_table (90%)
#       Reason: Both extractions reveal data consistent with budget line items.  Specifically, t...
# 📊 Loading ground truth labels...
# 🤖 Loading model predictions...
# 📝 Using mapping: 0=budget_table, 1=text
# 🔍 Matching predictions with ground truth...
#
# ============================================================
# 📈 CLASSIFICATION EVALUATION RESULTS
# ============================================================
#
# 🎯 OVERALL PERFORMANCE:
#    Accuracy: 0.971 (97.1%)
#    Precision (weighted): 0.972
#    Recall (weighted): 0.971
#    F1-Score (weighted): 0.971
#
# 📊 PER-CLASS METRICS:
#    TEXT:
#       Precision: 0.932
#       Recall: 0.953
#       F1-Score: 0.943
#       Support: 43 samples
#    BUDGET_TABLE:
#       Precision: 0.985
#       Recall: 0.977
#       F1-Score: 0.981
#       Support: 131 samples
#
# 🔢 CONFUSION MATRIX:
#                  Predicted
#                 text  budget_table
# Actual   text       41        2
#     budget_table     3      128
#
# 📊 CONFIDENCE ANALYSIS:
#    Correct predictions - Avg confidence: 90.7%
#    Incorrect predictions - Avg confidence: 92.0%
#
# ❌ ERRORS (5 total):
#    Page 83: budget_table → text (95%)
#       Reason: While the extractions contain project descriptions and project IDs (LNR numbers)...
#    Page 122: budget_table → text (90%)
#       Reason: While the extractions mention budget amounts (225, 1, 1300),  they lack the stru...
#    Page 125: budget_table → text (90%)
#       Reason: Neither extraction contains actual dollar amounts or financial appropriations da...
#    Page 140: text → budget_table (95%)
#       Reason: Both extractions clearly show a table with Item Nos., dollar amounts ('Amount (M...
#    Page 141: text → budget_table (90%)
#       Reason: Both extractions show budget line items with dollar amounts (45,000 and 2,000, a...
# 📊 Loading ground truth labels...
# 🤖 Loading model predictions...
# 📝 Using mapping: 0=budget_table, 1=text
# 🔍 Matching predictions with ground truth...
#
# ============================================================
# 📈 CLASSIFICATION EVALUATION RESULTS
# ============================================================
#
# 🎯 OVERALL PERFORMANCE:
#    Accuracy: 0.948 (94.8%)
#    Precision (weighted): 0.952
#    Recall (weighted): 0.948
#    F1-Score (weighted): 0.949
#
# 📊 PER-CLASS METRICS:
#    TEXT:
#       Precision: 0.812
#       Recall: 0.929
#       F1-Score: 0.867
#       Support: 28 samples
#    BUDGET_TABLE:
#       Precision: 0.984
#       Recall: 0.952
#       F1-Score: 0.968
#       Support: 126 samples
#
# 🔢 CONFUSION MATRIX:
#                  Predicted
#                 text  budget_table
# Actual   text       26        2
#     budget_table     6      120
#
# 📊 CONFIDENCE ANALYSIS:
#    Correct predictions - Avg confidence: 91.7%
#    Incorrect predictions - Avg confidence: 91.9%
#
# ❌ ERRORS (8 total):
#    Page 73: budget_table → text (90%)
#       Reason: While both extractions mention dollar amounts (e.g., 34,992 B, 44,992B),  they l...
#    Page 82: budget_table → text (90%)
#       Reason: While the extractions show project descriptions, titles, and some numerical valu...
#    Page 89: budget_table → text (95%)
#       Reason: While both extractions mention funding amounts ('LNR 2,000C', 'LNR 3,000C', '8,7...
#    Page 112: budget_table → text (90%)
#       Reason: While the extractions contain project descriptions, project IDs (e.g., UOH210), ...
#    Page 130: budget_table → text (90%)
#       Reason: While the extractions show project descriptions and total funding amounts ('2,00...
#    Page 132: budget_table → text (95%)
#       Reason: While the extractions mention project names, descriptions, and some funding amou...
#    Page 133: text → budget_table (95%)
#       Reason: Both extractions show a table with 'Item No.', dollar amounts ('Amount (MOF)'), ...
#    Page 134: text → budget_table (90%)
#       Reason: Both extractions show a list of program IDs (G-64, G-70.1, etc.) with correspond...
# 📊 Loading ground truth labels...
# 🤖 Loading model predictions...
# 📝 Using mapping: 0=budget_table, 1=text
# 🔍 Matching predictions with ground truth...
#
# ============================================================
# 📈 CLASSIFICATION EVALUATION RESULTS
# ============================================================
#
# 🎯 OVERALL PERFORMANCE:
#    Accuracy: 0.981 (98.1%)
#    Precision (weighted): 0.980
#    Recall (weighted): 0.981
#    F1-Score (weighted): 0.980
#
# 📊 PER-CLASS METRICS:
#    TEXT:
#       Precision: 0.973
#       Recall: 0.947
#       F1-Score: 0.960
#       Support: 38 samples
#    BUDGET_TABLE:
#       Precision: 0.983
#       Recall: 0.991
#       F1-Score: 0.987
#       Support: 116 samples
#
# 🔢 CONFUSION MATRIX:
#                  Predicted
#                 text  budget_table
# Actual   text       36        2
#     budget_table     1      115
#
# 📊 CONFIDENCE ANALYSIS:
#    Correct predictions - Avg confidence: 92.2%
#    Incorrect predictions - Avg confidence: 91.7%
#
# ❌ ERRORS (3 total):
#    Page 83: budget_table → text (90%)
#       Reason: While the PDF contains references to appropriations and fiscal years, and mentio...
#    Page 126: text → budget_table (95%)
#       Reason: Both extractions reveal a table with 'Item No.' and corresponding dollar amounts...
#    Page 146: text → budget_table (90%)
#       Reason: Both extractions show clear budget appropriations.  The Camelot extraction prese...

# %% [markdown]
# # More preprocessing -- expand abbreviations for peroperty values
# uses ./abbreviations.json as the translation table

# %%
import json
import re
from typing import Dict, List, Any

def expand_budget_items_abbreviations(processed_data: Dict[str, Any], abbreviations_path: str = './abbreviations.json') -> Dict[str, Any]:
    """
    Expand abbreviations in all budget items in processed data.
    
    Args:
        processed_data: Processed data dictionary containing budget_items
        abbreviations_path: Path to abbreviations.json file
        
    Returns:
        Processed data with expanded abbreviations added as new properties
    """
    # Load abbreviations
    with open(abbreviations_path, 'r') as f:
        abbreviations = json.load(f)
    
    agency_codes = abbreviations.get('agency_codes', {})
    mof_codes = abbreviations.get('mof_codes', {})
    
    # Create a copy of the data
    expanded_data = processed_data.copy()
    
    # Expand budget items
    if 'budget_items' in expanded_data:
        for item in expanded_data['budget_items']:
            # Expand program_id
            program_id = item.get('program_id', '')
            if program_id and program_id != "unknown":
                # Extract the agency code (letters at the beginning)
                match = re.match(r'^([A-Z]+)', program_id.upper())
                if match:
                    agency_code = match.group(1)
                    if agency_code in agency_codes:
                        # Replace the agency code with the full name
                        item['program_id_expanded'] = program_id.replace(agency_code, agency_codes[agency_code], 1)
                    else:
                        item['program_id_expanded'] = program_id
                else:
                    item['program_id_expanded'] = program_id
            else:
                item['program_id_expanded'] = program_id
            
            # Expand MOF codes for 2025-2026
            mof_2025_2026 = item.get('appropriations_mof_2025_2026', '')
            if mof_2025_2026 and mof_2025_2026 != "unknown":
                mof_code_upper = mof_2025_2026.upper().strip()
                item['appropriations_mof_2025_2026_expanded'] = mof_codes.get(mof_code_upper, mof_2025_2026)
            else:
                item['appropriations_mof_2025_2026_expanded'] = mof_2025_2026
            
            # Expand MOF codes for 2026-2027
            mof_2026_2027 = item.get('appropriations_mof_2026_2027', '')
            if mof_2026_2027 and mof_2026_2027 != "unknown":
                mof_code_upper = mof_2026_2027.upper().strip()
                item['appropriations_mof_2026_2027_expanded'] = mof_codes.get(mof_code_upper, mof_2026_2027)
            else:
                item['appropriations_mof_2026_2027_expanded'] = mof_2026_2027
    
    # Update metadata to indicate expansion was performed
    if 'metadata' in expanded_data:
        expanded_data['metadata']['abbreviations_expanded'] = True
    
    return expanded_data

# %%
document = "./model_ouputs/processed_documents/processed_all_documents_gemini.json"
final_data = {}

# Load your processed data
with open(document, 'r') as f:
    data = json.load(f)

for key in data.keys():
    expanded_data = expand_budget_items_abbreviations(data[key])
    final_data[key] = expanded_data

# Save back to file
with open('./model_ouputs/processed_documents/processed_all_documents_gemini_expanded.json', 'w') as f:
    json.dump(final_data, f, indent=2)  # ✅ Save the complete final_data

# %% [markdown]
# # New ChromaDB with collections that support budget items & text items

# %%
import chromadb

def setup_budget_chromadb(budget_collection_name="budget_items", text_collection_name="text_items", reset=True):
    """Set up a ChromaDB client and two collections for budget data"""
    
    # Create persistent client (newer API)
    client = chromadb.PersistentClient(path="./test_chroma_db")
    
    # Reset collections if they exist
    if reset:
        try:
            client.delete_collection(budget_collection_name)
            print(f"Deleted existing {budget_collection_name} collection")
        except:
            pass
        try:
            client.delete_collection(text_collection_name)
            print(f"Deleted existing {text_collection_name} collection")
        except:
            pass
    
    # Create budget items collection
    budget_collection = client.create_collection(
        name=budget_collection_name,
        metadata={"description": "Structured budget line items", "hnsw:space": "cosine"}
    )
    
    # Create text items collection
    text_collection = client.create_collection(
        name=text_collection_name,
        metadata={"description": "Text content from budget document pages", "hnsw:space": "cosine"}
    )
    
    print(f"Created collections: {budget_collection.name} and {text_collection.name}")
    
    return client, budget_collection, text_collection

# Usage:
client, budget_collection, text_collection = setup_budget_chromadb()
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Deleted existing budget_items collection
# Deleted existing text_items collection
# Created collections: budget_items and text_items

# %%
from sentence_transformers import SentenceTransformer

print("🤖 Loading sentence transformer model...")
model = SentenceTransformer('all-MiniLM-L6-v2')
print("✅ Model loaded successfully")
# Out:
# 🤖 Loading sentence transformer model...
# ✅ Model loaded successfully

# %%
def ingest_processed_budget_data(json_file_path, budget_collection, text_collection, model):
    """
    Ingest processed budget data into two separate ChromaDB collections:
    - budget_collection: For structured budget items
    - text_collection: For text items from each page
    """
    
    print(f"🔍 Loading JSON file: {json_file_path}")
    
    # Load the JSON file
    with open(json_file_path, 'r') as f:
        data = json.load(f)
    
    # Get items from the JSON
    budget_items = data.get('budget_items', [])
    text_items = data.get('text_items', [])
    document_name = data.get('metadata', {}).get('document_name', 'Unknown')
    
    print(f"✅ Found {len(budget_items)} budget items and {len(text_items)} text items in {json_file_path}")
    
    # Process Budget Items
    if budget_items:
        print("📋 Processing budget items...")
        budget_documents = []
        budget_metadatas = []
        budget_ids = []
        
        for i, item in enumerate(budget_items):
            # Show progress every 50 items
            if i % 50 == 0:
                print(f"  📊 Processing budget item {i+1}/{len(budget_items)}")
            
            # Create document text with key budget information
            doc_parts = []
            
            if item.get('program'):
                doc_parts.append(f"Program: {item.get('program')}")
            
            if item.get('expending_agency'):
                doc_parts.append(f"Expending Agency: {item.get('expending_agency')}")
            
            if item.get('fiscal_year_2025_2026_amount') and item.get('fiscal_year_2025_2026_amount') != 'unknown':
                doc_parts.append(f"FY 2025-2026 Amount: ${item.get('fiscal_year_2025_2026_amount')}")
            
            if item.get('fiscal_year_2026_2027_amount') and item.get('fiscal_year_2026_2027_amount') != 'unknown':
                doc_parts.append(f"FY 2026-2027 Amount: ${item.get('fiscal_year_2026_2027_amount')}")
            
            if item.get('program_id_expanded'):
                doc_parts.append(f"Program ID: {item.get('program_id_expanded')}")
            
            if item.get('appropriations_mof_2025_2026_expanded'):
                doc_parts.append(f"2025-2026 Funding Source: {item.get('appropriations_mof_2025_2026_expanded')}")
            
            if item.get('appropriations_mof_2026_2027_expanded'):
                doc_parts.append(f"2026-2027 Funding Source: {item.get('appropriations_mof_2026_2027_expanded')}")
            
            doc_text = " | ".join(doc_parts)
            budget_documents.append(doc_text)
            
            # Create metadata
            metadata = {
                'document_name': item.get('document_name', document_name),
                'page_number': item.get('page_number', 0),
                'item_number': item.get('item_number', 'unknown'),
                'program': item.get('program', 'unknown'),
                'program_id': item.get('program_id', 'unknown'),
                'program_id_expanded': item.get('program_id_expanded', 'unknown'),
                'expending_agency': item.get('expending_agency', 'unknown'),
                'fiscal_year_2025_2026_amount': item.get('fiscal_year_2025_2026_amount', 'unknown'),
                'appropriations_mof_2025_2026': item.get('appropriations_mof_2025_2026', 'unknown'),
                'appropriations_mof_2025_2026_expanded': item.get('appropriations_mof_2025_2026_expanded', 'unknown'),
                'fiscal_year_2026_2027_amount': item.get('fiscal_year_2026_2027_amount', 'unknown'),
                'appropriations_mof_2026_2027': item.get('appropriations_mof_2026_2027', 'unknown'),
                'appropriations_mof_2026_2027_expanded': item.get('appropriations_mof_2026_2027_expanded', 'unknown'),
                'extraction_method': item.get('extraction_method', 'unknown'),
                'classification_prediction': item.get('classification_prediction', 'unknown'),
                'chunk_type': 'budget_item'
            }
            
            budget_metadatas.append(metadata)
            budget_ids.append(f"{document_name}_budget_item_{item.get('page_number', 0)}_{i}")
        
        # Generate embeddings for budget items
        print(f"🧠 Generating embeddings for {len(budget_documents)} budget items...")
        budget_embeddings = model.encode(budget_documents, show_progress_bar=True).tolist()
        
        # Add to budget collection
        print("💾 Adding budget items to ChromaDB...")
        initial_budget_count = budget_collection.count()
        
        budget_collection.add(
            documents=budget_documents,
            metadatas=budget_metadatas,
            embeddings=budget_embeddings,
            ids=budget_ids
        )
        
        final_budget_count = budget_collection.count()
        print(f"✅ Added {final_budget_count - initial_budget_count} budget items to budget collection")
    
    # Process Text Items
    if text_items:
        print("📄 Processing text items...")
        text_documents = []
        text_metadatas = []
        text_ids = []
        
        for i, item in enumerate(text_items):
            # Show progress every 50 items
            if i % 50 == 0:
                print(f"  📊 Processing text item {i+1}/{len(text_items)}")
            
            # Use the text content directly
            text_content = item.get('text', '')
            if text_content and text_content != 'unknown':
                text_documents.append(text_content)
                
                # Create metadata
                metadata = {
                    'document_name': item.get('document_name', document_name),
                    'page_number': item.get('page_number', 0),
                    'extraction_method': item.get('extraction_method', 'unknown'),
                    'classification_prediction': item.get('classification_prediction', 'unknown'),
                    'classification_confidence': item.get('classification_confidence', 'unknown'),
                    'chunk_type': 'text_item'
                }
                
                text_metadatas.append(metadata)
                text_ids.append(f"{document_name}_text_item_{item.get('page_number', 0)}")
        
        if text_documents:
            # Generate embeddings for text items
            print(f"🧠 Generating embeddings for {len(text_documents)} text items...")
            text_embeddings = model.encode(text_documents, show_progress_bar=True).tolist()
            
            # Add to text collection
            print("💾 Adding text items to ChromaDB...")
            initial_text_count = text_collection.count()
            
            text_collection.add(
                documents=text_documents,
                metadatas=text_metadatas,
                embeddings=text_embeddings,
                ids=text_ids
            )
            
            final_text_count = text_collection.count()
            print(f"✅ Added {final_text_count - initial_text_count} text items to text collection")
    
    print(f"\n🎉 Successfully processed {json_file_path}!")
    print(f"  Budget items: {len(budget_items)} processed")
    print(f"  Text items: {len(text_items)} processed")
    
    return len(budget_items), len(text_items)

# Process a single file
budget_count, text_count = ingest_processed_budget_data(
    "./model_ouputs/processed_documents/processed_all_documents_gemini_expanded.json",
    budget_collection,
    text_collection,
    model
)
# Out:
# 🔍 Loading JSON file: ./model_ouputs/processed_documents/processed_all_documents_gemini_expanded.json
# ✅ Found 946 budget items and 154 text items in ./model_ouputs/processed_documents/processed_all_documents_gemini_expanded.json
# 📋 Processing budget items...
#   📊 Processing budget item 1/946
#   📊 Processing budget item 51/946
#   📊 Processing budget item 101/946
#   📊 Processing budget item 151/946
#   📊 Processing budget item 201/946
#   📊 Processing budget item 251/946
#   📊 Processing budget item 301/946
#   📊 Processing budget item 351/946
#   📊 Processing budget item 401/946
#   📊 Processing budget item 451/946
#   📊 Processing budget item 501/946
#   📊 Processing budget item 551/946
#   📊 Processing budget item 601/946
#   📊 Processing budget item 651/946
#   📊 Processing budget item 701/946
#   📊 Processing budget item 751/946
#   📊 Processing budget item 801/946
#   📊 Processing budget item 851/946
#   📊 Processing budget item 901/946
# 🧠 Generating embeddings for 946 budget items...
# Batches: 100%|██████████| 30/30 [00:23<00:00,  1.28it/s]
# Failed to send telemetry event CollectionAddEvent: capture() takes 1 positional argument but 3 were given
# 💾 Adding budget items to ChromaDB...
# ✅ Added 946 budget items to budget collection
# 📄 Processing text items...
#   📊 Processing text item 1/154
#   📊 Processing text item 51/154
#   📊 Processing text item 101/154
#   📊 Processing text item 151/154
# 🧠 Generating embeddings for 154 text items...
# Batches: 100%|██████████| 5/5 [00:02<00:00,  1.74it/s]
# Failed to send telemetry event CollectionAddEvent: capture() takes 1 positional argument but 3 were given
# 💾 Adding text items to ChromaDB...
# ✅ Added 154 text items to text collection
#
# 🎉 Successfully processed ./model_ouputs/processed_documents/processed_all_documents_gemini_expanded.json!
#   Budget items: 946 processed
#   Text items: 154 processed

# %%
def peek_collections(budget_collection, text_collection):
    """Quick peek at what's in your collections"""
    
    print(f"Budget items: {budget_collection.count()}")
    print(f"Text items: {text_collection.count()}")
    
    # Show 1 budget item
    if budget_collection.count() > 0:
        budget_sample = budget_collection.get(limit=1)
        print(f"\nBudget sample:\n{budget_sample['documents'][0]}")
    
    # Show 1 text item  
    if text_collection.count() > 0:
        text_sample = text_collection.get(limit=1)
        text_doc = text_sample['documents'][0]
        if len(text_doc) > 200:
            text_doc = text_doc[:200] + "..."
        print(f"\nText sample:\n{text_doc}")

# Usage:
peek_collections(budget_collection, text_collection)
# Out:
# Failed to send telemetry event CollectionGetEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionGetEvent: capture() takes 1 positional argument but 3 were given
# Budget items: 946
# Text items: 154
#
# Budget sample:
# Program: BEDIOO - STRATEGIC MARKETING AND SUPPORT | Expending Agency: BED | FY 2025-2026 Amount: $8293040 | FY 2026-2027 Amount: $8293040 | Program ID: BEDIOO | 2025-2026 Funding Source: general funds | 2026-2027 Funding Source: general funds
#
# Text sample:
# HOUSE OF REPRESENTATIVES H.B. NO.
# THIRTY-THIRD LEGISLATURE, 2025
# STATE OF HAWAII
# A BILL FOR AN ACT
# RELATING TO THE STATE BUDGET.
# BE IT ENACTED BY THE LEGISLATURE OF THE STATE OF HAWAII:
# PART I. GENERA...

# %%
def query_budget_collections(budget_collection, text_collection, query_text, n_results=100, distance_threshold=0.70, search_both=True):
    """
    Query both budget and text collections with distance threshold filtering
    
    Args:
        budget_collection: ChromaDB collection for budget items
        text_collection: ChromaDB collection for text items
        query_text: Search query
        n_results: Maximum number of results per collection
        distance_threshold: Filter out results with distance > this value
        search_both: If True, search both collections. If False, search only budget collection
    """
    
    def filter_results(results, collection_type):
        """Helper function to filter results by distance threshold"""
        if not results['documents'][0]:
            return results
        
        filtered_docs = []
        filtered_meta = []
        filtered_distances = []
        
        for doc, meta, dist in zip(results['documents'][0], results['metadatas'][0], results['distances'][0]):
            if dist <= distance_threshold:
                # Add collection type to metadata for identification
                meta['collection_type'] = collection_type
                filtered_docs.append(doc)
                filtered_meta.append(meta)
                filtered_distances.append(dist)
        
        return {
            'documents': [filtered_docs],
            'metadatas': [filtered_meta], 
            'distances': [filtered_distances]
        }
    
    all_results = {
        'documents': [[]],
        'metadatas': [[]],
        'distances': [[]]
    }
    
    # Query budget collection
    print(f"🔍 Searching budget items for: '{query_text}'")
    budget_results = budget_collection.query(
        query_texts=[query_text],
        n_results=n_results
    )
    budget_filtered = filter_results(budget_results, 'budget_item')
    budget_filtered = filter_results(budget_results, 'budget_item')
    
    # Add budget results to combined results
    all_results['documents'][0].extend(budget_filtered['documents'][0])
    all_results['metadatas'][0].extend(budget_filtered['metadatas'][0])
    all_results['distances'][0].extend(budget_filtered['distances'][0])
    
    print(f"✅ Found {len(budget_filtered['documents'][0])} budget items within threshold")
    
    # Query text collection if requested
    if search_both:
        print(f"🔍 Searching text items for: '{query_text}'")
        text_results = text_collection.query(
            query_texts=[query_text],
            n_results=n_results
        )
        text_filtered = filter_results(text_results, 'text_item')
        
        # Add text results to combined results
        all_results['documents'][0].extend(text_filtered['documents'][0])
        all_results['metadatas'][0].extend(text_filtered['metadatas'][0])
        all_results['distances'][0].extend(text_filtered['distances'][0])
        
        print(f"✅ Found {len(text_filtered['documents'][0])} text items within threshold")
    
    # Sort all results by distance (best matches first)
    if all_results['documents'][0]:
        combined = list(zip(all_results['documents'][0], all_results['metadatas'][0], all_results['distances'][0]))
        combined.sort(key=lambda x: x[2])  # Sort by distance
        
        all_results['documents'][0] = [item[0] for item in combined]
        all_results['metadatas'][0] = [item[1] for item in combined]
        all_results['distances'][0] = [item[2] for item in combined]
    
    # Print results
    total_results = len(all_results['documents'][0])
    if total_results > 0:
        print(f"\n📊 Found {total_results} total results for: '{query_text}' (threshold: {distance_threshold})")
        print("=" * 80)
        
        for i, (doc, meta, dist) in enumerate(zip(all_results['documents'][0], all_results['metadatas'][0], all_results['distances'][0])):
            collection_type = meta.get('collection_type', 'unknown')
            document_name = meta.get('document_name', 'Unknown')
            page_number = meta.get('page_number', 'N/A')
            
            # Truncate long documents for display
            display_doc = doc if len(doc) <= 150 else doc[:150] + "..."
            
            print(f"{i+1}. [{collection_type.upper()}] {display_doc}")
            print(f"    📄 {document_name} (Page {page_number}) - Distance: {dist:.3f}")
            
            # Show additional info for budget items
            if collection_type == 'budget_item':
                program = meta.get('program', 'N/A')
                if program != 'unknown':
                    print(f"    💰 Program: {program}")
            
            print()
    else:
        print(f"❌ No results found for: '{query_text}' within distance threshold of {distance_threshold}")
    
    return all_results

# Usage examples:
# Search both collections
query_budget_collections(budget_collection, text_collection, "education", distance_threshold=.7)

# Search only budget items
# query_budget_collections(budget_collection, text_collection, "transportation", search_both=False)

# Use different threshold
# query_budget_collections(budget_collection, text_collection, "health department", distance_threshold=0.6)
# Out:
# 🔍 Searching budget items for: 'education'
# ✅ Found 26 budget items within threshold
# 🔍 Searching text items for: 'education'
# ✅ Found 3 text items within threshold
#
# 📊 Found 29 total results for: 'education' (threshold: 0.7)
# ================================================================================
# 1. [BUDGET_ITEM] Program: JARRETT MIDDLE SCHOOL, OAHUREPAINTING OF BUILDING H. | Expending Agency: EDN | FY 2025-2026 Amount: $50 | Program ID: unknown | 2025-2026 Fun...
#     📄 HB300_SD1 (Page 101) - Distance: 0.630
#     💰 Program: JARRETT MIDDLE SCHOOL, OAHUREPAINTING OF BUILDING H.
#
# 2. [TEXT_ITEM] G. FORMAL EDUCATION
# 1. EDNIOO - SCHOOL-BASED BUDGETING
# OPERATING
# EDN 1,303,218,337 A 1,291,636,590 A
# EDN 5,251,693 B 5,251,693 B
# EDN 167,203,642 N 167...
#     📄 HB300_SD1 (Page 35) - Distance: 0.645
#
# 3. [BUDGET_ITEM] Program: MOLOKAI HIGH SCHOOL, MOLOKAI
# DESIGN AND CONSTRUCTION OF THE DEMO
# TEACHER COTTAGE. | Expending Agency: EDN | FY 2025-2026 Amount: $275 | Progr...
#     📄 HB300_SD1 (Page 106) - Distance: 0.658
#     💰 Program: MOLOKAI HIGH SCHOOL, MOLOKAI
# DESIGN AND CONSTRUCTION OF THE DEMO
# TEACHER COTTAGE.
#
# 4. [BUDGET_ITEM] Program: SCHOOL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $150000 | Program ID: Department of Education400 | 2025-2026 Funding Source: pr...
#     📄 HB300_SD1 (Page 36) - Distance: 0.661
#     💰 Program: SCHOOL SUPPORT
#
# 5. [BUDGET_ITEM] Program: DESIGN AND CONSTRUCTION FOR IMPROVEMENTS TO SCHOOL FACILITIES AND GROUNDS TO MEET HEALTH AND SAFETY REQUIREMENTS/LAWS, AND ORDINANCES AND/OR ...
#     📄 HB300_SD1 (Page 104) - Distance: 0.666
#     💰 Program: DESIGN AND CONSTRUCTION FOR IMPROVEMENTS TO SCHOOL FACILITIES AND GROUNDS TO MEET HEALTH AND SAFETY REQUIREMENTS/LAWS, AND ORDINANCES AND/OR COUNTY REQUIREMENTS; GROUND AND SITE IMPROVEMENTS; EQUIPMENT AND APPURTENANCES.
#
# 6. [BUDGET_ITEM] Program: LUMP SUM - TELECOMMUNICATIONS, STATEWIDE DESIGN, CONSTRUCTION, AND EQUIPMENT TO MAINTAIN AND IMPROVE DOE'S CONVERGED INFRASTRUCTURE PROVIDING...
#     📄 HB300_SD1 (Page 103) - Distance: 0.667
#     💰 Program: LUMP SUM - TELECOMMUNICATIONS, STATEWIDE DESIGN, CONSTRUCTION, AND EQUIPMENT TO MAINTAIN AND IMPROVE DOE'S CONVERGED INFRASTRUCTURE PROVIDING BELLS AND PAGING FOR SCHOOL SAFETY; CONVERGED INFRASTRUCTURE PROVIDING SCHOOLS' ACCESS TO ON-LINE LEARNING AND INTERNET RESOURCES; TELECOMMUNICATIONS, AND ELECTRICAL INFRASTRUCTURE IMPROVEMENTS; GROUND AND SITE IMPROVEMENTS; EQUIPMENT AND APPURTENANCES.
#
# 7. [BUDGET_ITEM] Program: MOANALUA MIDDLE SCHOOL, OAHU
# UPGRADING ELECTRICAL SYSTEMS; GROUND
# AND SITE IMPROVEMENTS. | Expending Agency: EDN | FY 2025-2026 Amount: $1500...
#     📄 HB300_SD1 (Page 106) - Distance: 0.672
#     💰 Program: MOANALUA MIDDLE SCHOOL, OAHU
# UPGRADING ELECTRICAL SYSTEMS; GROUND
# AND SITE IMPROVEMENTS.
#
# 8. [BUDGET_ITEM] Program: CHARTER SCHOOLS | Expending Agency: EDN | FY 2025-2026 Amount: $1500000 | Program ID: Department of Education600 | 2025-2026 Funding Source: ...
#     📄 HB300_SD1 (Page 36) - Distance: 0.675
#     💰 Program: CHARTER SCHOOLS
#
# 9. [BUDGET_ITEM] Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $21305769 | FY 2026-2027 Amount: $24749084 | Program ID: Department of Educat...
#     📄 HB300_SD1 (Page 37) - Distance: 0.675
#     💰 Program: - EARLY LEARNING
#
# 10. [TEXT_ITEM] CAPITAL IMPROVEMENT PROJECTS
#
# ITEM NO. PROJECT NO. TITLE AGENCY TOTAL FUNDING
# 23. MOANALUA HIGH SCHOOL, OAHU EDN 20,000 C C
# DEMOLITION AND CONSTRUCTIO...
#     📄 HB300_SD1 (Page 106) - Distance: 0.677
#
# 11. [BUDGET_ITEM] Program: MOLOKAI MIDDLE SCHOOL, MOLOKAI
# DESIGN AND CONSTRUCTION FOR
# REROOFING. | Expending Agency: EDN | FY 2025-2026 Amount: $1100 | Program ID: unkn...
#     📄 HB300_SD1 (Page 106) - Distance: 0.677
#     💰 Program: MOLOKAI MIDDLE SCHOOL, MOLOKAI
# DESIGN AND CONSTRUCTION FOR
# REROOFING.
#
# 12. [BUDGET_ITEM] Program: JARRETT MIDDLE SCHOOL, OAHUREPAVE PALOLO AVENUE AND KALUA ROADPARKING LOTS. | Expending Agency: EDN | FY 2025-2026 Amount: $305 | Program ID:...
#     📄 HB300_SD1 (Page 101) - Distance: 0.680
#     💰 Program: JARRETT MIDDLE SCHOOL, OAHUREPAVE PALOLO AVENUE AND KALUA ROADPARKING LOTS.
#
# 13. [BUDGET_ITEM] Program: INSTRUCTIONAL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $92400786 | FY 2026-2027 Amount: $92831771 | Program ID: Department of E...
#     📄 HB300_SD1 (Page 35) - Distance: 0.681
#     💰 Program: INSTRUCTIONAL SUPPORT
#
# 14. [TEXT_ITEM] CAPITAL IMPROVEMENT PROJECTS
#
# ITEM NO. PROJECT NO. TITLE AGENCY TOTAL FUNDING
# 37. WAIPAHU INTERMEDIATE SCHOOL, OAHU
# PLANS, DESIGN, CONSTRUCTION, AND E...
#     📄 HB300_SD1 (Page 109) - Distance: 0.681
#
# 15. [BUDGET_ITEM] Program: WAIMEA HIGH SCHOOL, KAUAI
# DESIGN AND CONSTRUCTION FOR GYMNASIUM
# RELATED FACILITIES AND IMPROVEMENTS;
# GROUND AND SITE IMPROVEMENTS, EQUIPMENT
# ...
#     📄 HB300_SD1 (Page 108) - Distance: 0.683
#     💰 Program: WAIMEA HIGH SCHOOL, KAUAI
# DESIGN AND CONSTRUCTION FOR GYMNASIUM
# RELATED FACILITIES AND IMPROVEMENTS;
# GROUND AND SITE IMPROVEMENTS, EQUIPMENT
# AND APPURTENANCES
#
# 16. [BUDGET_ITEM] Program: PLANS, DESIGN, LAND ACQUISITION,
# CONSTRUCTION, AND EQUIPMENT FOR A NEW
# SCHOOL; GROUND AND SITE IMPROVEMENTS;
# EQUIPMENT AND APPURTENANCES. | E...
#     📄 HB300_SD1 (Page 109) - Distance: 0.684
#     💰 Program: PLANS, DESIGN, LAND ACQUISITION,
# CONSTRUCTION, AND EQUIPMENT FOR A NEW
# SCHOOL; GROUND AND SITE IMPROVEMENTS;
# EQUIPMENT AND APPURTENANCES.
#
# 17. [BUDGET_ITEM] Program: INSTRUCTIONAL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $500000 | FY 2026-2027 Amount: $500000 | Program ID: Department of Educa...
#     📄 HB300_SD1 (Page 35) - Distance: 0.686
#     💰 Program: INSTRUCTIONAL SUPPORT
#
# 18. [BUDGET_ITEM] Program: SCHOOL FACILITIES AUTHORITY | Expending Agency: EDN | FY 2025-2026 Amount: $1731283 | FY 2026-2027 Amount: $1738979 | Program ID: Department ...
#     📄 HB300_SD1 (Page 36) - Distance: 0.687
#     💰 Program: SCHOOL FACILITIES AUTHORITY
#
# 19. [BUDGET_ITEM] Program: ILIMA INTERMEDIATE SCHOOL, OAHU.CONTINUATION OF PHASED FUNDING FORDESIGN, CONSTRUCTION, AND RENOVATION OFCAMPUS BUILDINGS, INCLUDING 6TH GRAD...
#     📄 HB300_SD1 (Page 101) - Distance: 0.687
#     💰 Program: ILIMA INTERMEDIATE SCHOOL, OAHU.CONTINUATION OF PHASED FUNDING FORDESIGN, CONSTRUCTION, AND RENOVATION OFCAMPUS BUILDINGS, INCLUDING 6TH GRADEBUILDING, RENOVATION OF VOCATIONALCLASSROOMS, RESTROOMS, AND CAMPUS SAFETYSECURITY FENCING; GROUND AND SITEIMPROVEMENTS, EQUIPMENT, ANDAPPURTENANCES.
#
# 20. [BUDGET_ITEM] Program: HILO, RENEW, IMPROVE AND MODERNIZE, | Expending Agency: UNIVERSITY OF HAWAII, HILO | Program ID: University of Hawaii210 | 2025-2026 Funding ...
#     📄 HB300_SD1 (Page 112) - Distance: 0.688
#     💰 Program: HILO, RENEW, IMPROVE AND MODERNIZE,
#
# 21. [BUDGET_ITEM] Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $3000000 | FY 2026-2027 Amount: $3000000 | Program ID: Department of Educatio...
#     📄 HB300_SD1 (Page 37) - Distance: 0.689
#     💰 Program: - EARLY LEARNING
#
# 22. [BUDGET_ITEM] Program: KALAHEO HIGH SCHOOL, OAHU
# DESIGN AND CONSTRUCTION FOR RETROFIT
# OF SCHOOL'S CAFETERIA. | Expending Agency: EDN | FY 2025-2026 Amount: $12000 |...
#     📄 HB300_SD1 (Page 102) - Distance: 0.690
#     💰 Program: KALAHEO HIGH SCHOOL, OAHU
# DESIGN AND CONSTRUCTION FOR RETROFIT
# OF SCHOOL'S CAFETERIA.
#
# 23. [BUDGET_ITEM] Program: SCHOOL FACILITIES AUTHORITY | Expending Agency: EDN | FY 2025-2026 Amount: $70000000 | Program ID: Department of Education450 | 2025-2026 Fun...
#     📄 HB300_SD1 (Page 36) - Distance: 0.691
#     💰 Program: SCHOOL FACILITIES AUTHORITY
#
# 24. [BUDGET_ITEM] Program: SCHOOL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $44200920 | FY 2026-2027 Amount: $44200920 | Program ID: Department of Educatio...
#     📄 HB300_SD1 (Page 36) - Distance: 0.693
#     💰 Program: SCHOOL SUPPORT
#
# 25. [BUDGET_ITEM] Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $125628 | FY 2026-2027 Amount: $125628 | Program ID: Department of Education7...
#     📄 HB300_SD1 (Page 37) - Distance: 0.698
#     💰 Program: - EARLY LEARNING
#
# 26. [BUDGET_ITEM] Program: SCHOOL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $74600000 | FY 2026-2027 Amount: $74600000 | Program ID: Department of Educatio...
#     📄 HB300_SD1 (Page 36) - Distance: 0.698
#     💰 Program: SCHOOL SUPPORT
#
# 27. [BUDGET_ITEM] Program: - CHARTER SCHOOLS COMMISSION AND ADMINISTRATION | Expending Agency: EDN | FY 2025-2026 Amount: $15019269 | FY 2026-2027 Amount: $15029269 | P...
#     📄 HB300_SD1 (Page 37) - Distance: 0.698
#     💰 Program: - CHARTER SCHOOLS COMMISSION AND ADMINISTRATION
#
# 28. [BUDGET_ITEM] Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $380000 | FY 2026-2027 Amount: $380000 | Program ID: Department of Education7...
#     📄 HB300_SD1 (Page 37) - Distance: 0.699
#     💰 Program: - EARLY LEARNING
#
# 29. [BUDGET_ITEM] Program: KAEWAI ELEMENTARY SCHOOL, OAHU
# EXPANDING EXISTING PARKING LOT;
# GROUND AND SITE IMPROVEMENTS. | Expending Agency: EDN | FY 2025-2026 Amount: $...
#     📄 HB300_SD1 (Page 102) - Distance: 0.700
#     💰 Program: KAEWAI ELEMENTARY SCHOOL, OAHU
# EXPANDING EXISTING PARKING LOT;
# GROUND AND SITE IMPROVEMENTS.
# {'documents': [['Program: JARRETT MIDDLE SCHOOL, OAHUREPAINTING OF BUILDING H. | Expending Agency: EDN | FY 2025-2026 Amount: $50 | Program ID: unknown | 2025-2026 Funding Source: C C | 2026-2027 Funding Source: unknown',
#    'G. FORMAL EDUCATION\n1. EDNIOO - SCHOOL-BASED BUDGETING\nOPERATING\nEDN 1,303,218,337 A 1,291,636,590 A\nEDN 5,251,693 B 5,251,693 B\nEDN 167,203,642 N 167,203,642 N\nEDN 13,390,000 T 13,390,000 T\nEDN 7,495,605 U 7,495,605 U\nEDN 3,239,686 W 3,239,301 W\nEDN 21,414,657 P 21,414,657 P\nINVESTMENT CAPITAL\nEDN 358,000,000 C 36,500,000 C\nEDN 240,000,000 P P\n2. EDN150 - SPECIAL EDUCATION AND STUDENT SUPPORT SERVICES\nOPERATING\nEDN 520,838,678 A 525,281,027 A\nEDN 250,000 B 250,000 B\nEDN 60,084,267 N 61,584,267 N\nEDN 11,000,000 W 11,000,000 W\nEDN 5,950,000 P 5,950,000 P\n3. EDN200 - INSTRUCTIONAL SUPPORT\nOPERATING\nEDN 92,400,786 A 92,831,771 A\nEDN 500,000 N 500,000 N\nEDN 273,794 P 273,794 P',
#    'Program: MOLOKAI HIGH SCHOOL, MOLOKAI\nDESIGN AND CONSTRUCTION OF THE DEMO\nTEACHER COTTAGE. | Expending Agency: EDN | FY 2025-2026 Amount: $275 | Program ID: unknown | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund',
#    'Program: SCHOOL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $150000 | Program ID: Department of Education400 | 2025-2026 Funding Source: private contributions | 2026-2027 Funding Source: unknown',
#    'Program: DESIGN AND CONSTRUCTION FOR IMPROVEMENTS TO SCHOOL FACILITIES AND GROUNDS TO MEET HEALTH AND SAFETY REQUIREMENTS/LAWS, AND ORDINANCES AND/OR COUNTY REQUIREMENTS; GROUND AND SITE IMPROVEMENTS; EQUIPMENT AND APPURTENANCES. | Expending Agency: unknown | FY 2025-2026 Amount: $23000 | Program ID: Department of Education | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund',
#    "Program: LUMP SUM - TELECOMMUNICATIONS, STATEWIDE DESIGN, CONSTRUCTION, AND EQUIPMENT TO MAINTAIN AND IMPROVE DOE'S CONVERGED INFRASTRUCTURE PROVIDING BELLS AND PAGING FOR SCHOOL SAFETY; CONVERGED INFRASTRUCTURE PROVIDING SCHOOLS' ACCESS TO ON-LINE LEARNING AND INTERNET RESOURCES; TELECOMMUNICATIONS, AND ELECTRICAL INFRASTRUCTURE IMPROVEMENTS; GROUND AND SITE IMPROVEMENTS; EQUIPMENT AND APPURTENANCES. | Expending Agency: EDN | FY 2025-2026 Amount: $3000 | Program ID: unknown | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund",
#    'Program: MOANALUA MIDDLE SCHOOL, OAHU\nUPGRADING ELECTRICAL SYSTEMS; GROUND\nAND SITE IMPROVEMENTS. | Expending Agency: EDN | FY 2025-2026 Amount: $1500 | Program ID: unknown | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund',
#    'Program: CHARTER SCHOOLS | Expending Agency: EDN | FY 2025-2026 Amount: $1500000 | Program ID: Department of Education600 | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: unknown',
#    'Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $21305769 | FY 2026-2027 Amount: $24749084 | Program ID: Department of Education700 | 2025-2026 Funding Source: general funds | 2026-2027 Funding Source: general funds',
#    'CAPITAL IMPROVEMENT PROJECTS\n\nITEM NO. PROJECT NO. TITLE AGENCY TOTAL FUNDING\n23. MOANALUA HIGH SCHOOL, OAHU EDN 20,000 C C\nDEMOLITION AND CONSTRUCTION OF WEIGHTROOM; GROUND AND SITE IMPROVEMENTS.\n\n24. MOANALUA MIDDLE SCHOOL, OAHU EDN 1,500 C C\nUPGRADING ELECTRICAL SYSTEMS; GROUND AND SITE IMPROVEMENTS.\n\n25. MOLOKAI HIGH SCHOOL, MOLOKAI EDN 275 C C\nDESIGN AND CONSTRUCTION OF THE DEMO TEACHER COTTAGE.\n\n26. MOLOKAI MIDDLE SCHOOL, MOLOKAI EDN 1,100 C c\nDESIGN AND CONSTRUCTION FOR REROOFING.\n\n27. PAIA ELEMENTARY SCHOOL NEW CLASSROOM EDN 35,500 C c\nCONSTRUCTION FOR A NEW CLASSROOM BUILDING AT PAIA ELEMENTARY SCHOOL, MAUI.',
#    'Program: MOLOKAI MIDDLE SCHOOL, MOLOKAI\nDESIGN AND CONSTRUCTION FOR\nREROOFING. | Expending Agency: EDN | FY 2025-2026 Amount: $1100 | Program ID: unknown | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund',
#    'Program: JARRETT MIDDLE SCHOOL, OAHUREPAVE PALOLO AVENUE AND KALUA ROADPARKING LOTS. | Expending Agency: EDN | FY 2025-2026 Amount: $305 | Program ID: unknown | 2025-2026 Funding Source: C C | 2026-2027 Funding Source: unknown',
#    'Program: INSTRUCTIONAL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $92400786 | FY 2026-2027 Amount: $92831771 | Program ID: Department of Education200 | 2025-2026 Funding Source: general funds | 2026-2027 Funding Source: general funds',
#    "CAPITAL IMPROVEMENT PROJECTS\n\nITEM NO. PROJECT NO. TITLE AGENCY TOTAL FUNDING\n37. WAIPAHU INTERMEDIATE SCHOOL, OAHU\nPLANS, DESIGN, CONSTRUCTION, AND EQUIPMENT FOR NEW COVERED ATHLETIC COURTS.\nEDN 2,000 C C\n\n38. WEBLING ELEMENTARY SCHOOL, OAHU\nPLANS, DESIGN, AND CONSTRUCTION FOR A NEW MAIN OFFICE BUILDING; EQUIPMENT AND APPURTENANCES.\nEDN 10,000 C C\n\nEDN450 - SCHOOL FACILITIES AUTHORITY\n\n39. LAHAINA ELEMENTARY SCHOOL, MAUI\nPLANS, DESIGN, LAND ACQUISITION, CONSTRUCTION, AND EQUIPMENT FOR A NEW SCHOOL; GROUND AND SITE IMPROVEMENTS; EQUIPMENT AND APPURTENANCES.\nEDN 70,000 W w\n\nEDN600 - CHARTER SCHOOLS\n\n40. WAI'ALAE ELEMENTARY PUBLIC CHARTER SCHOOL, OAHU\nINSTALLATION OF HVAC SYSTEMS; EXPANSION OF EXISTING SOLAR PANEL ARRAYS WITH ENERGY STORAGE SOLUTIONS; COMPREHENSIVE RENEWABLE ENERGY SYSTEM; DEPLOYMENT OF INTEGRATED AUTOMATION AI PLATFORM; INSTALLATION OF INTERACTIVE DASHBOARD SYSTEM.\nEDN 1,500 C c",
#    'Program: WAIMEA HIGH SCHOOL, KAUAI\nDESIGN AND CONSTRUCTION FOR GYMNASIUM\nRELATED FACILITIES AND IMPROVEMENTS;\nGROUND AND SITE IMPROVEMENTS, EQUIPMENT\nAND APPURTENANCES | Expending Agency: EDN | FY 2025-2026 Amount: $5000 | Program ID: unknown | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund',
#    'Program: PLANS, DESIGN, LAND ACQUISITION,\nCONSTRUCTION, AND EQUIPMENT FOR A NEW\nSCHOOL; GROUND AND SITE IMPROVEMENTS;\nEQUIPMENT AND APPURTENANCES. | Expending Agency: EDN | FY 2025-2026 Amount: $70000 | Program ID: Department of Education600 | 2025-2026 Funding Source: revolving funds | 2026-2027 Funding Source: unknown',
#    'Program: INSTRUCTIONAL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $500000 | FY 2026-2027 Amount: $500000 | Program ID: Department of Education200 | 2025-2026 Funding Source: federal funds | 2026-2027 Funding Source: federal funds',
#    'Program: SCHOOL FACILITIES AUTHORITY | Expending Agency: EDN | FY 2025-2026 Amount: $1731283 | FY 2026-2027 Amount: $1738979 | Program ID: Department of Education450 | 2025-2026 Funding Source: general funds | 2026-2027 Funding Source: general funds',
#    'Program: ILIMA INTERMEDIATE SCHOOL, OAHU.CONTINUATION OF PHASED FUNDING FORDESIGN, CONSTRUCTION, AND RENOVATION OFCAMPUS BUILDINGS, INCLUDING 6TH GRADEBUILDING, RENOVATION OF VOCATIONALCLASSROOMS, RESTROOMS, AND CAMPUS SAFETYSECURITY FENCING; GROUND AND SITEIMPROVEMENTS, EQUIPMENT, ANDAPPURTENANCES. | Expending Agency: EDN | FY 2025-2026 Amount: $4500 | Program ID: unknown | 2025-2026 Funding Source: C C | 2026-2027 Funding Source: unknown',
#    'Program: HILO, RENEW, IMPROVE AND MODERNIZE, | Expending Agency: UNIVERSITY OF HAWAII, HILO | Program ID: University of Hawaii210 | 2025-2026 Funding Source: unknown | 2026-2027 Funding Source: unknown',
#    'Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $3000000 | FY 2026-2027 Amount: $3000000 | Program ID: Department of Education700 | 2025-2026 Funding Source: special funds | 2026-2027 Funding Source: special funds',
#    "Program: KALAHEO HIGH SCHOOL, OAHU\nDESIGN AND CONSTRUCTION FOR RETROFIT\nOF SCHOOL'S CAFETERIA. | Expending Agency: EDN | FY 2025-2026 Amount: $12000 | Program ID: unknown | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund",
#    'Program: SCHOOL FACILITIES AUTHORITY | Expending Agency: EDN | FY 2025-2026 Amount: $70000000 | Program ID: Department of Education450 | 2025-2026 Funding Source: revolving funds | 2026-2027 Funding Source: unknown',
#    'Program: SCHOOL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $44200920 | FY 2026-2027 Amount: $44200920 | Program ID: Department of Education400 | 2025-2026 Funding Source: special funds | 2026-2027 Funding Source: special funds',
#    'Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $125628 | FY 2026-2027 Amount: $125628 | Program ID: Department of Education700 | 2025-2026 Funding Source: federal funds | 2026-2027 Funding Source: federal funds',
#    'Program: SCHOOL SUPPORT | Expending Agency: EDN | FY 2025-2026 Amount: $74600000 | FY 2026-2027 Amount: $74600000 | Program ID: Department of Education400 | 2025-2026 Funding Source: federal funds | 2026-2027 Funding Source: federal funds',
#    'Program: - CHARTER SCHOOLS COMMISSION AND ADMINISTRATION | Expending Agency: EDN | FY 2025-2026 Amount: $15019269 | FY 2026-2027 Amount: $15029269 | Program ID: Department of Education612 | 2025-2026 Funding Source: general funds | 2026-2027 Funding Source: general funds',
#    'Program: - EARLY LEARNING | Expending Agency: EDN | FY 2025-2026 Amount: $380000 | FY 2026-2027 Amount: $380000 | Program ID: Department of Education700 | 2025-2026 Funding Source: other federal funds | 2026-2027 Funding Source: other federal funds',
#    'Program: KAEWAI ELEMENTARY SCHOOL, OAHU\nEXPANDING EXISTING PARKING LOT;\nGROUND AND SITE IMPROVEMENTS. | Expending Agency: EDN | FY 2025-2026 Amount: $550 | Program ID: unknown | 2025-2026 Funding Source: general obligation bond fund | 2026-2027 Funding Source: general obligation bond fund']],
#  'metadatas': [[{'program_id_expanded': 'unknown',
#     'document_name': 'HB300_SD1',
#     'page_number': 101,
#     'appropriations_mof_2025_2026': 'C C',
#     'program': 'JARRETT MIDDLE SCHOOL, OAHUREPAINTING OF BUILDING H.',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'classification_prediction': 'budget_table',
#     'fiscal_year_2025_2026_amount': '50',
#     'appropriations_mof_2026_2027': 'unknown',
#     'item_number': '7',
#     'appropriations_mof_2025_2026_expanded': 'C C',
#     'expending_agency': 'EDN',
#     'program_id': 'unknown',
#     'extraction_method': 'gemini_dual',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'chunk_type': 'budget_item',
#     'collection_type': 'budget_item'},
#    {'classification_prediction': 'budget_table',
#     'chunk_type': 'text_item',
#     'document_name': 'HB300_SD1',
#     'extraction_method': 'gemini_dual',
#     'classification_confidence': 95,
#     'page_number': 35,
#     'collection_type': 'text_item'},
#    {'appropriations_mof_2026_2027': 'C',
#     'extraction_method': 'gemini_dual',
#     'appropriations_mof_2025_2026': 'C',
#     'program_id': 'unknown',
#     'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'item_number': '25',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'program': 'MOLOKAI HIGH SCHOOL, MOLOKAI\nDESIGN AND CONSTRUCTION OF THE DEMO\nTEACHER COTTAGE.',
#     'program_id_expanded': 'unknown',
#     'classification_prediction': 'budget_table',
#     'chunk_type': 'budget_item',
#     'page_number': 106,
#     'expending_agency': 'EDN',
#     'fiscal_year_2025_2026_amount': '275',
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'document_name': 'HB300_SD1',
#     'collection_type': 'budget_item'},
#    {'fiscal_year_2025_2026_amount': '150000',
#     'extraction_method': 'gemini_dual',
#     'program': 'SCHOOL SUPPORT',
#     'classification_prediction': 'budget_table',
#     'program_id_expanded': 'Department of Education400',
#     'document_name': 'HB300_SD1',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'appropriations_mof_2025_2026': 'R',
#     'program_id': 'EDN400',
#     'expending_agency': 'EDN',
#     'chunk_type': 'budget_item',
#     'page_number': 36,
#     'appropriations_mof_2026_2027': 'unknown',
#     'item_number': '5',
#     'appropriations_mof_2025_2026_expanded': 'private contributions',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'collection_type': 'budget_item'},
#    {'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'document_name': 'HB300_SD1',
#     'program_id': 'EDN',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'item_number': '35',
#     'page_number': 104,
#     'classification_prediction': 'budget_table',
#     'appropriations_mof_2026_2027': 'C',
#     'expending_agency': 'unknown',
#     'chunk_type': 'budget_item',
#     'extraction_method': 'gemini_dual',
#     'program': 'DESIGN AND CONSTRUCTION FOR IMPROVEMENTS TO SCHOOL FACILITIES AND GROUNDS TO MEET HEALTH AND SAFETY REQUIREMENTS/LAWS, AND ORDINANCES AND/OR COUNTY REQUIREMENTS; GROUND AND SITE IMPROVEMENTS; EQUIPMENT AND APPURTENANCES.',
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'fiscal_year_2025_2026_amount': '23000',
#     'program_id_expanded': 'Department of Education',
#     'appropriations_mof_2025_2026': 'C',
#     'collection_type': 'budget_item'},
#    {'document_name': 'HB300_SD1',
#     'program_id': 'unknown',
#     'program_id_expanded': 'unknown',
#     'item_number': '13.',
#     'appropriations_mof_2026_2027': 'C',
#     'appropriations_mof_2025_2026': 'C',
#     'page_number': 103,
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'fiscal_year_2025_2026_amount': '3000',
#     'program': "LUMP SUM - TELECOMMUNICATIONS, STATEWIDE DESIGN, CONSTRUCTION, AND EQUIPMENT TO MAINTAIN AND IMPROVE DOE'S CONVERGED INFRASTRUCTURE PROVIDING BELLS AND PAGING FOR SCHOOL SAFETY; CONVERGED INFRASTRUCTURE PROVIDING SCHOOLS' ACCESS TO ON-LINE LEARNING AND INTERNET RESOURCES; TELECOMMUNICATIONS, AND ELECTRICAL INFRASTRUCTURE IMPROVEMENTS; GROUND AND SITE IMPROVEMENTS; EQUIPMENT AND APPURTENANCES.",
#     'expending_agency': 'EDN',
#     'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'extraction_method': 'gemini_dual',
#     'classification_prediction': 'budget_table',
#     'chunk_type': 'budget_item',
#     'collection_type': 'budget_item'},
#    {'appropriations_mof_2025_2026': 'C',
#     'classification_prediction': 'budget_table',
#     'appropriations_mof_2026_2027': 'C',
#     'program_id': 'unknown',
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'chunk_type': 'budget_item',
#     'page_number': 106,
#     'fiscal_year_2025_2026_amount': '1500',
#     'item_number': '24',
#     'program': 'MOANALUA MIDDLE SCHOOL, OAHU\nUPGRADING ELECTRICAL SYSTEMS; GROUND\nAND SITE IMPROVEMENTS.',
#     'program_id_expanded': 'unknown',
#     'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'extraction_method': 'gemini_dual',
#     'expending_agency': 'EDN',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'document_name': 'HB300_SD1',
#     'collection_type': 'budget_item'},
#    {'program': 'CHARTER SCHOOLS',
#     'appropriations_mof_2026_2027': 'unknown',
#     'program_id_expanded': 'Department of Education600',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'appropriations_mof_2025_2026': 'C',
#     'item_number': '8',
#     'extraction_method': 'gemini_dual',
#     'page_number': 36,
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'fiscal_year_2025_2026_amount': '1500000',
#     'classification_prediction': 'budget_table',
#     'expending_agency': 'EDN',
#     'program_id': 'EDN600',
#     'chunk_type': 'budget_item',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'document_name': 'HB300_SD1',
#     'collection_type': 'budget_item'},
#    {'fiscal_year_2025_2026_amount': '21305769',
#     'program_id': 'EDN700',
#     'extraction_method': 'gemini_dual',
#     'page_number': 37,
#     'appropriations_mof_2025_2026_expanded': 'general funds',
#     'chunk_type': 'budget_item',
#     'appropriations_mof_2026_2027_expanded': 'general funds',
#     'item_number': '10',
#     'classification_prediction': 'budget_table',
#     'fiscal_year_2026_2027_amount': '24749084',
#     'program': '- EARLY LEARNING',
#     'document_name': 'HB300_SD1',
#     'expending_agency': 'EDN',
#     'appropriations_mof_2025_2026': 'A',
#     'program_id_expanded': 'Department of Education700',
#     'appropriations_mof_2026_2027': 'A',
#     'collection_type': 'budget_item'},
#    {'classification_confidence': 95,
#     'page_number': 106,
#     'document_name': 'HB300_SD1',
#     'extraction_method': 'gemini_dual',
#     'classification_prediction': 'budget_table',
#     'chunk_type': 'text_item',
#     'collection_type': 'text_item'},
#    {'classification_prediction': 'budget_table',
#     'page_number': 106,
#     'program_id_expanded': 'unknown',
#     'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'item_number': '26',
#     'program': 'MOLOKAI MIDDLE SCHOOL, MOLOKAI\nDESIGN AND CONSTRUCTION FOR\nREROOFING.',
#     'program_id': 'unknown',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'appropriations_mof_2025_2026': 'c',
#     'fiscal_year_2025_2026_amount': '1100',
#     'document_name': 'HB300_SD1',
#     'extraction_method': 'gemini_dual',
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'appropriations_mof_2026_2027': 'c',
#     'expending_agency': 'EDN',
#     'chunk_type': 'budget_item',
#     'collection_type': 'budget_item'},
#    {'appropriations_mof_2026_2027': 'unknown',
#     'page_number': 101,
#     'extraction_method': 'gemini_dual',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'program': 'JARRETT MIDDLE SCHOOL, OAHUREPAVE PALOLO AVENUE AND KALUA ROADPARKING LOTS.',
#     'document_name': 'HB300_SD1',
#     'chunk_type': 'budget_item',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'appropriations_mof_2025_2026': 'C C',
#     'fiscal_year_2025_2026_amount': '305',
#     'item_number': '8',
#     'expending_agency': 'EDN',
#     'program_id': 'unknown',
#     'appropriations_mof_2025_2026_expanded': 'C C',
#     'program_id_expanded': 'unknown',
#     'classification_prediction': 'budget_table',
#     'collection_type': 'budget_item'},
#    {'expending_agency': 'EDN',
#     'program_id': 'EDN200',
#     'appropriations_mof_2026_2027_expanded': 'general funds',
#     'appropriations_mof_2025_2026_expanded': 'general funds',
#     'fiscal_year_2026_2027_amount': '92831771',
#     'classification_prediction': 'budget_table',
#     'item_number': '32',
#     'program_id_expanded': 'Department of Education200',
#     'fiscal_year_2025_2026_amount': '92400786',
#     'appropriations_mof_2026_2027': 'A',
#     'extraction_method': 'gemini_dual',
#     'appropriations_mof_2025_2026': 'A',
#     'document_name': 'HB300_SD1',
#     'chunk_type': 'budget_item',
#     'program': 'INSTRUCTIONAL SUPPORT',
#     'page_number': 35,
#     'collection_type': 'budget_item'},
#    {'document_name': 'HB300_SD1',
#     'page_number': 109,
#     'classification_prediction': 'budget_table',
#     'chunk_type': 'text_item',
#     'extraction_method': 'gemini_dual',
#     'classification_confidence': 95,
#     'collection_type': 'text_item'},
#    {'program_id_expanded': 'unknown',
#     'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'program_id': 'unknown',
#     'extraction_method': 'gemini_dual',
#     'chunk_type': 'budget_item',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'appropriations_mof_2026_2027': 'c',
#     'page_number': 108,
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'fiscal_year_2025_2026_amount': '5000',
#     'expending_agency': 'EDN',
#     'appropriations_mof_2025_2026': 'C',
#     'program': 'WAIMEA HIGH SCHOOL, KAUAI\nDESIGN AND CONSTRUCTION FOR GYMNASIUM\nRELATED FACILITIES AND IMPROVEMENTS;\nGROUND AND SITE IMPROVEMENTS, EQUIPMENT\nAND APPURTENANCES',
#     'classification_prediction': 'budget_table',
#     'item_number': '36',
#     'collection_type': 'budget_item'},
#    {'program_id': 'EDN600',
#     'document_name': 'HB300_SD1',
#     'chunk_type': 'budget_item',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'appropriations_mof_2025_2026': 'W',
#     'appropriations_mof_2026_2027': 'unknown',
#     'item_number': '23',
#     'program_id_expanded': 'Department of Education600',
#     'page_number': 109,
#     'appropriations_mof_2025_2026_expanded': 'revolving funds',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'expending_agency': 'EDN',
#     'program': 'PLANS, DESIGN, LAND ACQUISITION,\nCONSTRUCTION, AND EQUIPMENT FOR A NEW\nSCHOOL; GROUND AND SITE IMPROVEMENTS;\nEQUIPMENT AND APPURTENANCES.',
#     'extraction_method': 'gemini_dual',
#     'fiscal_year_2025_2026_amount': '70000',
#     'classification_prediction': 'budget_table',
#     'collection_type': 'budget_item'},
#    {'fiscal_year_2025_2026_amount': '500000',
#     'extraction_method': 'gemini_dual',
#     'chunk_type': 'budget_item',
#     'appropriations_mof_2026_2027': 'N',
#     'appropriations_mof_2025_2026': 'N',
#     'program': 'INSTRUCTIONAL SUPPORT',
#     'classification_prediction': 'budget_table',
#     'document_name': 'HB300_SD1',
#     'fiscal_year_2026_2027_amount': '500000',
#     'page_number': 35,
#     'expending_agency': 'EDN',
#     'program_id': 'EDN200',
#     'appropriations_mof_2025_2026_expanded': 'federal funds',
#     'program_id_expanded': 'Department of Education200',
#     'item_number': '34',
#     'appropriations_mof_2026_2027_expanded': 'federal funds',
#     'collection_type': 'budget_item'},
#    {'item_number': '6',
#     'appropriations_mof_2025_2026_expanded': 'general funds',
#     'fiscal_year_2025_2026_amount': '1731283',
#     'chunk_type': 'budget_item',
#     'program': 'SCHOOL FACILITIES AUTHORITY',
#     'classification_prediction': 'budget_table',
#     'appropriations_mof_2026_2027': 'A',
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2026_2027_expanded': 'general funds',
#     'program_id': 'EDN450',
#     'appropriations_mof_2025_2026': 'A',
#     'fiscal_year_2026_2027_amount': '1738979',
#     'page_number': 36,
#     'extraction_method': 'gemini_dual',
#     'expending_agency': 'EDN',
#     'program_id_expanded': 'Department of Education450',
#     'collection_type': 'budget_item'},
#    {'fiscal_year_2026_2027_amount': 'unknown',
#     'fiscal_year_2025_2026_amount': '4500',
#     'expending_agency': 'EDN',
#     'extraction_method': 'gemini_dual',
#     'program': 'ILIMA INTERMEDIATE SCHOOL, OAHU.CONTINUATION OF PHASED FUNDING FORDESIGN, CONSTRUCTION, AND RENOVATION OFCAMPUS BUILDINGS, INCLUDING 6TH GRADEBUILDING, RENOVATION OF VOCATIONALCLASSROOMS, RESTROOMS, AND CAMPUS SAFETYSECURITY FENCING; GROUND AND SITEIMPROVEMENTS, EQUIPMENT, ANDAPPURTENANCES.',
#     'program_id_expanded': 'unknown',
#     'item_number': '5',
#     'chunk_type': 'budget_item',
#     'appropriations_mof_2025_2026': 'C C',
#     'page_number': 101,
#     'appropriations_mof_2025_2026_expanded': 'C C',
#     'appropriations_mof_2026_2027': 'unknown',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'classification_prediction': 'budget_table',
#     'program_id': 'unknown',
#     'document_name': 'HB300_SD1',
#     'collection_type': 'budget_item'},
#    {'program_id': 'UOH210',
#     'program_id_expanded': 'University of Hawaii210',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'appropriations_mof_2025_2026': 'unknown',
#     'page_number': 112,
#     'extraction_method': 'gemini_dual',
#     'program': 'HILO, RENEW, IMPROVE AND MODERNIZE,',
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2025_2026_expanded': 'unknown',
#     'classification_prediction': 'text',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'chunk_type': 'budget_item',
#     'appropriations_mof_2026_2027': 'unknown',
#     'expending_agency': 'UNIVERSITY OF HAWAII, HILO',
#     'fiscal_year_2025_2026_amount': 'unknown',
#     'item_number': '1',
#     'collection_type': 'budget_item'},
#    {'expending_agency': 'EDN',
#     'program_id': 'EDN700',
#     'extraction_method': 'gemini_dual',
#     'program_id_expanded': 'Department of Education700',
#     'fiscal_year_2026_2027_amount': '3000000',
#     'classification_prediction': 'budget_table',
#     'fiscal_year_2025_2026_amount': '3000000',
#     'page_number': 37,
#     'chunk_type': 'budget_item',
#     'program': '- EARLY LEARNING',
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2026_2027': 'B',
#     'appropriations_mof_2026_2027_expanded': 'special funds',
#     'item_number': '10',
#     'appropriations_mof_2025_2026': 'B',
#     'appropriations_mof_2025_2026_expanded': 'special funds',
#     'collection_type': 'budget_item'},
#    {'document_name': 'HB300_SD1',
#     'program_id': 'unknown',
#     'chunk_type': 'budget_item',
#     'program': "KALAHEO HIGH SCHOOL, OAHU\nDESIGN AND CONSTRUCTION FOR RETROFIT\nOF SCHOOL'S CAFETERIA.",
#     'item_number': '11.',
#     'expending_agency': 'EDN',
#     'appropriations_mof_2026_2027': 'C',
#     'fiscal_year_2025_2026_amount': '12000',
#     'page_number': 102,
#     'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'extraction_method': 'gemini_dual',
#     'classification_prediction': 'budget_table',
#     'program_id_expanded': 'unknown',
#     'appropriations_mof_2025_2026': 'C',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'collection_type': 'budget_item'},
#    {'item_number': '6',
#     'program_id': 'EDN450',
#     'program': 'SCHOOL FACILITIES AUTHORITY',
#     'program_id_expanded': 'Department of Education450',
#     'appropriations_mof_2025_2026': 'W',
#     'fiscal_year_2025_2026_amount': '70000000',
#     'chunk_type': 'budget_item',
#     'appropriations_mof_2026_2027': 'unknown',
#     'classification_prediction': 'budget_table',
#     'appropriations_mof_2026_2027_expanded': 'unknown',
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2025_2026_expanded': 'revolving funds',
#     'expending_agency': 'EDN',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'page_number': 36,
#     'extraction_method': 'gemini_dual',
#     'collection_type': 'budget_item'},
#    {'extraction_method': 'gemini_dual',
#     'appropriations_mof_2026_2027': 'B',
#     'program_id_expanded': 'Department of Education400',
#     'fiscal_year_2026_2027_amount': '44200920',
#     'fiscal_year_2025_2026_amount': '44200920',
#     'item_number': '5',
#     'appropriations_mof_2025_2026_expanded': 'special funds',
#     'document_name': 'HB300_SD1',
#     'program_id': 'EDN400',
#     'page_number': 36,
#     'program': 'SCHOOL SUPPORT',
#     'appropriations_mof_2026_2027_expanded': 'special funds',
#     'appropriations_mof_2025_2026': 'B',
#     'classification_prediction': 'budget_table',
#     'expending_agency': 'EDN',
#     'chunk_type': 'budget_item',
#     'collection_type': 'budget_item'},
#    {'appropriations_mof_2025_2026_expanded': 'federal funds',
#     'document_name': 'HB300_SD1',
#     'classification_prediction': 'budget_table',
#     'expending_agency': 'EDN',
#     'appropriations_mof_2026_2027_expanded': 'federal funds',
#     'item_number': '10',
#     'page_number': 37,
#     'appropriations_mof_2025_2026': 'N',
#     'program_id': 'EDN700',
#     'appropriations_mof_2026_2027': 'N',
#     'program_id_expanded': 'Department of Education700',
#     'program': '- EARLY LEARNING',
#     'fiscal_year_2026_2027_amount': '125628',
#     'extraction_method': 'gemini_dual',
#     'fiscal_year_2025_2026_amount': '125628',
#     'chunk_type': 'budget_item',
#     'collection_type': 'budget_item'},
#    {'appropriations_mof_2025_2026_expanded': 'federal funds',
#     'program': 'SCHOOL SUPPORT',
#     'program_id': 'EDN400',
#     'appropriations_mof_2026_2027': 'N',
#     'extraction_method': 'gemini_dual',
#     'chunk_type': 'budget_item',
#     'fiscal_year_2026_2027_amount': '74600000',
#     'program_id_expanded': 'Department of Education400',
#     'item_number': '5',
#     'appropriations_mof_2026_2027_expanded': 'federal funds',
#     'appropriations_mof_2025_2026': 'N',
#     'classification_prediction': 'budget_table',
#     'document_name': 'HB300_SD1',
#     'page_number': 36,
#     'expending_agency': 'EDN',
#     'fiscal_year_2025_2026_amount': '74600000',
#     'collection_type': 'budget_item'},
#    {'program_id_expanded': 'Department of Education612',
#     'appropriations_mof_2026_2027_expanded': 'general funds',
#     'page_number': 37,
#     'appropriations_mof_2026_2027': 'A',
#     'expending_agency': 'EDN',
#     'extraction_method': 'gemini_dual',
#     'program': '- CHARTER SCHOOLS COMMISSION AND ADMINISTRATION',
#     'appropriations_mof_2025_2026': 'A',
#     'chunk_type': 'budget_item',
#     'item_number': '9',
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2025_2026_expanded': 'general funds',
#     'program_id': 'EDN612',
#     'classification_prediction': 'budget_table',
#     'fiscal_year_2026_2027_amount': '15029269',
#     'fiscal_year_2025_2026_amount': '15019269',
#     'collection_type': 'budget_item'},
#    {'program_id_expanded': 'Department of Education700',
#     'appropriations_mof_2025_2026_expanded': 'other federal funds',
#     'program': '- EARLY LEARNING',
#     'item_number': '10',
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2025_2026': 'P',
#     'fiscal_year_2025_2026_amount': '380000',
#     'appropriations_mof_2026_2027_expanded': 'other federal funds',
#     'fiscal_year_2026_2027_amount': '380000',
#     'extraction_method': 'gemini_dual',
#     'expending_agency': 'EDN',
#     'appropriations_mof_2026_2027': 'P',
#     'chunk_type': 'budget_item',
#     'page_number': 37,
#     'program_id': 'EDN700',
#     'classification_prediction': 'budget_table',
#     'collection_type': 'budget_item'},
#    {'appropriations_mof_2026_2027_expanded': 'general obligation bond fund',
#     'program_id': 'unknown',
#     'item_number': '9.',
#     'appropriations_mof_2025_2026': 'C',
#     'program': 'KAEWAI ELEMENTARY SCHOOL, OAHU\nEXPANDING EXISTING PARKING LOT;\nGROUND AND SITE IMPROVEMENTS.',
#     'expending_agency': 'EDN',
#     'classification_prediction': 'budget_table',
#     'chunk_type': 'budget_item',
#     'page_number': 102,
#     'fiscal_year_2025_2026_amount': '550',
#     'program_id_expanded': 'unknown',
#     'document_name': 'HB300_SD1',
#     'appropriations_mof_2026_2027': 'C',
#     'fiscal_year_2026_2027_amount': 'unknown',
#     'appropriations_mof_2025_2026_expanded': 'general obligation bond fund',
#     'extraction_method': 'gemini_dual',
#     'collection_type': 'budget_item'}]],
#  'distances': [[0.6300037503242493,
#    0.6451923251152039,
#    0.6578294038772583,
#    0.6612769961357117,
#    0.6659021377563477,
#    0.6673213243484497,
#    0.6717885732650757,
#    0.6746902465820312,
#    0.675184965133667,
#    0.6769249439239502,
#    0.6769974827766418,
#    0.6801116466522217,
#    0.6814777255058289,
#    0.6814910769462585,
#    0.6834524273872375,
#    0.6842793226242065,
#    0.6864050626754761,
#    0.6874465942382812,
#    0.6874560117721558,
#    0.6879494190216064,
#    0.6892067193984985,
#    0.6902621388435364,
#    0.6905951499938965,
#    0.6927566528320312,
#    0.6976381540298462,
#    0.6977834701538086,
#    0.6981068849563599,
#    0.6991763114929199,
#    0.6995086669921875]]}
